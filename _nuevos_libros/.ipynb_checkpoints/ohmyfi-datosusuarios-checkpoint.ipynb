# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import pandas as pd
import numpy as np
import json
from ssl import create_default_context
from datetime import datetime
from datetime import timedelta
#para request
import requests
from getpass import getpass
#parametros
import parametros

# %% [markdown]
# ## Leyendo datos del indice ohmyfi-datosusuarios

# %%
context = create_default_context(cafile=parametros.cafile)
es = Elasticsearch(
    parametros.servidor,
    http_auth=(parametros.usuario_EC, parametros.password_EC),
    scheme="https",
    port=parametros.puerto,
    ssl_context=context,
)

# %% [markdown]
# ## tomando fecha mas reciente del indice

# %%
total_docs = 0
try:
    response = es.search(
        index=parametros.ohmyfi_d_u_index,
        body={"aggs" : {
                   "max_date": {"max": {"field": "creado", "format": "yyyy-MM-dd HH:mm:ss"}}
                }
             },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["aggregations"]
    fecha_max=response["aggregations"]["max_date"]['value_as_string']
except:
    fecha_max = '2021-05-01 00:00:00'
print("Fecha maxima en indice usuarios: ",fecha_max)
# Out:
# Fecha maxima en indice usuarios:  2021-10-08 09:42:44

# %% [markdown]
# # Opcion creado

# %% [markdown]
# ## Leyendo la APi ohmyfi-datosusuarios

# %%
now = datetime.now()
new_date = now - timedelta(days=6)
format = "%Y%m%d"
format_ES = "%Y.%m.%d"
fecha_url = str(new_date.strftime("%Y/%m/%d"))
fecha_hoy = str(now.strftime(format_ES))

# %%
h_fin = str(now.strftime("%Y/%m/%d %H:%M"))
h_inicio = str(( datetime.strptime(h_fin, '%Y/%m/%d %H:%M') - timedelta(hours=2)).strftime("%Y/%m/%d %H:%M"))

# %%
url = parametros.url_ohmyfi + '?/datosusuario' + '/=&apiKey=' + parametros.ohmyfi_api_key + '&opcion=creado' + '&inicio=' + str(h_inicio) + '&final=' + str(h_fin) 
#url = 'https://www.ohmyfi.com/ApiOMF?/datosusuario/=&apiKey=okMOpLAkiYpafQKXhXirwUys&opcion=creado&inicio=2021/05/28'

# %%
url
# Out:
# 'https://www.ohmyfi.com/ApiOMF?/datosusuario/=&apiKey=okMOpLAkiYpafQKXhXirwUys&opcion=creado&inicio=2021/10/08 07:51&final=2021/10/08 09:51'

# %%
r = requests.get(url)
if r.status_code == 200:
    res = json.loads(r.text)
    datos_api = pd.DataFrame(res,columns=['lugar_cod','acepto_politicas','nombre','id_usuario','nombre_completo','apellidos'
                              ,'correo','documento','tipodoc','celular','telefono','direccion','ciudad'
                              ,'pais','creado','actualizado','eliminado','genero','fecha_nacimiento'
                              ,'nivel_educativo','rango_edad','alias','fecha','id_usuario_datos'
                              ,'validacion_datos','campos_validados','ocupacion','estado_civil','estrato'
                              ,'cantidad_hijos','indicativo_celular','nombre_corto'
                              ,'tipo_dispositivo','sistema_operativo'])
else:
    #exit()
    print(r.status_code)

# %%
datos_api
# Out:
#          lugar_cod acepto_politicas                                    nombre  \
# 0    41977-ZIFV774       2021-10-08  CORREG ALTO GUARAMITO_SAN JOSE DE CUCUTA
# 1    32214-ZZZY779       2021-10-08                           RODANIA_SAHAGUN
# 2    32583-ZGYO468       2021-10-08                   VDA CARRIZOLA_TIERRALTA
# 3    32559-ZIFV685       2021-10-08               VDA. BUENOS AIRES_TIERRALTA
# 4    41977-ZIFV774       2021-10-08  CORREG ALTO GUARAMITO_SAN JOSE DE CUCUTA
# ..             ...              ...                                       ...
# 359  32602-KPWM545       2021-10-08                   AGUILA BATATA_TIERRALTA
# 360  48528-ZZZY630       2021-10-08                       VDA EL NOGAL_FRESNO
# 361  70391-VZVF857       2021-10-08  ETCR- AGUA BONITA_SAN VICENTE DEL CAGUAN
# 362  26073-ZGYO917       2021-10-08       CORREGIMIENTO DE SAMARIA_FILADELFIA
# 363  32065-ZZZY836       2021-10-08       CORREG TORNO ROJO_PUERTO LIBERTADOR
#
#             id_usuario nombre_completo            apellidos  \
# 0    90-09-17-B7-8D-5E   Ana valentina      Trujillo Patiño
# 1    94-7B-E7-A0-1B-CE  José Alejandro        Ayazo vergara
# 2    12-16-AC-C0-F2-3F       Eva María       Carvajal Muñoz
# 3    20-32-6C-0B-D4-06    Edith Esther        Ramos Vergara
# 4    06-7D-99-CB-1D-0C           Marvi          Barón Durán
# ..                 ...             ...                  ...
# 359  C6-33-7C-20-7C-6E           Ismer       Garces achuriz
# 360  64-09-AC-D3-3D-3E   Victor Manuel         Muñoz Arango
# 361  44-59-E3-D7-3C-D2          Edison              Rumique
# 362  02-62-D2-58-C6-B3    Ediergustavo  Aristizabal aguirre
# 363  E6-8A-72-7C-ED-80      Luis mario               Arroyo
#
#                                    correo   documento tipodoc     celular  \
# 0    anavalentinatrujillopatino@gmail.com   309388803      TI  3507402574
# 1                                    None  1019036597      TI  3122374663
# 2                                    None  1062434850      TI        None
# 3                                    None  1073985918      CC        None
# 4                   marvi201445@gmail.com  1090395621      CC  3142482367
# ..                                    ...         ...     ...         ...
# 359                                  None  1073974858      CC        None
# 360                                  None  3116498688      TI        None
# 361                                  None    17659126      CC  3212152801
# 362              edieraristi333@gmail.com    24874034      CC  3103515917
# 363                                  None  1063281099      CC  3223593555
#
#      ... validacion_datos campos_validados ocupacion estado_civil estrato  \
# 0    ...             None             None      None         None    None
# 1    ...             None             None      None         None    None
# 2    ...             None             None      None         None    None
# 3    ...             None             None      None         None    None
# 4    ...             None             None      None         None    None
# ..   ...              ...              ...       ...          ...     ...
# 359  ...             None             None      None         None    None
# 360  ...             None             None      None         None    None
# 361  ...             None             None      None         None    None
# 362  ...             None             None      None         None    None
# 363  ...             None             None      None         None    None
#
#     cantidad_hijos indicativo_celular nombre_corto tipo_dispositivo  \
# 0             None                +57         None       Smartphone
# 1             None                +57         None       Smartphone
# 2             None               None         None       Smartphone
# 3             None               None         None       Smartphone
# 4             None                +57         None       Smartphone
# ..             ...                ...          ...              ...
# 359           None               None         None       Smartphone
# 360           None               None         None       Smartphone
# 361           None                +57         None       Smartphone
# 362           None                +57         None       Smartphone
# 363           None                +57         None       Smartphone
#
#     sistema_operativo
# 0           AndroidOS
# 1             Android
# 2             Android
# 3           AndroidOS
# 4                 iOS
# ..                ...
# 359         AndroidOS
# 360         AndroidOS
# 361         AndroidOS
# 362         AndroidOS
# 363         AndroidOS
#
# [364 rows x 34 columns]

# %%
datos_api.to_excel("crudov5.xlsx")

# %%
datos_api = datos_api.drop(datos_api[(datos_api['documento']=='')].index)

# %%
datos_api
# Out:
#          lugar_cod acepto_politicas                                    nombre  \
# 0    41977-ZIFV774       2021-10-08  CORREG ALTO GUARAMITO_SAN JOSE DE CUCUTA
# 1    32214-ZZZY779       2021-10-08                           RODANIA_SAHAGUN
# 2    32583-ZGYO468       2021-10-08                   VDA CARRIZOLA_TIERRALTA
# 3    32559-ZIFV685       2021-10-08               VDA. BUENOS AIRES_TIERRALTA
# 4    41977-ZIFV774       2021-10-08  CORREG ALTO GUARAMITO_SAN JOSE DE CUCUTA
# ..             ...              ...                                       ...
# 359  32602-KPWM545       2021-10-08                   AGUILA BATATA_TIERRALTA
# 360  48528-ZZZY630       2021-10-08                       VDA EL NOGAL_FRESNO
# 361  70391-VZVF857       2021-10-08  ETCR- AGUA BONITA_SAN VICENTE DEL CAGUAN
# 362  26073-ZGYO917       2021-10-08       CORREGIMIENTO DE SAMARIA_FILADELFIA
# 363  32065-ZZZY836       2021-10-08       CORREG TORNO ROJO_PUERTO LIBERTADOR
#
#             id_usuario nombre_completo            apellidos  \
# 0    90-09-17-B7-8D-5E   Ana valentina      Trujillo Patiño
# 1    94-7B-E7-A0-1B-CE  José Alejandro        Ayazo vergara
# 2    12-16-AC-C0-F2-3F       Eva María       Carvajal Muñoz
# 3    20-32-6C-0B-D4-06    Edith Esther        Ramos Vergara
# 4    06-7D-99-CB-1D-0C           Marvi          Barón Durán
# ..                 ...             ...                  ...
# 359  C6-33-7C-20-7C-6E           Ismer       Garces achuriz
# 360  64-09-AC-D3-3D-3E   Victor Manuel         Muñoz Arango
# 361  44-59-E3-D7-3C-D2          Edison              Rumique
# 362  02-62-D2-58-C6-B3    Ediergustavo  Aristizabal aguirre
# 363  E6-8A-72-7C-ED-80      Luis mario               Arroyo
#
#                                    correo   documento tipodoc     celular  \
# 0    anavalentinatrujillopatino@gmail.com   309388803      TI  3507402574
# 1                                    None  1019036597      TI  3122374663
# 2                                    None  1062434850      TI        None
# 3                                    None  1073985918      CC        None
# 4                   marvi201445@gmail.com  1090395621      CC  3142482367
# ..                                    ...         ...     ...         ...
# 359                                  None  1073974858      CC        None
# 360                                  None  3116498688      TI        None
# 361                                  None    17659126      CC  3212152801
# 362              edieraristi333@gmail.com    24874034      CC  3103515917
# 363                                  None  1063281099      CC  3223593555
#
#      ... validacion_datos campos_validados ocupacion estado_civil estrato  \
# 0    ...             None             None      None         None    None
# 1    ...             None             None      None         None    None
# 2    ...             None             None      None         None    None
# 3    ...             None             None      None         None    None
# 4    ...             None             None      None         None    None
# ..   ...              ...              ...       ...          ...     ...
# 359  ...             None             None      None         None    None
# 360  ...             None             None      None         None    None
# 361  ...             None             None      None         None    None
# 362  ...             None             None      None         None    None
# 363  ...             None             None      None         None    None
#
#     cantidad_hijos indicativo_celular nombre_corto tipo_dispositivo  \
# 0             None                +57         None       Smartphone
# 1             None                +57         None       Smartphone
# 2             None               None         None       Smartphone
# 3             None               None         None       Smartphone
# 4             None                +57         None       Smartphone
# ..             ...                ...          ...              ...
# 359           None               None         None       Smartphone
# 360           None               None         None       Smartphone
# 361           None                +57         None       Smartphone
# 362           None                +57         None       Smartphone
# 363           None                +57         None       Smartphone
#
#     sistema_operativo
# 0           AndroidOS
# 1             Android
# 2             Android
# 3           AndroidOS
# 4                 iOS
# ..                ...
# 359         AndroidOS
# 360         AndroidOS
# 361         AndroidOS
# 362         AndroidOS
# 363         AndroidOS
#
# [364 rows x 34 columns]

# %%
#datos_api.to_excel("crudov5.xlsx") si se borran por falta de documento se imprime el excel para validar

# %%
datos_api['nombre'] = datos_api['nombre'].str.replace('"','')
datos_api['creado'] = datos_api['creado'].str.replace('"','')
datos_api['actualizado'] = datos_api['actualizado'].str.replace('"','')
datos_api['eliminado'] = datos_api['eliminado'].str.replace('"','')

# %% [markdown]
# ### Ajustando formato de fechas

# %%
try:
    datos_api['creado'] = datos_api["creado"].str.split(".", n = 1, expand = True)[0]
    datos_api['actualizado'] = datos_api["actualizado"].str.split(".", n = 1, expand = True)[0]
    datos_api['eliminado'] = datos_api["eliminado"].str.split(".", n = 1, expand = True)[0]
except:
    pass

# %%
datos_api.to_excel("antes_de_datosqueestan.xlsx")

# %% [markdown]
# ### Descartando datos de la API que ya están en el indice

# %%
datos_api = datos_api.drop(datos_api[(datos_api['creado']<= fecha_max)].index)

# %%
datos_api
# Out:
#          lugar_cod acepto_politicas                                    nombre  \
# 333  48590-ZGYO577       2021-10-08            VDA SERREZUELA PRIMAVERA_GUAMO
# 334  31076-ZZZY775       2021-10-08                         GUASIMAL_MONTERIA
# 335  31636-ZZZY230       2021-10-08          CORREGIMIENTO LOS CEDROS_COTORRA
# 336  74271-ZGYO207       2021-10-08                        LA IBERIA_RIOSUCIO
# 337  42896-ZGYO398       2021-10-08    CORREG LA VEGA DE SAN ANTONIO_LA PLAYA
# 338  13364-ZZZY480       2021-10-08                    SAN SEBASTIAN_CURUMANI
# 339  73844-ZZZY648       2021-10-08          RANCHERIA CARACAS RUYELA_MANAURE
# 340  20668-ZGYO166       2021-10-08               SANTA FE DEL TUNTUN_NECOCLI
# 341  11107-ZGYO062       2021-10-08                 CALLE 15  12 - 20_BARANOA
# 342  48163-KPWM055       2021-10-08                      EL ESCOBAL_CHAPARRAL
# 343  26120-VZVF273       2021-10-08                        LLANADAS_LA MERCED
# 344  26870-ZZZY005       2021-10-08                       PARTIDAS_VILLAMARIA
# 345  47271-ZZZY645       2021-10-08                        SAN ROQUE_MAJAGUAL
# 346  48163-KPWM055       2021-10-08                      EL ESCOBAL_CHAPARRAL
# 347  36136-ZIFV634       2021-10-08                      VDA LLANITOS_ACEVEDO
# 348  41960-ZGYO217       2021-10-08           SAN FAUSTINO_SAN JOSE DE CUCUTA
# 349  47065-VZVF399       2021-10-08                       POLICARPA_SINCELEJO
# 350  48660-ZGYO568       2021-10-08                 VDA DOSQUEBRADAS_ICONONZO
# 351  32267-ZZZY723       2021-10-08      LOS CARRETOS_SAN ANDRES DE SOTAVENTO
# 352  74271-ZGYO207       2021-10-08                        LA IBERIA_RIOSUCIO
# 353  32370-ZZZY210       2021-10-08             JUNIN_SAN BERNARDO DEL VIENTO
# 354  45589-ZZZY572       2021-10-08                    VEREDA PALOGORDO_GIRON
# 355  21289-ZGYO379       2021-10-08             ZAPINDONGA_SAN PEDRO DE URABA
# 356  47513-ZZZY560       2021-10-08              SABANETA_SAN JUAN DE BETULIA
# 357  74382-ZGYO172       2021-10-08                          EL TIGRE_NECOCLI
# 358  26802-ZIFV833       2021-10-08                 VEREDA HOJAS ANCHAS_SUPIA
# 359  32602-KPWM545       2021-10-08                   AGUILA BATATA_TIERRALTA
# 360  48528-ZZZY630       2021-10-08                       VDA EL NOGAL_FRESNO
# 361  70391-VZVF857       2021-10-08  ETCR- AGUA BONITA_SAN VICENTE DEL CAGUAN
# 362  26073-ZGYO917       2021-10-08       CORREGIMIENTO DE SAMARIA_FILADELFIA
# 363  32065-ZZZY836       2021-10-08       CORREG TORNO ROJO_PUERTO LIBERTADOR
#
#             id_usuario  nombre_completo            apellidos  \
# 333  24-FD-52-EE-01-43             luis               guzman
# 334  B2-19-38-4C-32-10      Levis Sofía       Ramos galarcio
# 335  1C-BF-C0-4F-31-CD            NEDYS                PETRO
# 336  74-15-75-89-DC-BC           Jhojan             Bladimir
# 337  0C-70-4A-0E-8A-63          Rubiela      Balaguera Pérez
# 338  60-1D-91-FE-B8-82       Diego Garg               Gracia
# 339  DA-CC-D9-A2-4A-03            Simón             Pushaina
# 340  7C-1C-68-97-D9-B8           Yostin               Racero
# 341  00-87-01-96-60-8D          Rosaura             Valencia
# 342  AA-2F-E1-A0-BC-AB          Adriana            Hernández
# 343  F4-71-90-B4-05-34           Eliana              Morales
# 344  F4-30-8B-45-17-C4             Saea                Velez
# 345  C2-18-49-F8-24-AE            Yivis               Vilrot
# 346  36-80-A9-55-EB-2A            Jaime               Aldana
# 347  D4-E6-B7-ED-F1-8D           Sarita                Rojas
# 348  78-62-56-A7-0B-8A             Jose               Chacon
# 349  00-1E-55-3A-24-A6           Julian                Perez
# 350  40-23-43-A6-50-77           amparo              herrera
# 351  F8-CF-C5-5E-B2-23            Yerli              Estrada
# 352  06-C4-42-9E-3F-1D           Felipe              Tapasco
# 353  2E-64-F5-F1-8B-F7            Johan                 None
# 354  6C-B7-49-FB-38-80           Gladys               Ortega
# 355  30-4B-07-54-A8-75            Elvia                 None
# 356  FC-A6-21-87-BF-77            Luisa               Ortega
# 357  7C-67-A2-3E-33-4D  sandra patricia     gonzalez rengifo
# 358  90-17-C8-23-66-76             Nora               Porras
# 359  C6-33-7C-20-7C-6E            Ismer       Garces achuriz
# 360  64-09-AC-D3-3D-3E    Victor Manuel         Muñoz Arango
# 361  44-59-E3-D7-3C-D2           Edison              Rumique
# 362  02-62-D2-58-C6-B3     Ediergustavo  Aristizabal aguirre
# 363  E6-8A-72-7C-ED-80       Luis mario               Arroyo
#
#                            correo    documento tipodoc     celular  ...  \
# 333          lued.guro@hotmal.com     93084895      CC  3204336027  ...
# 334  sofiaramos08112019@gmail.com   1067875798      TI  3105826685  ...
# 335                          None     30656075      CC        None  ...
# 336                          None   1059695084      CC  3187993982  ...
# 337           rubyperez@gmaik.com   1090440666      CC  3134594623  ...
# 338                          None   1064724740      CC  3207404037  ...
# 339                          None     15206121      CC  3147035388  ...
# 340                          None   1039087305      TI        None  ...
# 341                          None   1048204423      TI        None  ...
# 342       luzdevida0709@gmail.com     38144298      CC  3142780456  ...
# 343    jazmineliana2005@gmail.com   1055478337      TI  3175960037  ...
# 344                          None   1029788021      TI  3228186018  ...
# 345         yivisvm22@hotmail.com   1104378010      CC  3017209953  ...
# 346            jaeralmam@yahoo.es      5935334      CC  3208719897  ...
# 347    saraalejandra123@gmail.com   1077865815      TI  3158010904  ...
# 348                          None     27422992      CC        None  ...
# 349                          None     92638325      CC        None  ...
# 350          amparo2301@hotma.com     28786826      CC  3112398599  ...
# 351                          None   1104256885      TI        None  ...
# 352                          None  10088827497      TI  3008892243  ...
# 353                          None   3128640354      CC        None  ...
# 354                          None   1102354875      CC  3123842515  ...
# 355                          None     32252064      CC        None  ...
# 356                          None   1103949252      TI        None  ...
# 357          sankesanje@gmail.com   1039099450      CC  3137731009  ...
# 358                          None     25201557      CC  3117778236  ...
# 359                          None   1073974858      CC        None  ...
# 360                          None   3116498688      TI        None  ...
# 361                          None     17659126      CC  3212152801  ...
# 362      edieraristi333@gmail.com     24874034      CC  3103515917  ...
# 363                          None   1063281099      CC  3223593555  ...
#
#     validacion_datos campos_validados ocupacion estado_civil estrato  \
# 333             None             None      None         None    None
# 334             None             None      None         None    None
# 335             None             None      None         None    None
# 336             None             None      None         None    None
# 337             None             None      None         None    None
# 338             None             None      None         None    None
# 339             None             None      None         None    None
# 340             None             None      None         None    None
# 341             None             None      None         None    None
# 342             None             None      None         None    None
# 343             None             None      None         None    None
# 344             None             None      None         None    None
# 345             None             None      None         None    None
# 346             None             None      None         None    None
# 347             None             None      None         None    None
# 348             None             None      None         None    None
# 349             None             None      None         None    None
# 350             None             None      None         None    None
# 351             None             None      None         None    None
# 352             None             None      None         None    None
# 353             None             None      None         None    None
# 354             None             None      None         None    None
# 355             None             None      None         None    None
# 356             None             None      None         None    None
# 357             None             None      None         None    None
# 358             None             None      None         None    None
# 359             None             None      None         None    None
# 360             None             None      None         None    None
# 361             None             None      None         None    None
# 362             None             None      None         None    None
# 363             None             None      None         None    None
#
#     cantidad_hijos indicativo_celular nombre_corto tipo_dispositivo  \
# 333           None                +57         None               PC
# 334           None                +57         None       Smartphone
# 335           None               None         None               PC
# 336           None                +57         None       Smartphone
# 337           None                +57         None       Smartphone
# 338           None                +57         None       Smartphone
# 339           None                +57         None       Smartphone
# 340           None               None         None       Smartphone
# 341           None               None         None       Smartphone
# 342           None                +57         None       Smartphone
# 343           None                +57         None       Smartphone
# 344           None                +57         None       Smartphone
# 345           None                +57         None       Smartphone
# 346           None                +57         None       Smartphone
# 347           None                +57         None       Smartphone
# 348           None               None         None       Smartphone
# 349           None               None         None       Smartphone
# 350           None                +57         None               PC
# 351           None               None         None       Smartphone
# 352           None                +57         None       Smartphone
# 353           None               None         None       Smartphone
# 354           None                +57         None       Smartphone
# 355           None               None         None       Smartphone
# 356           None               None         None       Smartphone
# 357           None                +57         None               PC
# 358           None                +57         None       Smartphone
# 359           None               None         None       Smartphone
# 360           None               None         None       Smartphone
# 361           None                +57         None       Smartphone
# 362           None                +57         None       Smartphone
# 363           None                +57         None       Smartphone
#
#     sistema_operativo
# 333           Windows
# 334         AndroidOS
# 335           Windows
# 336           Android
# 337         AndroidOS
# 338         AndroidOS
# 339         AndroidOS
# 340         AndroidOS
# 341         AndroidOS
# 342         AndroidOS
# 343           Android
# 344         AndroidOS
# 345         AndroidOS
# 346         AndroidOS
# 347         AndroidOS
# 348           Android
# 349         AndroidOS
# 350           Windows
# 351           Android
# 352           Android
# 353         AndroidOS
# 354         AndroidOS
# 355         AndroidOS
# 356         AndroidOS
# 357           Windows
# 358         AndroidOS
# 359         AndroidOS
# 360         AndroidOS
# 361         AndroidOS
# 362         AndroidOS
# 363         AndroidOS
#
# [31 rows x 34 columns]

# %%
datos_api.to_excel("qeyaestan_datos_usuarios.xlsx")

# %%
indice = 'ohmyfi-datopruebaingesta1'

# %%
use_these_keys = ['lugar_cod','acepto_politicas','nombre','id_usuario','nombre_completo','apellidos'
                              ,'correo','documento','tipodoc','celular','telefono','direccion','ciudad'
                              ,'pais','creado','actualizado','eliminado','genero','fecha_nacimiento'
                              ,'nivel_educativo','rango_edad','alias','fecha','id_usuario_datos'
                              ,'validacion_datos','campos_validados','ocupacion','estado_civil','estrato'
                              ,'cantidad_hijos','indicativo_celular','nombre_corto'
                              ,'tipo_dispositivo','sistema_operativo','@timestamp']
def filterKeys(document):
    return {key: document[key] for key in use_these_keys }

timestamp = datetime.now()
datos_api['@timestamp'] = timestamp.isoformat()
def doc_generator(df):
    df_iter = df.iterrows()
    for index, document in df_iter:
        yield {
                "_index": indice, 
                "_id": f"{document['tipodoc']+document['documento']}",
                "_source": filterKeys(document),
            }
salida = helpers.bulk(es, doc_generator(datos_api))
print("Fecha: ", now, "- Documentos nuevos: ", salida[0])
# Out:
# Fecha:  2021-10-08 09:51:58.468609 - Documentos nuevos:  31

# %% [markdown]
# # Opcion actualizado

# %%
#url = 'https://www.ohmyfi.com/ApiOMF?/datosusuario/=&apiKey=okMOpLAkiYpafQKXhXirwUys&opcion=actualizado&inicio='+ fecha_url
#url = parametros.url_ohmyfi + '?/datosusuario' + '/=&apiKey=' + parametros.ohmyfi_api_key + '&opcion=actualizado&inicio=' + fecha_url
url = parametros.url_ohmyfi + '?/datosusuario' + '/=&apiKey=' + parametros.ohmyfi_api_key + '&opcion=actualizado' + '&inicio=' + str(h_inicio) + '&final=' + str(h_fin) 
r = requests.get(url)
r = requests.get(url)
if r.status_code == 200:
    res = json.loads(r.text)
    datos_api_act  = pd.DataFrame(res,columns=['lugar_cod','acepto_politicas','nombre','id_usuario','nombre_completo','apellidos'
                              ,'correo','documento','tipodoc','celular','telefono','direccion','ciudad'
                              ,'pais','creado','actualizado','eliminado','genero','fecha_nacimiento'
                              ,'nivel_educativo','rango_edad','alias','fecha','id_usuario_datos'
                              ,'validacion_datos','campos_validados','ocupacion','estado_civil','estrato'
                              ,'cantidad_hijos','indicativo_celular','nombre_corto'
                              ,'tipo_dispositivo','sistema_operativo'])
else:
    exit()

# %%
url
# Out:
# 'https://www.ohmyfi.com/ApiOMF?/datosusuario/=&apiKey=okMOpLAkiYpafQKXhXirwUys&opcion=actualizado&inicio=2021/10/08 07:51&final=2021/10/08 09:51'

# %%
datos_api_act
# Out:
#          lugar_cod acepto_politicas                         nombre  \
# 0    36899-ZZZY215       2021-06-20         VDA ALTO CALOTO_PAICOL
# 1    21289-ZGYO379       2021-07-12  ZAPINDONGA_SAN PEDRO DE URABA
# 2    49396-ZZZY516       2021-08-07     VDA SANTA ROSA_SAN ANTONIO
# 3    19445-ZZZY043       2021-07-21   VDA SANTO CRISTO_CANASGORDAS
# 4    14419-ZGYO499       2021-07-23   VEREDA VILLA COLOMBIA_OVEJAS
# ..             ...              ...                            ...
# 543  21002-ZGYO072       2021-10-08           LOS PENOLES_RIONEGRO
# 544  47056-ZZZY118       2021-05-05         LAS MAJAGUAS_SINCELEJO
# 545  48660-ZGYO568       2021-05-22      VDA DOSQUEBRADAS_ICONONZO
# 546  31957-ZGYO750       2021-06-04       SANTA CLARA_PUEBLO NUEVO
# 547  47426-ZZZY514       2021-08-14           MATA DE CANA_SAMPUES
#
#             id_usuario nombre_completo          apellidos  \
# 0    C4-06-83-AF-AA-18           Arley              López
# 1    7C-2E-DD-85-76-BE          Julian    Ramires gaviria
# 2    88-40-3B-B7-F2-91        Cristian            Vanegas
# 3    28-E3-47-B3-91-1A           elvia             urrego
# 4    34-2E-B6-64-F7-7A            Juan          Benavides
# ..                 ...             ...                ...
# 543  D8-0B-9A-92-4F-50          Andrez               None
# 544  00-B8-B6-AC-36-EA     Leivis José     Campo canchila
# 545  FC-42-03-CA-88-E6           Johan          Alejandro
# 546  88-46-04-24-BD-48            Ivan  Contreras Naranjo
# 547  60-1D-91-FA-FC-AF           Pedro              Gomez
#
#                            correo   documento tipodoc     celular  ...  \
# 0                            None    12280734      CC        None  ...
# 1            anagaviria@gmail.com    32273990      TI  3127869718  ...
# 2                            None  1005851515      CC  3105578622  ...
# 3              elviau34@gmail.com    32275272      CC  3146328769  ...
# 4                            None     9310259      CC  3205190719  ...
# ..                            ...         ...     ...         ...  ...
# 543  rodriguezangie2701@gmail.com  1040870571      TI  3205115396  ...
# 544      leiviscampo764@gmail.com  1102805303      CC  3202909943  ...
# 545                          None  1106363446      TI  3204448221  ...
# 546            crath269@gmail.com  1003362134      CC  3106566862  ...
# 547        jairo.jc2007@gmail.com    15783452      CC  3014834752  ...
#
#     validacion_datos campos_validados ocupacion estado_civil estrato  \
# 0               None             None      None         None    None
# 1               None             None      None         None    None
# 2               None             None      None         None    None
# 3               None             None      None         None    None
# 4               None             None      None         None    None
# ..               ...              ...       ...          ...     ...
# 543             None             None      None         None    None
# 544             None             None      None         None    None
# 545             None             None      None         None    None
# 546             None             None      None         None    None
# 547             None             None      None         None    None
#
#     cantidad_hijos indicativo_celular nombre_corto tipo_dispositivo  \
# 0             None               None         None       Smartphone
# 1             None                +57         None       Smartphone
# 2             None                +57         None       Smartphone
# 3             None                +57         None               PC
# 4             None                +57         None       Smartphone
# ..             ...                ...          ...              ...
# 543           None                +57         None       Smartphone
# 544           None                +57         None       Smartphone
# 545           None                +57         None       Smartphone
# 546           None                +57         None       Smartphone
# 547           None                +57         None       Smartphone
#
#     sistema_operativo
# 0             Android
# 1             Android
# 2             Android
# 3             Windows
# 4             Android
# ..                ...
# 543           Android
# 544           Android
# 545           Android
# 546           Android
# 547           Android
#
# [548 rows x 34 columns]

# %%
datos_api_act.to_excel("actu81021_datos_usuarios.xlsx")

# %%
datos_api_act.fillna('', inplace=True)
datos_api_act = datos_api_act.drop(datos_api_act[(datos_api_act['documento']=='')].index)
datos_api_act['nombre'] = datos_api_act['nombre'].str.replace('"','')
datos_api_act['creado'] = datos_api_act['creado'].str.replace('"','')
datos_api_act['actualizado'] = datos_api_act['actualizado'].str.replace('"','')
datos_api_act['eliminado'] = datos_api_act['eliminado'].str.replace('"','')

# %%
datos_api_act
# Out:
#          lugar_cod acepto_politicas                         nombre  \
# 0    36899-ZZZY215       2021-06-20         VDA ALTO CALOTO_PAICOL
# 1    21289-ZGYO379       2021-07-12  ZAPINDONGA_SAN PEDRO DE URABA
# 2    49396-ZZZY516       2021-08-07     VDA SANTA ROSA_SAN ANTONIO
# 3    19445-ZZZY043       2021-07-21   VDA SANTO CRISTO_CANASGORDAS
# 4    14419-ZGYO499       2021-07-23   VEREDA VILLA COLOMBIA_OVEJAS
# ..             ...              ...                            ...
# 543  21002-ZGYO072       2021-10-08           LOS PENOLES_RIONEGRO
# 544  47056-ZZZY118       2021-05-05         LAS MAJAGUAS_SINCELEJO
# 545  48660-ZGYO568       2021-05-22      VDA DOSQUEBRADAS_ICONONZO
# 546  31957-ZGYO750       2021-06-04       SANTA CLARA_PUEBLO NUEVO
# 547  47426-ZZZY514       2021-08-14           MATA DE CANA_SAMPUES
#
#             id_usuario nombre_completo          apellidos  \
# 0    C4-06-83-AF-AA-18           Arley              López
# 1    7C-2E-DD-85-76-BE          Julian    Ramires gaviria
# 2    88-40-3B-B7-F2-91        Cristian            Vanegas
# 3    28-E3-47-B3-91-1A           elvia             urrego
# 4    34-2E-B6-64-F7-7A            Juan          Benavides
# ..                 ...             ...                ...
# 543  D8-0B-9A-92-4F-50          Andrez
# 544  00-B8-B6-AC-36-EA     Leivis José     Campo canchila
# 545  FC-42-03-CA-88-E6           Johan          Alejandro
# 546  88-46-04-24-BD-48            Ivan  Contreras Naranjo
# 547  60-1D-91-FA-FC-AF           Pedro              Gomez
#
#                            correo   documento tipodoc     celular  ...  \
# 0                                    12280734      CC              ...
# 1            anagaviria@gmail.com    32273990      TI  3127869718  ...
# 2                                  1005851515      CC  3105578622  ...
# 3              elviau34@gmail.com    32275272      CC  3146328769  ...
# 4                                     9310259      CC  3205190719  ...
# ..                            ...         ...     ...         ...  ...
# 543  rodriguezangie2701@gmail.com  1040870571      TI  3205115396  ...
# 544      leiviscampo764@gmail.com  1102805303      CC  3202909943  ...
# 545                                1106363446      TI  3204448221  ...
# 546            crath269@gmail.com  1003362134      CC  3106566862  ...
# 547        jairo.jc2007@gmail.com    15783452      CC  3014834752  ...
#
#     validacion_datos campos_validados ocupacion estado_civil estrato  \
# 0
# 1
# 2
# 3
# 4
# ..               ...              ...       ...          ...     ...
# 543
# 544
# 545
# 546
# 547
#
#     cantidad_hijos indicativo_celular nombre_corto tipo_dispositivo  \
# 0                                                        Smartphone
# 1                                 +57                    Smartphone
# 2                                 +57                    Smartphone
# 3                                 +57                            PC
# 4                                 +57                    Smartphone
# ..             ...                ...          ...              ...
# 543                               +57                    Smartphone
# 544                               +57                    Smartphone
# 545                               +57                    Smartphone
# 546                               +57                    Smartphone
# 547                               +57                    Smartphone
#
#     sistema_operativo
# 0             Android
# 1             Android
# 2             Android
# 3             Windows
# 4             Android
# ..                ...
# 543           Android
# 544           Android
# 545           Android
# 546           Android
# 547           Android
#
# [547 rows x 34 columns]

# %% [markdown]
# ### Ajustando formato de fechas

# %%
try:
    datos_api_act['creado'] = datos_api_act["creado"].str.split(".", n = 1, expand = True)[0]
    datos_api_act['actualizado'] = datos_api_act["actualizado"].str.split(".", n = 1, expand = True)[0]
    datos_api_act['eliminado'] = datos_api_act["eliminado"].str.split(".", n = 1, expand = True)[0]
except:
    pass

# %% [markdown]
# ### Descartando datos de la API que ya están en el indice

# %%
datos_api_act = datos_api_act.drop(datos_api_act[(datos_api_act['actualizado']<= fecha_max)].index)

# %%
datos_api_act
# Out:
#          lugar_cod acepto_politicas                                    nombre  \
# 0    36899-ZZZY215       2021-06-20                    VDA ALTO CALOTO_PAICOL
# 381  32359-KPWM054       2021-10-08        PASO NUEVO_SAN BERNARDO DEL VIENTO
# 435  73749-VZVF122       2021-10-08               RANCHERIA JONJONCITO_URIBIA
# 454  36872-KPWM903       2021-10-08                      VDA EL ROBLE_OPORAPA
# 463  42110-KPWM963       2021-10-08               VDA ALTO CHICAGUA_ARBOLEDAS
# 475  36530-ZGYO552       2021-10-08                          SILVANIA_GIGANTE
# 486  20582-ZIFV039       2021-10-08                 CORREG. BEJUQUILLO_MUTATA
# 489  31837-ZGYO286       2021-10-08                         RIO CEDRO_MONITOS
# 490  48590-ZGYO577       2021-10-08            VDA SERREZUELA PRIMAVERA_GUAMO
# 491  31076-ZZZY775       2021-10-08                         GUASIMAL_MONTERIA
# 492  21717-VZVF125       2021-07-23                          JERUSALEN_SONSON
# 493  31636-ZZZY230       2021-10-08          CORREGIMIENTO LOS CEDROS_COTORRA
# 494  42896-ZGYO398       2021-10-08    CORREG LA VEGA DE SAN ANTONIO_LA PLAYA
# 495  13364-ZZZY480       2021-10-08                    SAN SEBASTIAN_CURUMANI
# 496  73844-ZZZY648       2021-10-08          RANCHERIA CARACAS RUYELA_MANAURE
# 497  20668-ZGYO166       2021-10-08               SANTA FE DEL TUNTUN_NECOCLI
# 498  11107-ZGYO062       2021-10-08                 CALLE 15  12 - 20_BARANOA
# 499  48163-KPWM055       2021-10-08                      EL ESCOBAL_CHAPARRAL
# 500  26120-VZVF273       2021-10-08                        LLANADAS_LA MERCED
# 501  26870-ZZZY005       2021-10-08                       PARTIDAS_VILLAMARIA
# 502  47271-ZZZY645       2021-10-08                        SAN ROQUE_MAJAGUAL
# 503  48163-KPWM055       2021-10-08                      EL ESCOBAL_CHAPARRAL
# 504  36136-ZIFV634       2021-10-08                      VDA LLANITOS_ACEVEDO
# 505  41960-ZGYO217       2021-10-08           SAN FAUSTINO_SAN JOSE DE CUCUTA
# 506  47065-VZVF399       2021-10-08                       POLICARPA_SINCELEJO
# 507  48660-ZGYO568       2021-10-08                 VDA DOSQUEBRADAS_ICONONZO
# 508  32267-ZZZY723       2021-10-08      LOS CARRETOS_SAN ANDRES DE SOTAVENTO
# 509  70563-ZGYO637       2021-09-23            CENTRO DE SALUD ZAPATA_NECOCLI
# 510  74271-ZGYO207       2021-10-08                        LA IBERIA_RIOSUCIO
# 511  32370-ZZZY210       2021-10-08             JUNIN_SAN BERNARDO DEL VIENTO
# 512  45589-ZZZY572       2021-10-08                    VEREDA PALOGORDO_GIRON
# 513  20217-ZGYO996       2021-06-24                     VDA CHAPARRAL, GUARNE
# 514  31442-ZGYO771       2021-08-17                        TIERRA GRATA_CHINU
# 515  21289-ZGYO379       2021-10-08             ZAPINDONGA_SAN PEDRO DE URABA
# 516  31181-ZGYO473       2021-05-31                     COSTA DE ORO_MONTERIA
# 517  47513-ZZZY560       2021-10-08              SABANETA_SAN JUAN DE BETULIA
# 518  74382-ZGYO172       2021-10-08                          EL TIGRE_NECOCLI
# 519  26122-VZVF880       2021-07-29        CENTRO POBLADO LA FELISA_LA MERCED
# 520  26802-ZIFV833       2021-10-08                 VEREDA HOJAS ANCHAS_SUPIA
# 521  48528-ZZZY630       2021-10-08                       VDA EL NOGAL_FRESNO
# 522  32065-ZZZY836       2021-10-08       CORREG TORNO ROJO_PUERTO LIBERTADOR
# 531  13692-ZIFV921       2021-10-06                COMUNIDAD EL CARMEN_TUCHIN
# 542  13695-ZGYO347       2021-04-19  BARRIO EL PANTEON CALLE MANGA_SAN ANTERO
# 543  21002-ZGYO072       2021-10-08                      LOS PENOLES_RIONEGRO
#
#             id_usuario  nombre_completo          apellidos  \
# 0    C4-06-83-AF-AA-18            Arley              López
# 381  2C-D2-6B-52-A0-26      jose daniel     fuentes ospino
# 435  18-D6-1C-92-6F-36         Vidalina           González
# 454  D8-5B-2A-79-0B-E3          Orlando          Rodriguez
# 463  4A-07-90-25-E4-5D            Leydi            Laguado
# 475  D2-CE-4F-55-61-16             Yury      Rojas ordoñez
# 486  AC-E3-42-0F-51-4D          Claudia              Marin
# 489  DC-BF-E9-DB-94-DE            Wendy             Valdez
# 490  24-FD-52-EE-01-43             luis             guzman
# 491  B2-19-38-4C-32-10      Levis Sofía     Ramos galarcio
# 492  C0-DC-DA-5B-5B-C0           Astrid            Salazar
# 493  1C-BF-C0-4F-31-CD            NEDYS              PETRO
# 494  0C-70-4A-0E-8A-63          Rubiela    Balaguera Pérez
# 495  60-1D-91-FE-B8-82       Diego Garg             Gracia
# 496  DA-CC-D9-A2-4A-03            Simón           Pushaina
# 497  7C-1C-68-97-D9-B8           Yostin             Racero
# 498  00-87-01-96-60-8D          Rosaura           Valencia
# 499  AA-2F-E1-A0-BC-AB          Adriana          Hernández
# 500  F4-71-90-B4-05-34           Eliana            Morales
# 501  F4-30-8B-45-17-C4             Saea              Velez
# 502  C2-18-49-F8-24-AE            Yivis             Vilrot
# 503  36-80-A9-55-EB-2A            Jaime             Aldana
# 504  D4-E6-B7-ED-F1-8D           Sarita              Rojas
# 505  78-62-56-A7-0B-8A             Jose             Chacon
# 506  00-1E-55-3A-24-A6           Julian              Perez
# 507  40-23-43-A6-50-77           amparo            herrera
# 508  F8-CF-C5-5E-B2-23            Yerli            Estrada
# 509  82-C3-FB-BC-06-87         Verónica              Bravo
# 510  06-C4-42-9E-3F-1D           Felipe            Tapasco
# 511  2E-64-F5-F1-8B-F7            Johan
# 512  6C-B7-49-FB-38-80           Gladys             Ortega
# 513  D8-9B-3B-70-FB-F1            Leidy          Hernández
# 514  32-75-78-5D-3C-07       Ledisester  Manjarres Medrano
# 515  30-4B-07-54-A8-75            Elvia
# 516  10-3F-44-7D-3E-2E             Rosa             Segura
# 517  FC-A6-21-87-BF-77            Luisa             Ortega
# 518  7C-67-A2-3E-33-4D  sandra patricia   gonzalez rengifo
# 519  E4-AA-EA-95-F7-63         VERONICA             BERNAL
# 520  90-17-C8-23-66-76             Nora             Porras
# 521  64-09-AC-D3-3D-3E    Victor Manuel       Muñoz Arango
# 522  E6-8A-72-7C-ED-80       Luis mario             Arroyo
# 531  D0-FF-98-F0-F8-54          Antonio            Marquez
# 542  58-C5-CB-D8-E2-E5          Gabriel          Hernandez
# 543  D8-0B-9A-92-4F-50           Andrez
#
#                                  correo    documento tipodoc     celular  ...  \
# 0                                           12280734      CC              ...
# 381                                       1063737453      TI              ...
# 435      vidalinagonzalez8410@gmail.com     40849063      CC  3132600599  ...
# 454                                       1084897003      CC  3144236495  ...
# 463            leydilaguado02@gmail.com   1127584698      CC  3103918894  ...
# 475                                       1080184777      CC              ...
# 486                henaoyane0@gmail.com   1045517617      CC  3205741382  ...
# 489                                       1067160082      TI              ...
# 490                lued.guro@hotmal.com     93084895      CC  3204336027  ...
# 491        sofiaramos08112019@gmail.com   1067875798      TI  3105826685  ...
# 492  astridramirez2006octubre@gmail.com   1036221781      TI  3147686370  ...
# 493                                         30656075      CC              ...
# 494                 rubyperez@gmaik.com   1090440666      CC  3134594623  ...
# 495                                       1064724740      CC  3207404037  ...
# 496                                         15206121      CC  3147035388  ...
# 497                                       1039087305      TI              ...
# 498                                       1048204423      TI              ...
# 499             luzdevida0709@gmail.com     38144298      CC  3142780456  ...
# 500          jazmineliana2005@gmail.com   1055478337      TI  3175960037  ...
# 501                                       1029788021      TI  3228186018  ...
# 502               yivisvm22@hotmail.com   1104378010      CC  3017209953  ...
# 503                  jaeralmam@yahoo.es      5935334      CC  3208719897  ...
# 504          saraalejandra123@gmail.com   1077865815      TI  3158010904  ...
# 505                                         27422992      CC              ...
# 506                                         92638325      CC              ...
# 507                amparo2301@hotma.com     28786826      CC  3112398599  ...
# 508                                       1104256885      TI              ...
# 509                  verobavo@gmail.com   1039087509      CC  3128541911  ...
# 510                                      10088827497      TI  3008892243  ...
# 511                                       3128640354      CC              ...
# 512                                       1102354875      CC  3123842515  ...
# 513            Nuevaepsjohana@gmail.com    394577034      CC  3113535849  ...
# 514                                       1066173292      CC  3145938382  ...
# 515                                         32252064      CC              ...
# 516   seguraarrietarosaelvira@gmail.com   1073981813      CC  3113009944  ...
# 517                                       1103949252      TI              ...
# 518                sankesanje@gmail.com   1039099450      CC  3137731009  ...
# 519      veronika.bernal.28@hotmail.com   1053821927      CC  3114098869  ...
# 520                                         25201557      CC  3117778236  ...
# 521                                       3116498688      TI              ...
# 522                                       1063281099      CC  3223593555  ...
# 531                                       1007792541      CC  3146241827  ...
# 542                                       1073788708      CC  3016344207  ...
# 543        rodriguezangie2701@gmail.com   1040870571      TI  3205115396  ...
#
#     campos_validados ocupacion estado_civil estrato cantidad_hijos  \
# 0
# 381
# 435
# 454
# 463
# 475
# 486
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# 531
# 542
# 543
#
#     indicativo_celular nombre_corto tipo_dispositivo sistema_operativo  \
# 0                                         Smartphone           Android
# 381                                               PC           Windows
# 435                +57                    Smartphone         AndroidOS
# 454                +57                    Smartphone         AndroidOS
# 463                +57                    Smartphone         AndroidOS
# 475                                       Smartphone         AndroidOS
# 486                +57                    Smartphone         AndroidOS
# 489                                       Smartphone         AndroidOS
# 490                +57                            PC           Windows
# 491                +57                    Smartphone         AndroidOS
# 492                +57                    Smartphone           Android
# 493                                               PC           Windows
# 494                +57                    Smartphone         AndroidOS
# 495                +57                    Smartphone         AndroidOS
# 496                +57                    Smartphone         AndroidOS
# 497                                       Smartphone         AndroidOS
# 498                                       Smartphone         AndroidOS
# 499                +57                    Smartphone         AndroidOS
# 500                +57                    Smartphone           Android
# 501                +57                    Smartphone         AndroidOS
# 502                +57                    Smartphone         AndroidOS
# 503                +57                    Smartphone         AndroidOS
# 504                +57                    Smartphone         AndroidOS
# 505                                       Smartphone           Android
# 506                                       Smartphone         AndroidOS
# 507                +57                            PC           Windows
# 508                                       Smartphone           Android
# 509                +57                    Smartphone           Android
# 510                +57                    Smartphone           Android
# 511                                       Smartphone         AndroidOS
# 512                +57                    Smartphone         AndroidOS
# 513                +57                    Smartphone           Android
# 514                +57                    Smartphone           Android
# 515                                       Smartphone         AndroidOS
# 516                +57                    Smartphone           Android
# 517                                       Smartphone         AndroidOS
# 518                +57                            PC           Windows
# 519                +57                            PC           Windows
# 520                +57                    Smartphone         AndroidOS
# 521                                       Smartphone         AndroidOS
# 522                +57                    Smartphone         AndroidOS
# 531                +57                    Smartphone           Android
# 542                +57                    Smartphone           Android
# 543                +57                    Smartphone           Android
#
#                      @timestamp
# 0    2021-10-08T10:02:28.045194
# 381  2021-10-08T10:02:28.045194
# 435  2021-10-08T10:02:28.045194
# 454  2021-10-08T10:02:28.045194
# 463  2021-10-08T10:02:28.045194
# 475  2021-10-08T10:02:28.045194
# 486  2021-10-08T10:02:28.045194
# 489  2021-10-08T10:02:28.045194
# 490  2021-10-08T10:02:28.045194
# 491  2021-10-08T10:02:28.045194
# 492  2021-10-08T10:02:28.045194
# 493  2021-10-08T10:02:28.045194
# 494  2021-10-08T10:02:28.045194
# 495  2021-10-08T10:02:28.045194
# 496  2021-10-08T10:02:28.045194
# 497  2021-10-08T10:02:28.045194
# 498  2021-10-08T10:02:28.045194
# 499  2021-10-08T10:02:28.045194
# 500  2021-10-08T10:02:28.045194
# 501  2021-10-08T10:02:28.045194
# 502  2021-10-08T10:02:28.045194
# 503  2021-10-08T10:02:28.045194
# 504  2021-10-08T10:02:28.045194
# 505  2021-10-08T10:02:28.045194
# 506  2021-10-08T10:02:28.045194
# 507  2021-10-08T10:02:28.045194
# 508  2021-10-08T10:02:28.045194
# 509  2021-10-08T10:02:28.045194
# 510  2021-10-08T10:02:28.045194
# 511  2021-10-08T10:02:28.045194
# 512  2021-10-08T10:02:28.045194
# 513  2021-10-08T10:02:28.045194
# 514  2021-10-08T10:02:28.045194
# 515  2021-10-08T10:02:28.045194
# 516  2021-10-08T10:02:28.045194
# 517  2021-10-08T10:02:28.045194
# 518  2021-10-08T10:02:28.045194
# 519  2021-10-08T10:02:28.045194
# 520  2021-10-08T10:02:28.045194
# 521  2021-10-08T10:02:28.045194
# 522  2021-10-08T10:02:28.045194
# 531  2021-10-08T10:02:28.045194
# 542  2021-10-08T10:02:28.045194
# 543  2021-10-08T10:02:28.045194
#
# [44 rows x 35 columns]

# %%
datos_api_act.to_excel("actu3_datos_usuarios_cruce.xlsx")

# %% [markdown]
# ### Escribiendo actualizados al indice

# %%
timestamp = datetime.now()
datos_api_act['@timestamp'] = timestamp.isoformat()
salida = helpers.bulk(es, doc_generator(datos_api_act))
print("Fecha: ", now, "- Documentos actualizados: ", salida[0])
# Out:
# Fecha:  2021-10-08 09:51:58.468609 - Documentos actualizados:  44
