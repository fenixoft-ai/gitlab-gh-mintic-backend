# %% [markdown]
# ### ¿Qué genera este script?
#
# Para cada sitio y fecha, el total de usuarios registrados (usuarios.usuariosRegistrados)

# %%
from elasticsearch import Elasticsearch, helpers
from ssl import create_default_context
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import parametros
import re
import random
import time

# %% [markdown]
# ## Conectando a ElasticSearch

# %% [markdown]
# La ultima línea se utiliza para garantizar la ejecución de la consulta
# * timeout es el tiempo para cada ejecución
# * max_retries el número de intentos si la conexión falla
# * retry_on_timeout para activar los reitentos

# %%
context = create_default_context(cafile=parametros.cafile)
es = Elasticsearch(
    parametros.servidor,
    http_auth=(parametros.usuario_EC, parametros.password_EC),
    scheme="https",
    port=parametros.puerto,
    ssl_context=context,
    timeout=60, max_retries=3, retry_on_timeout=True
)

# %% [markdown]
# ### Calculando fechas para la ejecución

# %% [markdown]
# * Se calculan las fechas para asociar al nombre del indice
# * fecha_hoy es usada para concatenar al nombre del indice principal previa inserción

# %%
now = datetime.now()
fecha_hoy = str(now.strftime("%Y.%m.%d"))

# %% [markdown]
# ### Definiendo indice principal con fecha de hoy e indice de control

# %% [markdown]
# ### Función para generar JSON compatible con ElactiSearch

# %%
def filterKeys(document):
    return {key: document[key] for key in use_these_keys }

# %% [markdown]
# ### leyendo indice semilla-inventario

# %% [markdown]
# En el script que ingesta semilla, trae la información de los centros de conexión administrados. Para el indice principal se requiere:
#
# * site_id como llave del centro de conexión.
# * Datos geográficos (Departamento, municipio, centro poblado, sede, energía, latitud, longitud, COD_ISOid_Beneficiario).

# %%
total_docs = 10000
try:
    response = es.search(
        index= parametros.semilla_inventario_index,
        body={
               "_source": ['site_id','nombre_municipio', 'nombre_departamento', 'nombre_centro_pob', 'nombreSede' 
                           , 'energiadesc', 'latitud', 'longitud','COD_ISO','id_Beneficiario']
        },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["hits"]["hits"]
    fields = {}
    for num, doc in enumerate(elastic_docs):
        source_data = doc["_source"]
        for key, val in source_data.items():
            try:
                fields[key] = np.append(fields[key], val)
            except KeyError:
                fields[key] = np.array([val])

    datos_semilla = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ])) #pd.DataFrame(fields)
except:
    print("fecha:",now,"- Error en lectura de datos semilla")
    #exit()

# %% [markdown]
# * Se valida latitud y longitud. Luego se calcula campo location
# * Se renombran los campos de semilla

# %%
def get_location(x,y='lat'):
    patron = re.compile('^(\-?\d+(\.\d+)?),\s*(\-?\d+(\.\d+)?)$') #patrón que debe cumplir
    if (not patron.match(x) is None) and (str(x)!=''):
        return x.replace(',','.')
    else:
        #Código a ejecutar si las coordenadas no son válidas
        return '4.596389' if y=='lat' else '-74.074639'

# %%
datos_semilla['latitud'] = datos_semilla['latitud'].apply(lambda x:get_location(x,'lat'))
datos_semilla['longitud'] = datos_semilla['longitud'].apply(lambda x:get_location(x,'lon'))
datos_semilla['usuarios.location'] = datos_semilla['latitud'] + ',' + datos_semilla['longitud']
datos_semilla['usuarios.location']=datos_semilla['usuarios.location'].str.replace('a,a','')
datos_semilla.drop(columns=['latitud','longitud'],inplace=True)

datos_semilla = datos_semilla.rename(columns={'lugar_cod' : 'usuarios.centroDigitalUsuarios'
                                            , 'nombre_municipio': 'usuarios.nombreMunicipio'
                                            , 'nombre_departamento' : 'usuarios.nombreDepartamento'
                                            , 'nombre_centro_pob': 'usuarios.localidad'
                                            , 'nombreSede' : 'usuarios.nomCentroDigital'
                                            , 'energiadesc' : 'usuarios.sistemaEnergia'
                                            , 'COD_ISO' : 'usuarios.codISO'
                                            , 'id_Beneficiario' : 'usuarios.idBeneficiario'})
datos_semilla.fillna('', inplace=True)

# %% [markdown]
# ### Trae la ultima fecha para control de ejecución

# %% [markdown]
# Cuando en el rango de tiempo de la ejecución, no se insertan nuevos valores, las fecha maxima en indice mintic no aumenta, por tanto se usa esta fecha de control para garantizar que incremente el bucle de ejecución

# %%
total_docs = 1
try:
    response = es.search(
        index= indice_control,
        body={
               "_source": ['usuarios.fechaControl'],
              "query": {
                "bool": {
                  "filter": [
                  {
                    "exists": {
                      "field":"jerarquia-tablero12"
                    }
                  }
                  ]
                }
              }
        },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["hits"]["hits"]
    fields = {}
    for num, doc in enumerate(elastic_docs):
        fecha_ejecucion = doc["_source"]['usuarios.fechaControl']
except:
    fecha_ejecucion = '2021-05-01 00:00:00'
if response["hits"]["hits"] == []:
    fecha_ejecucion = '2021-05-01 00:00:00'
print("ultima fecha para control de ejecucion:",fecha_ejecucion)
# Out:
# ultima fecha para control de ejecucion: 2021-06-07 00:00:00

# %% [markdown]
# ### Asociando datos de usuarios

# %% [markdown]
# * Se realiza lectura por día procesado
# * lugar_cod se usa para cruzar con semilla por site_id
# * creado es la fecha de creación del usuario
# * tipodoc y documento corresponden a datos del usuario. Se usa para calcular totales

# %%
def traeRegistros(fecha_max,fecha_tope):
    total_docs = 10000
    response = es.search(
        index= parametros.ohmyfi_d_u_index,
        body={
                "_source": ['lugar_cod','tipodoc', 'documento', 'creado']
                  , "query": {
                  "range": {
                    "creado": {
                      "gte": fecha_max.split(' ')[0]+' 00:00:00',
                      "lt": fecha_tope.split(' ')[0]+' 23:59:59'
                      #"gte": "2021-05-26 10:00:00",
                      #"lt": "2021-05-26 15:00:00"  
                    }
                  }
              }
        },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["hits"]["hits"]
#    fields = {}
#    for num, doc in enumerate(elastic_docs):
#        source_data = doc["_source"]
#        for key, val in source_data.items():
#            try:
#                fields[key] = np.append(fields[key], val)
#            except KeyError:
#                fields[key] = np.array([val])

#    return pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ]))
    return pd.DataFrame([x["_source"] for x in elastic_docs])

# %% [markdown]
# ### Se realiza consulta de datos

# %% [markdown]
# * Se calcula rango en base a la fecha de control. Para este caso es de un día.
# * Se ejecuta la función de consulta con el rango de fechas.
# * Si no retorna datos se incrementa el rango y se ejecuta nuevamente. Este proceso se repite hasta conseguir datos o hasta que el rango de ejecución alcance la fecha actual.

# %%
fecha_max_mintic = fecha_ejecucion
fecha_tope_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(days=1)-timedelta(seconds=1)).strftime("%Y-%m-%d %H:%M:%S")
datos_registro = traeRegistros(fecha_max_mintic,fecha_tope_mintic)

if datos_registro is None or datos_registro.empty:
    while (datos_registro is None or datos_registro.empty) and ((datetime.strptime(fecha_max_mintic[0:10], '%Y-%m-%d').strftime("%Y-%m-%d %H:%M:%S")) < str(now.strftime("%Y-%m-%d %H:%M:%S"))):
        fecha_max_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(days=1)).strftime("%Y-%m-%d %H:%M:%S")
        fecha_tope_mintic = (datetime.strptime(fecha_tope_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(days=1)).strftime("%Y-%m-%d %H:%M:%S")
        datos_speed = traeRegistros(fecha_max_mintic,fecha_tope_mintic)
else:
    pass

# %% [markdown]
# # leyendo indice cambium-devicedevices

# %% [markdown]
# De esta formas se asocia las MAC de dispositivos de red INDOOR y OUTDOOR
#
# site_id para cruzar con las misma llave de semilla.
# datos del dispositivo: mac, status, ip.
# ap_group para identificar si la conexión es indoor/outdoor

# %%
total_docs = 30000
try:
    response = es.search(
        index= parametros.cambium_d_d_index,
        body={
                    "_source": ["site_id","mac","status","ip","ap_group"]
                  , "query": {
                    "match_all": {}
                  }
        },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["hits"]["hits"]
    fields = {}
    for num, doc in enumerate(elastic_docs):
        source_data = doc["_source"]
        for key, val in source_data.items():
            try:
                fields[key] = np.append(fields[key], val)
            except KeyError:
                fields[key] = np.array([val])

    datos_dev = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ])) #pd.DataFrame(fields)
except:
    exit()

# %% [markdown]
# Se descartan registros con site_id vacios ya que no cruzarán en el merge y se limpian los NaN del dataframe

# %%
datos_dev.dropna(subset=['site_id'], inplace=True)
datos_dev.fillna('', inplace=True)
datos_dev = datos_dev.drop(datos_dev[(datos_dev['site_id']=='')].index)

# %% [markdown]
# Se corrigen datos de ap group con formato no valido

# %%
datos_dev['ap_group'] = datos_dev['ap_group'].str.split("-", n = 1, expand = True)[0]
datos_dev['ap_group'] = datos_dev['ap_group'].str.split("_", n = 1, expand = True)[0]
datos_dev['ap_group'] = datos_dev['ap_group'].str.split(".", n = 1, expand = True)[0]
datos_dev = datos_dev.drop(datos_dev[(datos_dev['ap_group']=='')].index)

# %% [markdown]
# Se toman solo los datos con site_id y mac unicos

# %%
#datos_dev.drop_duplicates(subset=['site_id','mac'],inplace=True)
datos_dev = datos_dev.drop_duplicates('mac')

# %% [markdown]
# Se cambia el nombre a la mac del dispositivo de red para no confundir con la de dispositivos de usuario

# %%
datos_dev= datos_dev.rename(columns={'mac' : 'usuarios.macRed','ap_group' : 'usuarios.apGroup'})

# %% [markdown]
# # Se lee información de Ohmyfi consumos

# %% [markdown]
# Apartir de esta lectura se toma el valor del tiempo promedio de sesión en minutos. Se toma de referencia los campos:
#
# fecha_inicio a partir de la cual se calcula fecha control
# tiempo_sesion_minutos
# mac_usuario
# lugar_cod

# %%
def traeSesiones(fecha_max,fecha_tope):
    total_docs = 500000
    response = es.search(
        index= parametros.ohmyfi_consumos_index,
        body={
                  "_source": ["lugar_cod", "tiempo_sesion_minutos","mac_usuario","fecha_inicio"]
                , "query": {
                      "range": {
                            "fecha_inicio": {
                            "gte": fecha_max,
                            "lt": fecha_tope
                            }
                        }
                  }
        },
        size=total_docs
    )
    elastic_docs = response["hits"]["hits"]
    #fields = {}
    #for num, doc in enumerate(elastic_docs):
        #source_data = doc["_source"]
        #for key, val in source_data.items():
            #try:
                #fields[key] = np.append(fields[key], val)
            #except KeyError:
                #fields[key] = np.array([val])
                
    #return pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ])) 

    return pd.DataFrame([x["_source"] for x in elastic_docs])

# %% [markdown]
# ## Lectura de datos ohmyfi-detalleconexiones

# %% [markdown]
# Los datos que se toman son:
#
# fechahora (de cada conexión). fecha_control es lo mismo pero con el intervalo de 10 minutos
# Información del centro: lugar, lugar_cod.
# Información del dispositivo de usuario: mac_usuario, dispositivo, sistema_operativo.
# Información de usuario: tipodoc y documento

# %%
def trae_conexiones(fecha_ini,fecha_fin):
    total_docs = 5000000
    response = es.search(
        index= parametros.ohmyfi_d_c_index,
        body={
                "_source": ["fechahora","fecha_control","lugar","lugar_cod","mac_usuario", "dispositivo"
                            ,"sistema_operativo",'tipodoc','documento']
                , "query": {
                  "range": {
                    "fechahora": {
                      "gte": fecha_ini,
                      "lt": fecha_fin
                    }
                  }
              }
        },
        size=total_docs
    )
    elastic_docs = response["hits"]["hits"]
#     fields = {}
#     for num, doc in enumerate(elastic_docs):
#         source_data = doc["_source"]
#         for key, val in source_data.items():
#             try:
#                 fields[key] = np.append(fields[key], val)
#             except KeyError:
#                 fields[key] = np.array([val])

#     return pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ])) 

    return pd.DataFrame([x["_source"] for x in elastic_docs])

# %%
fecha_max_mintic = fecha_ejecucion
fecha_tope_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=10)-timedelta(seconds=1)).strftime("%Y-%m-%d %H:%M:%S")
datos_det_conex = trae_conexiones(fecha_max_mintic,fecha_tope_mintic)

if datos_det_conex is None or datos_det_conex.empty:
    while (datos_det_conex is None or datos_det_conex.empty) and ((datetime.strptime(fecha_max_mintic[0:10], '%Y-%m-%d').strftime("%Y-%m-%d %H:%M:%S")) < str(now.strftime("%Y-%m-%d %H:%M:%S"))):
        fecha_max_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=10)).strftime("%Y-%m-%d %H:%M:%S")
        fecha_tope_mintic = (datetime.strptime(fecha_tope_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=10)).strftime("%Y-%m-%d %H:%M:%S")
        datos_det_conex = trae_conexiones(fecha_max_mintic,fecha_tope_mintic)
else:
    pass

# %%
datos_det_conex['fecha'] = datos_det_conex['fecha_control'].str.split(" ", n = 1, expand = True)[0]
datos_det_conex.drop_duplicates(subset=["fecha_control","lugar","lugar_cod","mac_usuario", "dispositivo","sistema_operativo",'tipodoc','documento'],inplace=True)

# %%
datos_det_conex = datos_det_conex.rename(columns={'lugar_cod' : 'site_id'
                                                             ,'fechahora':'usuarios.fechaConexionUsuarios'
                                                             ,'dispositivo': 'usuarios.tipoDispositivoUsuarios'
                                                             , 'sistema_operativo': 'usuarios.sistemaOperativoUsuarios'})

# %% [markdown]
# Se corrigen valores errados de site_id en detalle conexiones

# %%
datos_det_conex['site_id'] = datos_det_conex['site_id'].str.replace("_","-")

# %% [markdown]
# ### Se lee la información de cambium device client

# %% [markdown]
# Esta lectura se usa para identificar:
#
# Lecturas de consumo por dispositivo (radios rx y tx)
# Fabricante del dispositivo
# la mac del ap que luego se usa para identificar el ap group(Indoor/Outdoor)

# %%
t1=time.time()

total_docs = 30000000
response = es.search(
    index= parametros.cambium_d_c_index,
    body={
            "_source": ["mac","ap_mac", 'manufacturer','name',"radio.band",'radio.rx_bytes','radio.tx_bytes'],
              "query": {
                "bool": {
                  "filter": [
                  {
                    "exists": {
                      "field":"mac"
                    }
                  }
                  ]
                }
              }
    },
    size=total_docs
)
elastic_docs = response["hits"]["hits"]
# fields = {}
# for num, doc in enumerate(elastic_docs):
#     source_data = doc["_source"]
#     for key, val in source_data.items():
#         try:
#             fields[key] = np.append(fields[key], val)
#         except KeyError:
#             fields[key] = np.array([val])

# datos_dev_clients = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ]))

datos_dev_clients = pd.DataFrame([x["_source"] for x in elastic_docs])

t2=time.time()

# %% [markdown]
# se cruza por mac_usuario
# Los merge usan left para evitar perdida de datos en cruce con cambium-devicedevices. Aquellos datos que no cruzan se les marca como no identificados. En condiciones ideales, no debería presentarse ausencia de información
# Solo se toma lo que cruza con INNER
# se cambia el fabricante [Local MAC]
# se cambian lo nulos

# %%
try:
    datos_dev_clients.drop_duplicates(inplace=True)
    datos_dev_clients = datos_dev_clients.rename(columns={'ap_mac' : 'usuarios.macRed','mac' : 'mac_usuario'})
    datos_dev_clients['manufacturer'] = datos_dev_clients['manufacturer'].replace("[Local MAC]", "No identificado")
    datos_dev_clients.fillna({'manufacturer':'No identificado'},inplace=True)
    datos_det_conex = pd.merge(datos_det_conex,  datos_dev_clients, on='mac_usuario',how='left')
    datos_det_conex = pd.merge(datos_det_conex,datos_dev[['usuarios.macRed','usuarios.apGroup']],on='usuarios.macRed', how='left')
    datos_det_conex.fillna({'usuarios.tipoDispositivoUsuarios':'No identificado'
                       ,'usuarios.sistemaOperativoUsuarios':'No identificado'
                       ,'manufacturer':'No identificado'
                       ,'radio.band':'No identificado'
                       },inplace=True)
except:
    pass

# %% [markdown]
# # Se ejecuta consulta de datos

# %% [markdown]
# Se calcula rango en base a la fecha de control. Para este caso es de 10 minutos.
# Se ejecuta la función de consulta con el rango de fechas.
# Si no retorna datos se incrementa el rango y se ejecuta nuevamente. Este proceso se repite hasta conseguir datos o hasta que el rango de ejecución alcance la fecha y hora actual.

# %%
fecha_max_mintic = fecha_ejecucion

fecha_tope_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=50)-timedelta(seconds=1)).strftime("%Y-%m-%d %H:%M:%S")
datos_consumos = traeSesiones(fecha_max_mintic,fecha_tope_mintic)

if datos_consumos is None or datos_consumos.empty:
    #while (datos_consumos is None or datos_consumos.empty) and ((datetime.strptime(fecha_max_mintic[0:50], '%Y-%m-%d %H:%M:%S').strftime("%Y-%m-%d %H:%M:%S")) < str(now.strftime("%Y-%m-%d %H:%M:%S"))):
    while (datos_consumos is None or datos_consumos.empty) and ((datetime.strptime(fecha_max_mintic[0:50], '%Y-%m-%d %H:%M:%S').strftime("%Y-%m-%d %H:%M:%S")) < str(now.strftime("%Y-%m-%d %H:%M:%S"))):
        fecha_max_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=50)).strftime("%Y-%m-%d %H:%M:%S")
        fecha_tope_mintic = (datetime.strptime(fecha_tope_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=50)).strftime("%Y-%m-%d %H:%M:%S")
        datos_consumos = traeSesiones(fecha_max_mintic,fecha_tope_mintic)
else:
    pass

# %% [markdown]
# # Marcando si usuario es nuevo o recurrente¶

# %% [markdown]
# Se toma del dataframe datos_det_conex y se cuenta las veces que cada mac_usuario aparece
# Luego se suma con el historico de conexiones por usuario (indice intermedio ohmyfi-total-conexiones-historico)
# marca como Nuevo(1 conexión).
# De este proceso se obtiene el campo:
#
# usuarios.usuariosNuevos
# usuarios.totales.usuariosNuevos

# %%
try:
    datos_recurrencia = datos_det_conex[["fecha","tipodoc","documento"]].groupby(["tipodoc","documento"]).agg(['count']).reset_index()
    datos_recurrencia.columns = datos_recurrencia.columns.droplevel(1)
    datos_recurrencia= datos_recurrencia.rename(columns={'fecha' : 'usuarios_recurrencia_aux'})
    datos_recurrencia['tipodoc'] = datos_recurrencia['tipodoc'].replace('','No especificado')
    datos_recurrencia['documento'] = datos_recurrencia['documento'].replace('','No especificado')
except:
    pass

# %% [markdown]
# ### Se lee historico

# %% [markdown]
# Se lee ohmyfi-total-conexiones-historico, el cual es un indice creado a partir de los datos crudos. Este guarda la cantidad de conexiones realizadas por ese usuario. Para que la consulta funcione correctamente se debe colocar el filtro que usuarios_recurrencia exista.

# %%
try:
    total_docs = 30000000
    response = es.search(
        index= parametros.ohmyfi_total_c_index,
        body={
              "_source": ['tipodoc', 'documento', 'usuarios_recurrencia'],
              "query": {
                "bool": {
                  "filter": [
                  {
                    "exists": {
                      "field":"usuarios_recurrencia"
                    }
                  }
                  ]
                }
              }
        },
        size=total_docs
    )
    elastic_docs = response["hits"]["hits"]
#    fields = {}
#    for num, doc in enumerate(elastic_docs):
#       source_data = doc["_source"]
#       for key, val in source_data.items():
#            try:
#                fields[key] = np.append(fields[key], val)
#            except KeyError:
#               fields[key] = np.array([val])

    #ya_en_indice = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ]))
    
    ya_en_indice = pd.DataFrame([x["_source"] for x in elastic_docs])
    
except:
    ya_en_indice = pd.DataFrame(columns=['tipodoc', 'documento', 'usuarios_recurrencia'])

# %%
ya_en_indice
# Out:
#         usuarios_recurrencia tipodoc   documento
# 0                       90.0      CC  1042999676
# 1                       26.0      CC  1063481153
# 2                        8.0      CC  1073986488
# 3                        6.0      CC  1101177429
# 4                       52.0      CC     1839473
# ...                      ...     ...         ...
# 259484                 220.0       x    72017832
# 259485                 176.0       x    72017915
# 259486                 129.0       x    72018216
# 259487                 132.0       x    72020959
# 259488                  26.0       x    72290770
#
# [259489 rows x 3 columns]

# %%
if ya_en_indice is None or ya_en_indice.empty:
    datos_recurrencia= datos_recurrencia.rename(columns={'usuarios_recurrencia_aux' : 'usuarios_recurrencia'})
else:
    datos_recurrencia = pd.merge(datos_recurrencia, ya_en_indice, on=['tipodoc', 'documento'],how='left')
    datos_recurrencia.fillna({'usuarios_recurrencia':0},inplace=True)
    datos_recurrencia['usuarios_recurrencia'] = datos_recurrencia['usuarios_recurrencia'] + datos_recurrencia['usuarios_recurrencia_aux']
    datos_recurrencia['usuarios_recurrencia'] = [int(x) for x in datos_recurrencia['usuarios_recurrencia']]

# %%
try:
    aux_recurrencia = pd.merge(datos_recurrencia,datos_det_conex, on=['tipodoc','documento'],how='inner' )
    aux_recurrencia = aux_recurrencia[(aux_recurrencia['usuarios_recurrencia']==1)]
    aux_recurrencia.loc[aux_recurrencia['usuarios_recurrencia']==1,'usuarios.usuariosNuevos']='Nuevo'
    #aux_recurrencia.loc[aux_recurrencia['usuarios_recurrencia']!=1,'usuarios.usuariosNuevos']='Recurrente'
    aux_recurrencia = aux_recurrencia.rename(columns={'usuarios_recurrencia' :'usuarios.sesiones_Usuarios'})
    aux_recurrencia = aux_recurrencia[["fecha_control","site_id","usuarios.usuariosNuevos",'documento']].groupby(["fecha_control","site_id","usuarios.usuariosNuevos"])['documento'].nunique().reset_index()
    aux_recurrencia= aux_recurrencia.rename(columns={'documento' : 'usuarios.totales.usuariosNuevos'})
except:
    pass

# %%
try:
    datos_recurrencia = pd.merge(datos_semilla,  aux_recurrencia, on='site_id', how='inner')
    datos_recurrencia = datos_recurrencia.rename(columns={'fecha_control' : 'usuarios.fechaControl'})
    datos_recurrencia["usuarios.fecha"] = datos_recurrencia["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[0]
    datos_recurrencia["usuarios.anyo"] = datos_recurrencia["usuarios.fecha"].str[0:4]
    datos_recurrencia["usuarios.mes"] = datos_recurrencia["usuarios.fecha"].str[5:7]
    datos_recurrencia["usuarios.dia"] = datos_recurrencia["usuarios.fecha"].str[8:10]
    datos_recurrencia["usuarios.hora"] = datos_recurrencia["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[0]
    datos_recurrencia["usuarios.minuto"] = datos_recurrencia["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[1]
    datos_recurrencia= datos_recurrencia.rename(columns={'site_id' : 'usuarios.siteID'})
    
    datos_recurrencia['nombreDepartamento'] = datos_recurrencia['usuarios.nombreDepartamento']
    datos_recurrencia['nombreMunicipio'] = datos_recurrencia['usuarios.nombreMunicipio']
    datos_recurrencia['idBeneficiario'] = datos_recurrencia['usuarios.idBeneficiario']
    datos_recurrencia['fecha'] = datos_recurrencia['usuarios.fecha']
    datos_recurrencia['anyo'] = datos_recurrencia['usuarios.anyo']
    datos_recurrencia['mes'] = datos_recurrencia['usuarios.mes']
    datos_recurrencia['dia'] = datos_recurrencia['usuarios.dia']
except:
    pass

# %%
datos_recurrencia
# Out:
#           usuarios.nomCentroDigital usuarios.codISO usuarios.localidad  \
# 0              ESC NVA PIEDRA ABAJO          CO-COR  VDA PIEDRAS ABAJO
# 1                    SEDE PRINCIPAL          CO-COR     PUEBLECITO SUR
# 2  I.E. DON ALONSO - SEDE PRINCIPAL          CO-SUC         DON ALONSO
# 3            JAGUALITO PUEBLO NUEVO          CO-TOL       PUEBLO NUEVO
#
#   usuarios.siteID usuarios.nombreDepartamento usuarios.sistemaEnergia  \
# 0   31505-ZZZY232                     CÓRDOBA      RED INTERCONECTADA
# 1   32284-ZZZY240                     CÓRDOBA      RED INTERCONECTADA
# 2   47119-ZZZY211                       SUCRE      RED INTERCONECTADA
# 3   48605-ZGYO579                      TOLIMA      RED INTERCONECTADA
#
#   usuarios.nombreMunicipio  usuarios.idBeneficiario  \
# 0           CIÉNAGA DE ORO                    31505
# 1  SAN ANDRÉS DE SOTAVENTO                    32284
# 2                  COROZAL                    47119
# 3                    GUAMO                    48605
#
#            usuarios.location usuarios.fechaControl  ... usuarios.dia  \
# 0    7.9471111,-73.656805000   2021-06-07 00:00:00  ...           07
# 1     9.3517975,-75.79683054   2021-06-07 00:00:00  ...           07
# 2    9.25824627,-75.31213588   2021-06-07 00:00:00  ...           07
# 3  4.000838889,-74.894555556   2021-06-07 00:00:00  ...           07
#
#    usuarios.hora usuarios.minuto nombreDepartamento          nombreMunicipio  \
# 0             00              00            CÓRDOBA           CIÉNAGA DE ORO
# 1             00              00            CÓRDOBA  SAN ANDRÉS DE SOTAVENTO
# 2             00              00              SUCRE                  COROZAL
# 3             00              00             TOLIMA                    GUAMO
#
#   idBeneficiario       fecha  anyo mes dia
# 0          31505  2021-06-07  2021  06  07
# 1          32284  2021-06-07  2021  06  07
# 2          47119  2021-06-07  2021  06  07
# 3          48605  2021-06-07  2021  06  07
#
# [4 rows x 25 columns]

# %%
datos_recurrencia.columns
# Out:
# Index(['usuarios.nomCentroDigital', 'usuarios.codISO', 'usuarios.localidad',
#        'usuarios.siteID', 'usuarios.nombreDepartamento',
#        'usuarios.sistemaEnergia', 'usuarios.nombreMunicipio',
#        'usuarios.idBeneficiario', 'usuarios.location', 'usuarios.fechaControl',
#        'usuarios.usuariosNuevos', 'usuarios.totales.usuariosNuevos',
#        'usuarios.fecha', 'usuarios.anyo', 'usuarios.mes', 'usuarios.dia',
#        'usuarios.hora', 'usuarios.minuto', 'nombreDepartamento',
#        'nombreMunicipio', 'idBeneficiario', 'fecha', 'anyo', 'mes', 'dia'],
#       dtype='object')

# %% [markdown]
# # Total registros  a indice

# %% [markdown]
# la lista use_these_keys se usa para referenciar cuales campos del dataframe irán al indice final. si los datos no se declaran en este, no se insertarán

# %%
use_these_keys = ['usuarios.fecha'
                  ,'usuarios.siteID'
                  ,'usuarios.usuariosRegistrados'
                  , 'usuarios.anyo'
                  , 'usuarios.mes'
                  , 'usuarios.dia'
                  , 'usuarios.nomCentroDigital'
                  , 'usuarios.codISO'
                  , 'usuarios.localidad'
                  , 'usuarios.nombreDepartamento'
                  , 'usuarios.sistemaEnergia'
                  , 'usuarios.nombreMunicipio'
                  , 'usuarios.idBeneficiario'
                  , 'usuarios.location'
                  , 'usuarios.macRed'
                  , 'usuarios.fechaControl'
                  , 'usuarios.tiempoPromedioSesionSitio'
                  , 'usuarios.apGroup'
                  , 'usuarios.totales.usuariosNuevos'
                  , 'usuarios.sesiones_Usuarios'
                  , 'usuarios.usuariosConectados'
                  #, 'usuarios.hora'
                  #, 'usuarios.minuto'
                  , 'ip'
                  , 'status'
                  , 'nombreDepartamento'
                    , 'nombreMunicipio'
                    , 'idBeneficiario'
                    , 'fecha'
                    , 'anyo'
                    , 'mes'
                    , 'dia'
                  , '@timestamp']

def doc_generator(df):
    df_iter = df.iterrows()
    for index, document in df_iter:
        document = document.rename(index={ 'usuarios.apGroup_x':'usuarios.apGroup', 'usuarios.fecha_x': 'usuarios.fecha','usuarios.anyo_x': 'usuarios.anyo','usuarios.mes_x':'usuarios.mes','usuarios.dia_x':'usuarios.dia','usuarios.nomCentroDigital_x':'usuarios.nomCentroDigital', 'usuarios.codISO_x':'usuarios.codISO', 'usuarios.localidad_x':'usuarios.localidad', 'usuarios.nombreDepartamento_x':'usuarios.nombreDepartamento', 'usuarios.sistemaEnergia_x':'usuarios.sistemaEnergia', 'usuarios.nombreMunicipio_x':'usuarios.nombreMunicipio', 'usuarios.idBeneficiario_x':'usuarios.idBeneficiario', 'usuarios.location_x':'usuarios.location', 'nombreDepartamento_x':'nombreDepartamento', 'nombreMunicipio_x':'nombreMunicipio', 'idBeneficiario_x':'idBeneficiario', 'usuarios.fechaControl_x':'usuarios.fechaControl', 'usuarios.macRed_x':'usuarios.macRed','fecha_x':'fecha', 'anyo_x':'anyo', 'mes_x':'mes', 'dia_x':'dia', '@timestamp_x':'@timestamp'})
        
        #print(document)
        #print("=========================")
        yield {
                "_index": indice, 
                "_id": f"{'UsuRegistro-'+ str(document['usuarios.siteID']) + '-' + str(document['usuarios.fecha']) + str(random.randrange(1000))}",
                "_source": filterKeys(document),
            }

# %% [markdown]
# Para cada sitio y fecha, se cuentan los documentos de usuario. Esto resulta en el total de usuarios registrados para esa fecha

# %%
def invalid_values(df, values=['']):
    return df.loc[df['usuarios.location'].isin(values)]

# %%
try:
    
    datos_registro['creado'] = datos_registro['creado'].str[0:10]
    datos_registro['tipo_mas_doc'] = datos_registro['tipodoc'] + datos_registro['documento']
    datos_registro= datos_registro.rename(columns={'creado' : 'usuarios.fecha'
                                                  ,'lugar_cod':'site_id'})

    datos_registro = datos_registro[["usuarios.fecha","site_id","tipo_mas_doc"]].groupby(["usuarios.fecha","site_id"]).agg(['count']).reset_index()
    datos_registro.columns = datos_registro.columns.droplevel(1)
    datos_registro= datos_registro.rename(columns={'tipo_mas_doc' : 'usuarios.usuariosRegistrados'})
    datos_registro["usuarios.anyo"] = datos_registro["usuarios.fecha"].str[0:4]
    datos_registro["usuarios.mes"] = datos_registro["usuarios.fecha"].str[5:7]
    datos_registro["usuarios.dia"] = datos_registro["usuarios.fecha"].str[8:10]
    datos_registro = pd.merge(datos_registro,  datos_semilla, on='site_id', how='inner')
    datos_registro.rename(columns={'site_id': 'usuarios.siteID'
                               }, inplace=True)
    
    datos_registro['nombreDepartamento'] = datos_registro['usuarios.nombreDepartamento']
    datos_registro['nombreMunicipio'] = datos_registro['usuarios.nombreMunicipio']
    datos_registro['idBeneficiario'] = datos_registro['usuarios.idBeneficiario']
    datos_registro['fecha'] = datos_registro['usuarios.fecha']
    datos_registro['anyo'] = datos_registro['usuarios.anyo']
    datos_registro['mes'] = datos_registro['usuarios.mes']
    datos_registro['dia'] = datos_registro['usuarios.dia']
    
    datos_registro['@timestamp'] = now.isoformat()
    #salida = helpers.bulk(es, doc_generator(datos_registro))
    #print("Fecha: ", now,"- Datos Registro usuarios en indice principal:",salida[0])
except Exception as e:
    print("Fecha: ", now,"- Nada que insertar en indice principal",e)
# Out:
# Fecha:  2021-08-09 22:26:01.102495 - Nada que insertar en indice principal 'creado'

# %%
datos_registro.head()
# Out:
#   usuarios.fecha usuarios.siteID  usuarios.usuariosRegistrados usuarios.anyo  \
# 0     2021-06-07   10835-ZGYO372                             2          2021
# 1     2021-06-07   11107-ZGYO062                             1          2021
# 2     2021-06-07   11128-ZGYO932                             2          2021
# 3     2021-06-07   13253-ZGYO527                             3          2021
# 4     2021-06-07   13258-ZGYO980                            15          2021
#
#   usuarios.mes usuarios.dia         usuarios.nomCentroDigital usuarios.codISO  \
# 0           06           07              E.U. SIETE DE AGOSTO          CO-ANT
# 1           06           07                  MARIA INMACULADA          CO-ATL
# 2           06           07                    LAS PETRONITAS          CO-ATL
# 3           06           07                           EL JABO          CO-CES
# 4           06           07  IE ANTONIO ENRIQUE DIAZ MARTINEZ          CO-CES
#
#                   usuarios.localidad usuarios.nombreDepartamento  ...  \
# 0                CALLE 115 # 06 - 60                   ANTIOQUIA  ...
# 1                  CALLE 15  12 - 20                   ATLÁNTICO  ...
# 2  VEREDA LAS PETRONITAS CORDIALIDAD                   ATLÁNTICO  ...
# 3                            EL JABO                       CESAR  ...
# 4                            BADILLO                       CESAR  ...
#
#   usuarios.idBeneficiario          usuarios.location  nombreDepartamento  \
# 0                   10835  10.88307108,-75.077732850           ANTIOQUIA
# 1                   11107       10.504888,-74.816395           ATLÁNTICO
# 2                   11128      8.751218,-75.49306166           ATLÁNTICO
# 3                   13253         3.985,-75.06861111               CESAR
# 4                   13258    10.40971209,-73.5167746               CESAR
#
#   nombreMunicipio idBeneficiario       fecha  anyo mes dia  \
# 0           TURBO          10835  2021-06-07  2021  06  07
# 1         BARANOA          11107  2021-06-07  2021  06  07
# 2          GALAPA          11128  2021-06-07  2021  06  07
# 3      VALLEDUPAR          13253  2021-06-07  2021  06  07
# 4      VALLEDUPAR          13258  2021-06-07  2021  06  07
#
#                    @timestamp
# 0  2021-08-09T22:26:01.102495
# 1  2021-08-09T22:26:01.102495
# 2  2021-08-09T22:26:01.102495
# 3  2021-08-09T22:26:01.102495
# 4  2021-08-09T22:26:01.102495
#
# [5 rows x 22 columns]

# %%
datos_registro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359 entries, 0 to 358
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   usuarios.fecha                359 non-null    object
#  1   usuarios.siteID               359 non-null    object
#  2   usuarios.usuariosRegistrados  359 non-null    int64
#  3   usuarios.anyo                 359 non-null    object
#  4   usuarios.mes                  359 non-null    object
#  5   usuarios.dia                  359 non-null    object
#  6   usuarios.nomCentroDigital     359 non-null    object
#  7   usuarios.codISO               359 non-null    object
#  8   usuarios.localidad            359 non-null    object
#  9   usuarios.nombreDepartamento   359 non-null    object
#  10  usuarios.sistemaEnergia       359 non-null    object
#  11  usuarios.nombreMunicipio      359 non-null    object
#  12  usuarios.idBeneficiario       359 non-null    int64
#  13  usuarios.location             359 non-null    object
#  14  nombreDepartamento            359 non-null    object
#  15  nombreMunicipio               359 non-null    object
#  16  idBeneficiario                359 non-null    int64
#  17  fecha                         359 non-null    object
#  18  anyo                          359 non-null    object
#  19  mes                           359 non-null    object
#  20  dia                           359 non-null    object
#  21  @timestamp                    359 non-null    object
# dtypes: int64(3), object(19)
# memory usage: 64.5+ KB

# %%
try:
    datos_consumos = datos_consumos.rename(columns={'lugar_cod' :'site_id'})
    datos_consumos['mac_usuario'] = datos_consumos['mac_usuario'].str.replace('-',':')
    datos_consumos['fecha_control'] = datos_consumos["fecha_inicio"].str[0:-4] + '0:00'
    tiempoPromedioSesionSitio=datos_consumos[['site_id','mac_usuario','fecha_control','tiempo_sesion_minutos']].groupby(['site_id','mac_usuario','fecha_control']).agg(['mean']).reset_index()
    tiempoPromedioSesionSitio.columns = tiempoPromedioSesionSitio.columns.droplevel(1)
    tiempoPromedioSesionSitio = tiempoPromedioSesionSitio.rename(columns={'tiempo_sesion_minutos' : 'usuarios.tiempoPromedioSesionSitio'})
    tiempoPromedioSesionSitio['usuarios.tiempoPromedioSesionSitio'] = round(tiempoPromedioSesionSitio['usuarios.tiempoPromedioSesionSitio'],6)
    tiempoPromedioSesionSitio = tiempoPromedioSesionSitio.rename(columns={'mac_usuario' : 'usuarios.macRed'
                                                                     , 'fecha_control' : 'usuarios.fechaControl'})
    tiempoPromedioSesionSitio = pd.merge(tiempoPromedioSesionSitio,datos_semilla, on ='site_id', how='inner')
    tiempoPromedioSesionSitio = pd.merge(tiempoPromedioSesionSitio, datos_dev, on=['site_id','usuarios.macRed'], how='left')
    tiempoPromedioSesionSitio.fillna({'usuarios.apGroup':'No identificado'},inplace=True)
    
    tiempoPromedioSesionSitio = tiempoPromedioSesionSitio.rename(columns={'site_id' : 'usuarios.siteID'})
    tiempoPromedioSesionSitio["usuarios.fecha"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str[0:10]
    tiempoPromedioSesionSitio["usuarios.anyo"] = tiempoPromedioSesionSitio["usuarios.fecha"].str[0:4]
    tiempoPromedioSesionSitio["usuarios.mes"] = tiempoPromedioSesionSitio["usuarios.fecha"].str[5:7]
    tiempoPromedioSesionSitio["usuarios.dia"] = tiempoPromedioSesionSitio["usuarios.fecha"].str[8:10]
    tiempoPromedioSesionSitio["usuarios.hora"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[0]["usuarios.hora"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[0]
    tiempoPromedioSesionSitio["usuarios.minuto"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[1]
    
    tiempoPromedioSesionSitio['nombreDepartamento'] = tiempoPromedioSesionSitio['usuarios.nombreDepartamento']
    tiempoPromedioSesionSitio['nombreMunicipio'] = tiempoPromedioSesionSitio['usuarios.nombreMunicipio']
    tiempoPromedioSesionSitio['idBeneficiario'] = tiempoPromedioSesionSitio['usuarios.idBeneficiario']
    tiempoPromedioSesionSitio['fecha'] = tiempoPromedioSesionSitio['usuarios.fecha']
    tiempoPromedioSesionSitio['anyo'] = tiempoPromedioSesionSitio['usuarios.anyo']
    tiempoPromedioSesionSitio['mes'] = tiempoPromedioSesionSitio['usuarios.mes']
    tiempoPromedioSesionSitio['dia'] = tiempoPromedioSesionSitio['usuarios.dia']
    
    tiempoPromedioSesionSitio['@timestamp'] = now.isoformat()
    #salida = helpers.bulk(es, doc_generator(tiempoPromedioSesionSitio))
    #print("Fecha: ", now,"- Tiempo promedio sesion en sitio insertado en indice principal:",salida[0])
except Exception as e:
    print("Fecha: ", now,"- Nada para insertar en indice principal",e)

# %%
tiempoPromedioSesionSitio.head()
# Out:
#   usuarios.siteID    usuarios.macRed usuarios.fechaControl  \
# 0   13253-ZGYO527  98:FF:D0:46:AD:16   2021-06-07 00:10:00
# 1   13253-ZGYO527  98:FF:D0:46:AD:16   2021-06-07 00:20:00
# 2   13253-ZGYO527  98:FF:D0:46:AD:16   2021-06-07 00:30:00
# 3   13253-ZGYO527  98:FF:D0:46:AD:16   2021-06-07 00:40:00
# 4   13253-ZGYO527  D6:7A:05:FA:CD:D3   2021-06-07 00:30:00
#
#    usuarios.tiempoPromedioSesionSitio usuarios.nomCentroDigital  \
# 0                                5.47                   EL JABO
# 1                                4.53                   EL JABO
# 2                               12.02                   EL JABO
# 3                                3.27                   EL JABO
# 4                                1.87                   EL JABO
#
#   usuarios.codISO usuarios.localidad usuarios.nombreDepartamento  \
# 0          CO-CES            EL JABO                       CESAR
# 1          CO-CES            EL JABO                       CESAR
# 2          CO-CES            EL JABO                       CESAR
# 3          CO-CES            EL JABO                       CESAR
# 4          CO-CES            EL JABO                       CESAR
#
#   usuarios.sistemaEnergia usuarios.nombreMunicipio  ...  usuarios.hora  \
# 0      RED INTERCONECTADA               VALLEDUPAR  ...             00
# 1      RED INTERCONECTADA               VALLEDUPAR  ...             00
# 2      RED INTERCONECTADA               VALLEDUPAR  ...             00
# 3      RED INTERCONECTADA               VALLEDUPAR  ...             00
# 4      RED INTERCONECTADA               VALLEDUPAR  ...             00
#
#   usuarios.minuto nombreDepartamento nombreMunicipio idBeneficiario  \
# 0              10              CESAR      VALLEDUPAR          13253
# 1              20              CESAR      VALLEDUPAR          13253
# 2              30              CESAR      VALLEDUPAR          13253
# 3              40              CESAR      VALLEDUPAR          13253
# 4              30              CESAR      VALLEDUPAR          13253
#
#         fecha  anyo mes dia                  @timestamp
# 0  2021-06-07  2021  06  07  2021-08-09T22:26:01.102495
# 1  2021-06-07  2021  06  07  2021-08-09T22:26:01.102495
# 2  2021-06-07  2021  06  07  2021-08-09T22:26:01.102495
# 3  2021-06-07  2021  06  07  2021-08-09T22:26:01.102495
# 4  2021-06-07  2021  06  07  2021-08-09T22:26:01.102495
#
# [5 rows x 29 columns]

# %%
tiempoPromedioSesionSitio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326 entries, 0 to 325
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   usuarios.siteID                     326 non-null    object
#  1   usuarios.macRed                     326 non-null    object
#  2   usuarios.fechaControl               326 non-null    object
#  3   usuarios.tiempoPromedioSesionSitio  326 non-null    float64
#  4   usuarios.nomCentroDigital           326 non-null    object
#  5   usuarios.codISO                     326 non-null    object
#  6   usuarios.localidad                  326 non-null    object
#  7   usuarios.nombreDepartamento         326 non-null    object
#  8   usuarios.sistemaEnergia             326 non-null    object
#  9   usuarios.nombreMunicipio            326 non-null    object
#  10  usuarios.idBeneficiario             326 non-null    int64
#  11  usuarios.location                   326 non-null    object
#  12  usuarios.apGroup                    326 non-null    object
#  13  ip                                  0 non-null      object
#  14  status                              0 non-null      object
#  15  usuarios.fecha                      326 non-null    object
#  16  usuarios.anyo                       326 non-null    object
#  17  usuarios.mes                        326 non-null    object
#  18  usuarios.dia                        326 non-null    object
#  19  usuarios.hora                       326 non-null    object
#  20  usuarios.minuto                     326 non-null    object
#  21  nombreDepartamento                  326 non-null    object
#  22  nombreMunicipio                     326 non-null    object
#  23  idBeneficiario                      326 non-null    int64
#  24  fecha                               326 non-null    object
#  25  anyo                                326 non-null    object
#  26  mes                                 326 non-null    object
#  27  dia                                 326 non-null    object
#  28  @timestamp                          326 non-null    object
# dtypes: float64(1), int64(2), object(26)
# memory usage: 86.4+ KB

# %%
# Insertando usuarios conectados al indice principal

# %% [raw]
# * Se calcula cantidad de sesiones por sitio con detalle conexiones, pero contando la ocurrencia unica de documento
# * Se calcula la cantidad de conexiones. Se agrupa por el campo usuarios.macRed(el cual corresponde al AP) y fecha_control. Se cuenta las ocurrencias de mac_usuario. Luego al cruzar con flujo principal, si el dato es nulo para ese momento, se debe colocar en 0.

# %%
try:
    datos_logins = datos_det_conex[['fecha_control', 'site_id', 'documento','usuarios.macRed']].groupby(["fecha_control","site_id","usuarios.macRed"])['documento'].nunique().reset_index()
    datos_logins= datos_logins.rename(columns={'documento' : 'usuarios.sesiones_Usuarios'})
    usuariosConectados = datos_det_conex[["fecha_control","site_id","usuarios.macRed","mac_usuario"]].groupby(["fecha_control","site_id","usuarios.macRed"]).agg(['count']).reset_index()
    usuariosConectados.columns = usuariosConectados.columns.droplevel(1)
    usuariosConectados= usuariosConectados.rename(columns={'mac_usuario' : 'usuarios.usuariosConectados'})
    usuariosConectados = pd.merge(usuariosConectados,datos_logins, on=["fecha_control","site_id","usuarios.macRed"], how='inner')
    usuariosConectados = pd.merge(datos_semilla,  usuariosConectados, on=['site_id'], how='inner')
    usuariosConectados.fillna({'usuarios.consumoUsuarios' : 0
                              ,'usuarios.consumoUsuariosDescarga':0
                              ,'usuarios.consumoUsuariosCarga':0},inplace=True)
    usuariosConectados = pd.merge(usuariosConectados,datos_dev[['usuarios.apGroup','usuarios.macRed']], on ='usuarios.macRed', how='left')
    usuariosConectados.fillna({'usuarios.apGroup':'No identificado'},inplace=True)
    usuariosConectados['usuarios.usuariosConectados'] = usuariosConectados['usuarios.usuariosConectados'].astype(int)
    usuariosConectados = usuariosConectados.rename(columns={'fecha_control':'usuarios.fechaControl'
                                                           ,'site_id' : 'usuarios.siteID'})
    
    usuariosConectados["usuarios.fecha"] = usuariosConectados["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[0]
    usuariosConectados["usuarios.anyo"] = usuariosConectados["usuarios.fecha"].str[0:4]
    usuariosConectados["usuarios.mes"] = usuariosConectados["usuarios.fecha"].str[5:7]
    usuariosConectados["usuarios.dia"] = usuariosConectados["usuarios.fecha"].str[8:10]
    usuariosConectados["usuarios.hora"] = usuariosConectados["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[0]
    usuariosConectados["usuarios.minuto"] = usuariosConectados["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[1]
    
    usuariosConectados['nombreDepartamento'] = usuariosConectados['usuarios.nombreDepartamento']
    usuariosConectados['nombreMunicipio'] = usuariosConectados['usuarios.nombreMunicipio']
    usuariosConectados['idBeneficiario'] = usuariosConectados['usuarios.idBeneficiario']
    usuariosConectados['fecha'] = usuariosConectados['usuarios.fecha']
    usuariosConectados['anyo'] = usuariosConectados['usuarios.anyo']
    usuariosConectados['mes'] = usuariosConectados['usuarios.mes']
    usuariosConectados['dia'] = usuariosConectados['usuarios.dia']
except:
    pass

# %%
datos_logins = datos_det_conex[['fecha_control', 'site_id', 'documento','usuarios.macRed']].groupby(["fecha_control","site_id","usuarios.macRed"])['documento'].nunique().reset_index()
datos_logins= datos_logins.rename(columns={'documento' : 'usuarios.sesiones_Usuarios'})
usuariosConectados = datos_det_conex[["fecha_control","site_id","usuarios.macRed","mac_usuario"]].groupby(["fecha_control","site_id","usuarios.macRed"]).agg(['count']).reset_index()
usuariosConectados.columns = usuariosConectados.columns.droplevel(1)
usuariosConectados= usuariosConectados.rename(columns={'mac_usuario' : 'usuarios.usuariosConectados'})
usuariosConectados = pd.merge(usuariosConectados,datos_logins, on=["fecha_control","site_id","usuarios.macRed"], how='inner')
usuariosConectados = pd.merge(datos_semilla,  usuariosConectados, on=['site_id'], how='inner')
usuariosConectados.fillna({'usuarios.consumoUsuarios' : 0
                          ,'usuarios.consumoUsuariosDescarga':0
                          ,'usuarios.consumoUsuariosCarga':0},inplace=True)
usuariosConectados = pd.merge(usuariosConectados,datos_dev[['usuarios.apGroup','usuarios.macRed']], on ='usuarios.macRed', how='left')
usuariosConectados.fillna({'usuarios.apGroup':'No identificado'},inplace=True)
usuariosConectados['usuarios.usuariosConectados'] = usuariosConectados['usuarios.usuariosConectados'].astype(int)
usuariosConectados = usuariosConectados.rename(columns={'fecha_control':'usuarios.fechaControl'
                                                       ,'site_id' : 'usuarios.siteID'})

usuariosConectados["usuarios.fecha"] = usuariosConectados["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[0]
usuariosConectados["usuarios.anyo"] = usuariosConectados["usuarios.fecha"].str[0:4]
usuariosConectados["usuarios.mes"] = usuariosConectados["usuarios.fecha"].str[5:7]
usuariosConectados["usuarios.dia"] = usuariosConectados["usuarios.fecha"].str[8:10]
usuariosConectados["usuarios.hora"] = usuariosConectados["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[0]
usuariosConectados["usuarios.minuto"] = usuariosConectados["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[1]

usuariosConectados['nombreDepartamento'] = usuariosConectados['usuarios.nombreDepartamento']
usuariosConectados['nombreMunicipio'] = usuariosConectados['usuarios.nombreMunicipio']
usuariosConectados['idBeneficiario'] = usuariosConectados['usuarios.idBeneficiario']
usuariosConectados['fecha'] = usuariosConectados['usuarios.fecha']
usuariosConectados['anyo'] = usuariosConectados['usuarios.anyo']
usuariosConectados['mes'] = usuariosConectados['usuarios.mes']
usuariosConectados['dia'] = usuariosConectados['usuarios.dia']

# %%
datos_logins.columns
# Out:
# Index(['fecha_control', 'site_id', 'usuarios.macRed',
#        'usuarios.sesiones_Usuarios'],
#       dtype='object')

# %%
 result1=pd.merge(datos_registro, tiempoPromedioSesionSitio,on=['usuarios.siteID'],how='inner')

# %%
 result1
# Out:
#     usuarios.fecha_x usuarios.siteID  usuarios.usuariosRegistrados  \
# 0         2021-06-07   13253-ZGYO527                             3
# 1         2021-06-07   13253-ZGYO527                             3
# 2         2021-06-07   13253-ZGYO527                             3
# 3         2021-06-07   13253-ZGYO527                             3
# 4         2021-06-07   13253-ZGYO527                             3
# ..               ...             ...                           ...
# 287       2021-06-07   73868-ZGYO254                             1
# 288       2021-06-07   73868-ZGYO254                             1
# 289       2021-06-07   73868-ZGYO254                             1
# 290       2021-06-07   73868-ZGYO254                             1
# 291       2021-06-07   73868-ZGYO254                             1
#
#     usuarios.anyo_x usuarios.mes_x usuarios.dia_x  \
# 0              2021             06             07
# 1              2021             06             07
# 2              2021             06             07
# 3              2021             06             07
# 4              2021             06             07
# ..              ...            ...            ...
# 287            2021             06             07
# 288            2021             06             07
# 289            2021             06             07
# 290            2021             06             07
# 291            2021             06             07
#
#                            usuarios.nomCentroDigital_x usuarios.codISO_x  \
# 0                                              EL JABO            CO-CES
# 1                                              EL JABO            CO-CES
# 2                                              EL JABO            CO-CES
# 3                                              EL JABO            CO-CES
# 4                                              EL JABO            CO-CES
# ..                                                 ...               ...
# 287  CENTRO ETNOEDUCATIVO RURAL SAN LORENZO DE SHIR...            CO-LAG
# 288  CENTRO ETNOEDUCATIVO RURAL SAN LORENZO DE SHIR...            CO-LAG
# 289  CENTRO ETNOEDUCATIVO RURAL SAN LORENZO DE SHIR...            CO-LAG
# 290  CENTRO ETNOEDUCATIVO RURAL SAN LORENZO DE SHIR...            CO-LAG
# 291  CENTRO ETNOEDUCATIVO RURAL SAN LORENZO DE SHIR...            CO-LAG
#
#     usuarios.localidad_x usuarios.nombreDepartamento_x  ... usuarios.hora  \
# 0                EL JABO                         CESAR  ...            00
# 1                EL JABO                         CESAR  ...            00
# 2                EL JABO                         CESAR  ...            00
# 3                EL JABO                         CESAR  ...            00
# 4                EL JABO                         CESAR  ...            00
# ..                   ...                           ...  ...           ...
# 287              SHIRURI                    LA GUAJIRA  ...            00
# 288              SHIRURI                    LA GUAJIRA  ...            00
# 289              SHIRURI                    LA GUAJIRA  ...            00
# 290              SHIRURI                    LA GUAJIRA  ...            00
# 291              SHIRURI                    LA GUAJIRA  ...            00
#
#     usuarios.minuto  nombreDepartamento_y nombreMunicipio_y idBeneficiario_y  \
# 0                10                 CESAR        VALLEDUPAR            13253
# 1                20                 CESAR        VALLEDUPAR            13253
# 2                30                 CESAR        VALLEDUPAR            13253
# 3                40                 CESAR        VALLEDUPAR            13253
# 4                30                 CESAR        VALLEDUPAR            13253
# ..              ...                   ...               ...              ...
# 287              40            LA GUAJIRA           MANAURE            73868
# 288              10            LA GUAJIRA           MANAURE            73868
# 289              00            LA GUAJIRA           MANAURE            73868
# 290              10            LA GUAJIRA           MANAURE            73868
# 291              20            LA GUAJIRA           MANAURE            73868
#
#         fecha_y  anyo_y mes_y dia_y                @timestamp_y
# 0    2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 1    2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 2    2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 3    2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 4    2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# ..          ...     ...   ...   ...                         ...
# 287  2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 288  2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 289  2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 290  2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
# 291  2021-06-07    2021    06    07  2021-08-09T22:26:01.102495
#
# [292 rows x 50 columns]

# %%
 result2=pd.merge(result1, usuariosConectados,on=['usuarios.siteID'],how='inner')

# %%
result2
# Out:
#    usuarios.fecha_x usuarios.siteID  usuarios.usuariosRegistrados  \
# 0        2021-06-07   20006-ZGYO924                             3
# 1        2021-06-07   26489-ZGYO602                             8
# 2        2021-06-07   26489-ZGYO602                             8
# 3        2021-06-07   26489-ZGYO602                             8
# 4        2021-06-07   26489-ZGYO602                             8
# 5        2021-06-07   26489-ZGYO602                             8
# 6        2021-06-07   26489-ZGYO602                             8
# 7        2021-06-07   26489-ZGYO602                             8
# 8        2021-06-07   26489-ZGYO602                             8
# 9        2021-06-07   26489-ZGYO602                             8
# 10       2021-06-07   26489-ZGYO602                             8
# 11       2021-06-07   26489-ZGYO602                             8
# 12       2021-06-07   26489-ZGYO602                             8
# 13       2021-06-07   26489-ZGYO602                             8
# 14       2021-06-07   26489-ZGYO602                             8
# 15       2021-06-07   32069-ZZZY833                             2
# 16       2021-06-07   32069-ZZZY833                             2
# 17       2021-06-07   32069-ZZZY833                             2
# 18       2021-06-07   32069-ZZZY833                             2
# 19       2021-06-07   32485-ZGYO857                             8
# 20       2021-06-07   47804-ZZZY912                            11
# 21       2021-06-07   47804-ZZZY912                            11
# 22       2021-06-07   70348-ZGYO530                             4
#
#    usuarios.anyo_x usuarios.mes_x usuarios.dia_x  \
# 0             2021             06             07
# 1             2021             06             07
# 2             2021             06             07
# 3             2021             06             07
# 4             2021             06             07
# 5             2021             06             07
# 6             2021             06             07
# 7             2021             06             07
# 8             2021             06             07
# 9             2021             06             07
# 10            2021             06             07
# 11            2021             06             07
# 12            2021             06             07
# 13            2021             06             07
# 14            2021             06             07
# 15            2021             06             07
# 16            2021             06             07
# 17            2021             06             07
# 18            2021             06             07
# 19            2021             06             07
# 20            2021             06             07
# 21            2021             06             07
# 22            2021             06             07
#
#                           usuarios.nomCentroDigital_x usuarios.codISO_x  \
# 0                                  I. E. LLANO GRANDE            CO-ANT
# 1   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 2   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 3   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 4   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 5   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 6   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 7   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 8   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 9   INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 10  INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 11  INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 12  INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 13  INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 14  INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...            CO-CAL
# 15                          CENT EDUC PICA PICA VIEJO            CO-COR
# 16                          CENT EDUC PICA PICA VIEJO            CO-COR
# 17                          CENT EDUC PICA PICA VIEJO            CO-COR
# 18                          CENT EDUC PICA PICA VIEJO            CO-COR
# 19                                        LA CHAMARRA            CO-COR
# 20                           SEDE 7  NICOLAS ESGUERRA            CO-TOL
# 21                           SEDE 7  NICOLAS ESGUERRA            CO-TOL
# 22                           ESCUELA RURAL DIOS ME VE            CO-CES
#
#    usuarios.localidad_x usuarios.nombreDepartamento_x  ... usuarios.dia  \
# 0      CORREG. MARSELLA                     ANTIOQUIA  ...           07
# 1          SAN JERONIMO                        CALDAS  ...           07
# 2          SAN JERONIMO                        CALDAS  ...           07
# 3          SAN JERONIMO                        CALDAS  ...           07
# 4          SAN JERONIMO                        CALDAS  ...           07
# 5          SAN JERONIMO                        CALDAS  ...           07
# 6          SAN JERONIMO                        CALDAS  ...           07
# 7          SAN JERONIMO                        CALDAS  ...           07
# 8          SAN JERONIMO                        CALDAS  ...           07
# 9          SAN JERONIMO                        CALDAS  ...           07
# 10         SAN JERONIMO                        CALDAS  ...           07
# 11         SAN JERONIMO                        CALDAS  ...           07
# 12         SAN JERONIMO                        CALDAS  ...           07
# 13         SAN JERONIMO                        CALDAS  ...           07
# 14         SAN JERONIMO                        CALDAS  ...           07
# 15      PICA PICA VIEJO                       CÓRDOBA  ...           07
# 16      PICA PICA VIEJO                       CÓRDOBA  ...           07
# 17      PICA PICA VIEJO                       CÓRDOBA  ...           07
# 18      PICA PICA VIEJO                       CÓRDOBA  ...           07
# 19          LA CHAMARRA                       CÓRDOBA  ...           07
# 20       PASTALES NUEVO                        TOLIMA  ...           07
# 21       PASTALES NUEVO                        TOLIMA  ...           07
# 22           DIOS ME VE                         CESAR  ...           07
#
#    usuarios.hora_y  usuarios.minuto_y nombreDepartamento    nombreMunicipio  \
# 0               00                 00          ANTIOQUIA           FREDONIA
# 1               00                 00             CALDAS           RIOSUCIO
# 2               00                 00             CALDAS           RIOSUCIO
# 3               00                 00             CALDAS           RIOSUCIO
# 4               00                 00             CALDAS           RIOSUCIO
# 5               00                 00             CALDAS           RIOSUCIO
# 6               00                 00             CALDAS           RIOSUCIO
# 7               00                 00             CALDAS           RIOSUCIO
# 8               00                 00             CALDAS           RIOSUCIO
# 9               00                 00             CALDAS           RIOSUCIO
# 10              00                 00             CALDAS           RIOSUCIO
# 11              00                 00             CALDAS           RIOSUCIO
# 12              00                 00             CALDAS           RIOSUCIO
# 13              00                 00             CALDAS           RIOSUCIO
# 14              00                 00             CALDAS           RIOSUCIO
# 15              00                 00            CÓRDOBA  PUERTO LIBERTADOR
# 16              00                 00            CÓRDOBA  PUERTO LIBERTADOR
# 17              00                 00            CÓRDOBA  PUERTO LIBERTADOR
# 18              00                 00            CÓRDOBA  PUERTO LIBERTADOR
# 19              00                 00            CÓRDOBA         SAN PELAYO
# 20              00                 00             TOLIMA             IBAGUÉ
# 21              00                 00             TOLIMA             IBAGUÉ
# 22              00                 00              CESAR        CHIMICHAGUA
#
#    idBeneficiario       fecha  anyo mes dia
# 0           20006  2021-06-07  2021  06  07
# 1           26489  2021-06-07  2021  06  07
# 2           26489  2021-06-07  2021  06  07
# 3           26489  2021-06-07  2021  06  07
# 4           26489  2021-06-07  2021  06  07
# 5           26489  2021-06-07  2021  06  07
# 6           26489  2021-06-07  2021  06  07
# 7           26489  2021-06-07  2021  06  07
# 8           26489  2021-06-07  2021  06  07
# 9           26489  2021-06-07  2021  06  07
# 10          26489  2021-06-07  2021  06  07
# 11          26489  2021-06-07  2021  06  07
# 12          26489  2021-06-07  2021  06  07
# 13          26489  2021-06-07  2021  06  07
# 14          26489  2021-06-07  2021  06  07
# 15          32069  2021-06-07  2021  06  07
# 16          32069  2021-06-07  2021  06  07
# 17          32069  2021-06-07  2021  06  07
# 18          32069  2021-06-07  2021  06  07
# 19          32485  2021-06-07  2021  06  07
# 20          47804  2021-06-07  2021  06  07
# 21          47804  2021-06-07  2021  06  07
# 22          70348  2021-06-07  2021  06  07
#
# [23 rows x 76 columns]

# %%
result=pd.merge(result2, datos_recurrencia,on=['usuarios.siteID'],how='inner')

# %%
result
# Out:
# Empty DataFrame
# Columns: [usuarios.fecha_x, usuarios.siteID, usuarios.usuariosRegistrados, usuarios.anyo_x, usuarios.mes_x, usuarios.dia_x, usuarios.nomCentroDigital_x, usuarios.codISO_x, usuarios.localidad_x, usuarios.nombreDepartamento_x, usuarios.sistemaEnergia_x, usuarios.nombreMunicipio_x, usuarios.idBeneficiario_x, usuarios.location_x, nombreDepartamento_x, nombreMunicipio_x, idBeneficiario_x, fecha_x, anyo_x, mes_x, dia_x, @timestamp_x, usuarios.macRed_x, usuarios.fechaControl_x, usuarios.tiempoPromedioSesionSitio, usuarios.nomCentroDigital_y, usuarios.codISO_y, usuarios.localidad_y, usuarios.nombreDepartamento_y, usuarios.sistemaEnergia_y, usuarios.nombreMunicipio_y, usuarios.idBeneficiario_y, usuarios.location_y, usuarios.apGroup_x, ip, status, usuarios.fecha_y, usuarios.anyo_y, usuarios.mes_y, usuarios.dia_y, usuarios.hora_x, usuarios.minuto_x, nombreDepartamento_y, nombreMunicipio_y, idBeneficiario_y, fecha_y, anyo_y, mes_y, dia_y, @timestamp_y, usuarios.nomCentroDigital_x, usuarios.codISO_x, usuarios.localidad_x, usuarios.nombreDepartamento_x, usuarios.sistemaEnergia_x, usuarios.nombreMunicipio_x, usuarios.idBeneficiario_x, usuarios.location_x, usuarios.fechaControl_y, usuarios.macRed_y, usuarios.usuariosConectados, usuarios.sesiones_Usuarios, usuarios.apGroup_y, usuarios.fecha_x, usuarios.anyo_x, usuarios.mes_x, usuarios.dia_x, usuarios.hora_y, usuarios.minuto_y, nombreDepartamento_x, nombreMunicipio_x, idBeneficiario_x, fecha_x, anyo_x, mes_x, dia_x, usuarios.nomCentroDigital_y, usuarios.codISO_y, usuarios.localidad_y, usuarios.nombreDepartamento_y, usuarios.sistemaEnergia_y, usuarios.nombreMunicipio_y, usuarios.idBeneficiario_y, usuarios.location_y, usuarios.fechaControl, usuarios.usuariosNuevos, usuarios.totales.usuariosNuevos, usuarios.fecha_y, usuarios.anyo_y, usuarios.mes_y, usuarios.dia_y, usuarios.hora, usuarios.minuto, nombreDepartamento_y, nombreMunicipio_y, idBeneficiario_y, fecha_y, anyo_y, mes_y, dia_y]
# Index: []
#
# [0 rows x 100 columns]

# %%
datos_recurrencia
# Out:
#           usuarios.nomCentroDigital usuarios.codISO usuarios.localidad  \
# 0              ESC NVA PIEDRA ABAJO          CO-COR  VDA PIEDRAS ABAJO
# 1                    SEDE PRINCIPAL          CO-COR     PUEBLECITO SUR
# 2  I.E. DON ALONSO - SEDE PRINCIPAL          CO-SUC         DON ALONSO
# 3            JAGUALITO PUEBLO NUEVO          CO-TOL       PUEBLO NUEVO
#
#   usuarios.siteID usuarios.nombreDepartamento usuarios.sistemaEnergia  \
# 0   31505-ZZZY232                     CÓRDOBA      RED INTERCONECTADA
# 1   32284-ZZZY240                     CÓRDOBA      RED INTERCONECTADA
# 2   47119-ZZZY211                       SUCRE      RED INTERCONECTADA
# 3   48605-ZGYO579                      TOLIMA      RED INTERCONECTADA
#
#   usuarios.nombreMunicipio  usuarios.idBeneficiario  \
# 0           CIÉNAGA DE ORO                    31505
# 1  SAN ANDRÉS DE SOTAVENTO                    32284
# 2                  COROZAL                    47119
# 3                    GUAMO                    48605
#
#            usuarios.location usuarios.fechaControl  ... usuarios.dia  \
# 0    7.9471111,-73.656805000   2021-06-07 00:00:00  ...           07
# 1     9.3517975,-75.79683054   2021-06-07 00:00:00  ...           07
# 2    9.25824627,-75.31213588   2021-06-07 00:00:00  ...           07
# 3  4.000838889,-74.894555556   2021-06-07 00:00:00  ...           07
#
#    usuarios.hora usuarios.minuto nombreDepartamento          nombreMunicipio  \
# 0             00              00            CÓRDOBA           CIÉNAGA DE ORO
# 1             00              00            CÓRDOBA  SAN ANDRÉS DE SOTAVENTO
# 2             00              00              SUCRE                  COROZAL
# 3             00              00             TOLIMA                    GUAMO
#
#   idBeneficiario       fecha  anyo mes dia
# 0          31505  2021-06-07  2021  06  07
# 1          32284  2021-06-07  2021  06  07
# 2          47119  2021-06-07  2021  06  07
# 3          48605  2021-06-07  2021  06  07
#
# [4 rows x 25 columns]

# %%
try:
    result1=pd.merge(datos_registro, tiempoPromedioSesionSitio,on=['usuarios.siteID'],how='inner')
    result2=pd.merge(result1, usuariosConectados,on=['usuarios.siteID'],how='inner')
    result=pd.merge(result2, datos_recurrencia,on=['usuarios.siteID'],how='left')
    #salida = helpers.bulk(es, doc_generator(result,use_these_keys))
    result.fillna('', inplace=True)
    #result['usuarios.fechaControl'] = fecha_ejecucion
    result['usuarios.fecha_x'] = fecha_ejecucion[0:4] + '-' + fecha_ejecucion[5:7] + '-' + fecha_ejecucion[8:10]
    #result['usuarios.location_x'] = "0.0000000,0.0000000"
    
    salida = helpers.bulk(es, doc_generator(result))
    print("Fecha: ", now,"- Cantidad de registros insertado en indice principal:",salida[0])
except Exception as e:
    print(e)
    print("Fecha: ", now,"- Nada para insertar en indice principal")
# Out:
# ('22 document(s) failed to index.', [{'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-20006-ZGYO924-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 0, dtype: object389', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-20006-ZGYO924-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 0, dtype: object389'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 0, dtype: object, 'usuarios.siteID': '20006-ZGYO924', 'usuarios.usuariosRegistrados': 3, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 0, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 0, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 0, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    I. E. LLANO GRANDE
# usuarios.nomCentroDigital    I. E. LLANO GRANDE
# Name: 0, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-ANT
# usuarios.codISO    CO-ANT
# Name: 0, dtype: object, 'usuarios.localidad': usuarios.localidad    CORREG. MARSELLA
# usuarios.localidad    CORREG. MARSELLA
# Name: 0, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    ANTIOQUIA
# usuarios.nombreDepartamento    ANTIOQUIA
# Name: 0, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 0, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    FREDONIA
# usuarios.nombreMunicipio    FREDONIA
# Name: 0, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    20006
# usuarios.idBeneficiario    20006
# Name: 0, dtype: object, 'usuarios.location': usuarios.location    8.8740277,-73.750583
# usuarios.location    8.8740277,-73.750583
# Name: 0, dtype: object, 'usuarios.macRed': '54:F2:01:D2:61:CE', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:00:00
# usuarios.fechaControl
# Name: 0, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 120.0, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 1, 'usuarios.usuariosConectados': 1, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    ANTIOQUIA
# nombreDepartamento    ANTIOQUIA
# Name: 0, dtype: object, 'nombreMunicipio': nombreMunicipio    FREDONIA
# nombreMunicipio    FREDONIA
# Name: 0, dtype: object, 'idBeneficiario': idBeneficiario    20006
# idBeneficiario    20006
# Name: 0, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 0, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 0, dtype: object, 'mes': mes    06
# mes    06
# Name: 0, dtype: object, 'dia': dia    07
# dia    07
# Name: 0, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 1, dtype: object854', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 1, dtype: object854'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 1, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 1, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 1, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 1, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 1, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 1, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 1, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 1, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 1, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 1, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 1, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 1, dtype: object, 'usuarios.macRed': '00:B5:D0:78:81:A5', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:20:00
# usuarios.fechaControl
# Name: 1, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 4.22, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 1, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 1, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 1, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 1, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 1, dtype: object, 'mes': mes    06
# mes    06
# Name: 1, dtype: object, 'dia': dia    07
# dia    07
# Name: 1, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 2, dtype: object196', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 2, dtype: object196'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 2, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 2, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 2, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 2, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 2, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 2, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 2, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 2, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 2, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 2, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 2, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 2, dtype: object, 'usuarios.macRed': '02:7F:F2:96:B3:B6', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:10:00
# usuarios.fechaControl
# Name: 2, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 1.58, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 2, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 2, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 2, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 2, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 2, dtype: object, 'mes': mes    06
# mes    06
# Name: 2, dtype: object, 'dia': dia    07
# dia    07
# Name: 2, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 3, dtype: object604', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 3, dtype: object604'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 3, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 3, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 3, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 3, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 3, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 3, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 3, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 3, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 3, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 3, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 3, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 3, dtype: object, 'usuarios.macRed': '02:7F:F2:96:B3:B6', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:20:00
# usuarios.fechaControl
# Name: 3, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 11.17, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 3, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 3, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 3, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 3, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 3, dtype: object, 'mes': mes    06
# mes    06
# Name: 3, dtype: object, 'dia': dia    07
# dia    07
# Name: 3, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 4, dtype: object751', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 4, dtype: object751'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 4, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 4, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 4, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 4, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 4, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 4, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 4, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 4, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 4, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 4, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 4, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 4, dtype: object, 'usuarios.macRed': '02:7F:F2:96:B3:B6', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:30:00
# usuarios.fechaControl
# Name: 4, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 3.355, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 4, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 4, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 4, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 4, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 4, dtype: object, 'mes': mes    06
# mes    06
# Name: 4, dtype: object, 'dia': dia    07
# dia    07
# Name: 4, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 5, dtype: object574', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 5, dtype: object574'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 5, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 5, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 5, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 5, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 5, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 5, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 5, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 5, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 5, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 5, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 5, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 5, dtype: object, 'usuarios.macRed': '14:96:E5:E5:6F:9B', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:20:00
# usuarios.fechaControl
# Name: 5, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 25.58, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 5, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 5, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 5, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 5, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 5, dtype: object, 'mes': mes    06
# mes    06
# Name: 5, dtype: object, 'dia': dia    07
# dia    07
# Name: 5, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 6, dtype: object66', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 6, dtype: object66'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 6, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 6, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 6, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 6, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 6, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 6, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 6, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 6, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 6, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 6, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 6, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 6, dtype: object, 'usuarios.macRed': '1C:B7:96:35:D7:D7', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:10:00
# usuarios.fechaControl
# Name: 6, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 120.0, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 6, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 6, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 6, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 6, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 6, dtype: object, 'mes': mes    06
# mes    06
# Name: 6, dtype: object, 'dia': dia    07
# dia    07
# Name: 6, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 7, dtype: object200', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 7, dtype: object200'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 7, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 7, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 7, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 7, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 7, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 7, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 7, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 7, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 7, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 7, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 7, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 7, dtype: object, 'usuarios.macRed': '1E:D9:6B:47:2E:99', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:00:00
# usuarios.fechaControl
# Name: 7, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 120.0, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 7, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 7, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 7, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 7, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 7, dtype: object, 'mes': mes    06
# mes    06
# Name: 7, dtype: object, 'dia': dia    07
# dia    07
# Name: 7, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 8, dtype: object330', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 8, dtype: object330'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 8, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 8, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 8, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 8, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 8, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 8, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 8, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 8, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 8, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 8, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 8, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 8, dtype: object, 'usuarios.macRed': '60:14:66:E1:B4:B4', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:00:00
# usuarios.fechaControl
# Name: 8, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 36.48, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 8, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 8, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 8, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 8, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 8, dtype: object, 'mes': mes    06
# mes    06
# Name: 8, dtype: object, 'dia': dia    07
# dia    07
# Name: 8, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 9, dtype: object517', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 9, dtype: object517'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 9, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 9, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 9, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 9, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 9, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 9, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 9, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 9, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 9, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 9, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 9, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 9, dtype: object, 'usuarios.macRed': 'B4:1C:30:D9:0F:F9', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:00:00
# usuarios.fechaControl
# Name: 9, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 0.27, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 9, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 9, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 9, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 9, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 9, dtype: object, 'mes': mes    06
# mes    06
# Name: 9, dtype: object, 'dia': dia    07
# dia    07
# Name: 9, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 10, dtype: object365', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 10, dtype: object365'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 10, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 10, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 10, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 10, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 10, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 10, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 10, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 10, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 10, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 10, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 10, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 10, dtype: object, 'usuarios.macRed': 'C8:C7:50:11:94:92', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:10:00
# usuarios.fechaControl
# Name: 10, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 25.15, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 10, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 10, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 10, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 10, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 10, dtype: object, 'mes': mes    06
# mes    06
# Name: 10, dtype: object, 'dia': dia    07
# dia    07
# Name: 10, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 11, dtype: object690', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 11, dtype: object690'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 11, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 11, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 11, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 11, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 11, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 11, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 11, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 11, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 11, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 11, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 11, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 11, dtype: object, 'usuarios.macRed': 'C8:C7:50:11:94:92', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:40:00
# usuarios.fechaControl
# Name: 11, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 2.05, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 11, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 11, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 11, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 11, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 11, dtype: object, 'mes': mes    06
# mes    06
# Name: 11, dtype: object, 'dia': dia    07
# dia    07
# Name: 11, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 12, dtype: object845', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 12, dtype: object845'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 12, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 12, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 12, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 12, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 12, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 12, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 12, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 12, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 12, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 12, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 12, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 12, dtype: object, 'usuarios.macRed': 'DC:BF:E9:28:42:79', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:20:00
# usuarios.fechaControl
# Name: 12, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 2.945, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 12, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 12, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 12, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 12, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 12, dtype: object, 'mes': mes    06
# mes    06
# Name: 12, dtype: object, 'dia': dia    07
# dia    07
# Name: 12, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 13, dtype: object299', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 13, dtype: object299'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 13, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 13, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 13, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 13, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 13, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 13, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 13, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 13, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 13, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 13, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 13, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 13, dtype: object, 'usuarios.macRed': 'DC:BF:E9:28:42:79', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:40:00
# usuarios.fechaControl
# Name: 13, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 0.466667, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 13, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 13, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 13, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 13, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 13, dtype: object, 'mes': mes    06
# mes    06
# Name: 13, dtype: object, 'dia': dia    07
# dia    07
# Name: 13, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 14, dtype: object966', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-26489-ZGYO602-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 14, dtype: object966'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 14, dtype: object, 'usuarios.siteID': '26489-ZGYO602', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 14, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 14, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 14, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# usuarios.nomCentroDigital    INSTITUCION EDUCATIVA SAN JERONIMO - SEDE PRIN...
# Name: 14, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-CAL
# usuarios.codISO    CO-CAL
# Name: 14, dtype: object, 'usuarios.localidad': usuarios.localidad    SAN JERONIMO
# usuarios.localidad    SAN JERONIMO
# Name: 14, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CALDAS
# usuarios.nombreDepartamento    CALDAS
# Name: 14, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 14, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    RIOSUCIO
# usuarios.nombreMunicipio    RIOSUCIO
# Name: 14, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    26489
# usuarios.idBeneficiario    26489
# Name: 14, dtype: object, 'usuarios.location': usuarios.location    5.45291851,-75.68882468
# usuarios.location    5.45291851,-75.68882468
# Name: 14, dtype: object, 'usuarios.macRed': 'E6:1E:98:17:40:3B', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:20:00
# usuarios.fechaControl
# Name: 14, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 15.36, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 2, 'usuarios.usuariosConectados': 2, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CALDAS
# nombreDepartamento    CALDAS
# Name: 14, dtype: object, 'nombreMunicipio': nombreMunicipio    RIOSUCIO
# nombreMunicipio    RIOSUCIO
# Name: 14, dtype: object, 'idBeneficiario': idBeneficiario    26489
# idBeneficiario    26489
# Name: 14, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 14, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 14, dtype: object, 'mes': mes    06
# mes    06
# Name: 14, dtype: object, 'dia': dia    07
# dia    07
# Name: 14, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-32069-ZZZY833-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 15, dtype: object868', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-32069-ZZZY833-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 15, dtype: object868'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 15, dtype: object, 'usuarios.siteID': '32069-ZZZY833', 'usuarios.usuariosRegistrados': 2, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 15, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 15, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 15, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    CENT EDUC PICA PICA VIEJO
# usuarios.nomCentroDigital    CENT EDUC PICA PICA VIEJO
# Name: 15, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-COR
# usuarios.codISO    CO-COR
# Name: 15, dtype: object, 'usuarios.localidad': usuarios.localidad    PICA PICA VIEJO
# usuarios.localidad    PICA PICA VIEJO
# Name: 15, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CÓRDOBA
# usuarios.nombreDepartamento    CÓRDOBA
# Name: 15, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 15, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    PUERTO LIBERTADOR
# usuarios.nombreMunicipio    PUERTO LIBERTADOR
# Name: 15, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    32069
# usuarios.idBeneficiario    32069
# Name: 15, dtype: object, 'usuarios.location': usuarios.location    9.026666667,-75.603333333
# usuarios.location    9.026666667,-75.603333333
# Name: 15, dtype: object, 'usuarios.macRed': 'C8:D7:B0:E9:03:4F', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:00:00
# usuarios.fechaControl
# ...
# nombreDepartamento    CÓRDOBA
# Name: 16, dtype: object, 'nombreMunicipio': nombreMunicipio    PUERTO LIBERTADOR
# nombreMunicipio    PUERTO LIBERTADOR
# Name: 16, dtype: object, 'idBeneficiario': idBeneficiario    32069
# idBeneficiario    32069
# Name: 16, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 16, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 16, dtype: object, 'mes': mes    06
# mes    06
# Name: 16, dtype: object, 'dia': dia    07
# dia    07
# Name: 16, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-32069-ZZZY833-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 17, dtype: object80', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-32069-ZZZY833-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 17, dtype: object80'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 17, dtype: object, 'usuarios.siteID': '32069-ZZZY833', 'usuarios.usuariosRegistrados': 2, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 17, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 17, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 17, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    CENT EDUC PICA PICA VIEJO
# usuarios.nomCentroDigital    CENT EDUC PICA PICA VIEJO
# Name: 17, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-COR
# usuarios.codISO    CO-COR
# Name: 17, dtype: object, 'usuarios.localidad': usuarios.localidad    PICA PICA VIEJO
# usuarios.localidad    PICA PICA VIEJO
# Name: 17, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CÓRDOBA
# usuarios.nombreDepartamento    CÓRDOBA
# Name: 17, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 17, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    PUERTO LIBERTADOR
# usuarios.nombreMunicipio    PUERTO LIBERTADOR
# Name: 17, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    32069
# usuarios.idBeneficiario    32069
# Name: 17, dtype: object, 'usuarios.location': usuarios.location    9.026666667,-75.603333333
# usuarios.location    9.026666667,-75.603333333
# Name: 17, dtype: object, 'usuarios.macRed': 'C8:D7:B0:E9:03:4F', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:20:00
# usuarios.fechaControl
# Name: 17, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 1.821667, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 1, 'usuarios.usuariosConectados': 1, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CÓRDOBA
# nombreDepartamento    CÓRDOBA
# Name: 17, dtype: object, 'nombreMunicipio': nombreMunicipio    PUERTO LIBERTADOR
# nombreMunicipio    PUERTO LIBERTADOR
# Name: 17, dtype: object, 'idBeneficiario': idBeneficiario    32069
# idBeneficiario    32069
# Name: 17, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 17, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 17, dtype: object, 'mes': mes    06
# mes    06
# Name: 17, dtype: object, 'dia': dia    07
# dia    07
# Name: 17, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-32069-ZZZY833-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 18, dtype: object823', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-32069-ZZZY833-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 18, dtype: object823'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 18, dtype: object, 'usuarios.siteID': '32069-ZZZY833', 'usuarios.usuariosRegistrados': 2, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 18, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 18, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 18, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    CENT EDUC PICA PICA VIEJO
# usuarios.nomCentroDigital    CENT EDUC PICA PICA VIEJO
# Name: 18, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-COR
# usuarios.codISO    CO-COR
# Name: 18, dtype: object, 'usuarios.localidad': usuarios.localidad    PICA PICA VIEJO
# usuarios.localidad    PICA PICA VIEJO
# Name: 18, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CÓRDOBA
# usuarios.nombreDepartamento    CÓRDOBA
# Name: 18, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 18, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    PUERTO LIBERTADOR
# usuarios.nombreMunicipio    PUERTO LIBERTADOR
# Name: 18, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    32069
# usuarios.idBeneficiario    32069
# Name: 18, dtype: object, 'usuarios.location': usuarios.location    9.026666667,-75.603333333
# usuarios.location    9.026666667,-75.603333333
# Name: 18, dtype: object, 'usuarios.macRed': 'C8:D7:B0:E9:03:4F', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:30:00
# usuarios.fechaControl
# Name: 18, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 4.61625, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 1, 'usuarios.usuariosConectados': 1, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CÓRDOBA
# nombreDepartamento    CÓRDOBA
# Name: 18, dtype: object, 'nombreMunicipio': nombreMunicipio    PUERTO LIBERTADOR
# nombreMunicipio    PUERTO LIBERTADOR
# Name: 18, dtype: object, 'idBeneficiario': idBeneficiario    32069
# idBeneficiario    32069
# Name: 18, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 18, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 18, dtype: object, 'mes': mes    06
# mes    06
# Name: 18, dtype: object, 'dia': dia    07
# dia    07
# Name: 18, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-32485-ZGYO857-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 19, dtype: object579', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-32485-ZGYO857-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 19, dtype: object579'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 19, dtype: object, 'usuarios.siteID': '32485-ZGYO857', 'usuarios.usuariosRegistrados': 8, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 19, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 19, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 19, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    LA CHAMARRA
# usuarios.nomCentroDigital    LA CHAMARRA
# Name: 19, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-COR
# usuarios.codISO    CO-COR
# Name: 19, dtype: object, 'usuarios.localidad': usuarios.localidad    LA CHAMARRA
# usuarios.localidad    LA CHAMARRA
# Name: 19, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    CÓRDOBA
# usuarios.nombreDepartamento    CÓRDOBA
# Name: 19, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 19, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    SAN PELAYO
# usuarios.nombreMunicipio    SAN PELAYO
# Name: 19, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    32485
# usuarios.idBeneficiario    32485
# Name: 19, dtype: object, 'usuarios.location': usuarios.location    9.36646031,-75.454680080
# usuarios.location    9.36646031,-75.454680080
# Name: 19, dtype: object, 'usuarios.macRed': 'B0:55:08:4A:08:E9', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:00:00
# usuarios.fechaControl
# Name: 19, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 20.54, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 1, 'usuarios.usuariosConectados': 1, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    CÓRDOBA
# nombreDepartamento    CÓRDOBA
# Name: 19, dtype: object, 'nombreMunicipio': nombreMunicipio    SAN PELAYO
# nombreMunicipio    SAN PELAYO
# Name: 19, dtype: object, 'idBeneficiario': idBeneficiario    32485
# idBeneficiario    32485
# Name: 19, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 19, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 19, dtype: object, 'mes': mes    06
# mes    06
# Name: 19, dtype: object, 'dia': dia    07
# dia    07
# Name: 19, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-47804-ZZZY912-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 20, dtype: object491', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-47804-ZZZY912-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 20, dtype: object491'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 20, dtype: object, 'usuarios.siteID': '47804-ZZZY912', 'usuarios.usuariosRegistrados': 11, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 20, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 20, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 20, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    SEDE 7  NICOLAS ESGUERRA
# usuarios.nomCentroDigital    SEDE 7  NICOLAS ESGUERRA
# Name: 20, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-TOL
# usuarios.codISO    CO-TOL
# Name: 20, dtype: object, 'usuarios.localidad': usuarios.localidad    PASTALES NUEVO
# usuarios.localidad    PASTALES NUEVO
# Name: 20, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    TOLIMA
# usuarios.nombreDepartamento    TOLIMA
# Name: 20, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 20, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    IBAGUÉ
# usuarios.nombreMunicipio    IBAGUÉ
# Name: 20, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    47804
# usuarios.idBeneficiario    47804
# Name: 20, dtype: object, 'usuarios.location': usuarios.location    4.58320548,-75.40562212
# usuarios.location    4.58320548,-75.40562212
# Name: 20, dtype: object, 'usuarios.macRed': '8C:F1:12:F9:31:57', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:00:00
# usuarios.fechaControl
# Name: 20, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 22.13, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 1, 'usuarios.usuariosConectados': 1, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    TOLIMA
# nombreDepartamento    TOLIMA
# Name: 20, dtype: object, 'nombreMunicipio': nombreMunicipio    IBAGUÉ
# nombreMunicipio    IBAGUÉ
# Name: 20, dtype: object, 'idBeneficiario': idBeneficiario    47804
# idBeneficiario    47804
# Name: 20, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 20, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 20, dtype: object, 'mes': mes    06
# mes    06
# Name: 20, dtype: object, 'dia': dia    07
# dia    07
# Name: 20, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}, {'index': {'_index': 'dev-usuarios-tablero12-001', '_type': '_doc', '_id': 'UsuRegistro-47804-ZZZY912-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 21, dtype: object371', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': "failed to parse field [usuarios.fechaControl] of type [date] in document with id 'UsuRegistro-47804-ZZZY912-usuarios.fecha    2021-06-07\nusuarios.fecha    2021-06-07\nName: 21, dtype: object371'. Preview of field's value: ''", 'caused_by': {'type': 'illegal_argument_exception', 'reason': 'cannot parse empty date'}}, 'data': {'usuarios.fecha': usuarios.fecha    2021-06-07
# usuarios.fecha    2021-06-07
# Name: 21, dtype: object, 'usuarios.siteID': '47804-ZZZY912', 'usuarios.usuariosRegistrados': 11, 'usuarios.anyo': usuarios.anyo    2021
# usuarios.anyo    2021
# Name: 21, dtype: object, 'usuarios.mes': usuarios.mes    06
# usuarios.mes    06
# Name: 21, dtype: object, 'usuarios.dia': usuarios.dia    07
# usuarios.dia    07
# Name: 21, dtype: object, 'usuarios.nomCentroDigital': usuarios.nomCentroDigital    SEDE 7  NICOLAS ESGUERRA
# usuarios.nomCentroDigital    SEDE 7  NICOLAS ESGUERRA
# Name: 21, dtype: object, 'usuarios.codISO': usuarios.codISO    CO-TOL
# usuarios.codISO    CO-TOL
# Name: 21, dtype: object, 'usuarios.localidad': usuarios.localidad    PASTALES NUEVO
# usuarios.localidad    PASTALES NUEVO
# Name: 21, dtype: object, 'usuarios.nombreDepartamento': usuarios.nombreDepartamento    TOLIMA
# usuarios.nombreDepartamento    TOLIMA
# Name: 21, dtype: object, 'usuarios.sistemaEnergia': usuarios.sistemaEnergia    RED INTERCONECTADA
# usuarios.sistemaEnergia    RED INTERCONECTADA
# Name: 21, dtype: object, 'usuarios.nombreMunicipio': usuarios.nombreMunicipio    IBAGUÉ
# usuarios.nombreMunicipio    IBAGUÉ
# Name: 21, dtype: object, 'usuarios.idBeneficiario': usuarios.idBeneficiario    47804
# usuarios.idBeneficiario    47804
# Name: 21, dtype: object, 'usuarios.location': usuarios.location    4.58320548,-75.40562212
# usuarios.location    4.58320548,-75.40562212
# Name: 21, dtype: object, 'usuarios.macRed': '8C:F1:12:F9:31:57', 'usuarios.fechaControl': usuarios.fechaControl    2021-06-07 00:20:00
# usuarios.fechaControl
# Name: 21, dtype: object, 'usuarios.tiempoPromedioSesionSitio': 22.8, 'usuarios.apGroup': 'No identificado', 'usuarios.totales.usuariosNuevos': '', 'usuarios.sesiones_Usuarios': 1, 'usuarios.usuariosConectados': 1, 'ip': '', 'status': '', 'nombreDepartamento': nombreDepartamento    TOLIMA
# nombreDepartamento    TOLIMA
# Name: 21, dtype: object, 'nombreMunicipio': nombreMunicipio    IBAGUÉ
# nombreMunicipio    IBAGUÉ
# Name: 21, dtype: object, 'idBeneficiario': idBeneficiario    47804
# idBeneficiario    47804
# Name: 21, dtype: object, 'fecha': fecha    2021-06-07
# fecha    2021-06-07
# Name: 21, dtype: object, 'anyo': anyo    2021
# anyo    2021
# Name: 21, dtype: object, 'mes': mes    06
# mes    06
# Name: 21, dtype: object, 'dia': dia    07
# dia    07
# Name: 21, dtype: object, '@timestamp': '2021-08-09T22:26:01.102495'}}}])
# Fecha:  2021-08-09 22:26:01.102495 - Nada para insertar en indice principal

# %%
result.columns
# Out:
# Index(['usuarios.fecha_x', 'usuarios.siteID', 'usuarios.usuariosRegistrados',
#        'usuarios.anyo_x', 'usuarios.mes_x', 'usuarios.dia_x',
#        'usuarios.nomCentroDigital_x', 'usuarios.codISO_x',
#        'usuarios.localidad_x', 'usuarios.nombreDepartamento_x',
#        'usuarios.sistemaEnergia_x', 'usuarios.nombreMunicipio_x',
#        'usuarios.idBeneficiario_x', 'usuarios.location_x',
#        'nombreDepartamento_x', 'nombreMunicipio_x', 'idBeneficiario_x',
#        'fecha_x', 'anyo_x', 'mes_x', 'dia_x', '@timestamp_x',
#        'usuarios.macRed_x', 'usuarios.fechaControl_x',
#        'usuarios.tiempoPromedioSesionSitio', 'usuarios.nomCentroDigital_y',
#        'usuarios.codISO_y', 'usuarios.localidad_y',
#        'usuarios.nombreDepartamento_y', 'usuarios.sistemaEnergia_y',
#        'usuarios.nombreMunicipio_y', 'usuarios.idBeneficiario_y',
#        'usuarios.location_y', 'usuarios.apGroup_x', 'ip', 'status',
#        'usuarios.fecha_y', 'usuarios.anyo_y', 'usuarios.mes_y',
#        'usuarios.dia_y', 'usuarios.hora_x', 'usuarios.minuto_x',
#        'nombreDepartamento_y', 'nombreMunicipio_y', 'idBeneficiario_y',
#        'fecha_y', 'anyo_y', 'mes_y', 'dia_y', '@timestamp_y',
#        'usuarios.nomCentroDigital_x', 'usuarios.codISO_x',
#        'usuarios.localidad_x', 'usuarios.nombreDepartamento_x',
#        'usuarios.sistemaEnergia_x', 'usuarios.nombreMunicipio_x',
#        'usuarios.idBeneficiario_x', 'usuarios.location_x',
#        'usuarios.fechaControl_y', 'usuarios.macRed_y',
#        'usuarios.usuariosConectados', 'usuarios.sesiones_Usuarios',
#        'usuarios.apGroup_y', 'usuarios.fecha_x', 'usuarios.anyo_x',
#        'usuarios.mes_x', 'usuarios.dia_x', 'usuarios.hora_y',
#        'usuarios.minuto_y', 'nombreDepartamento_x', 'nombreMunicipio_x',
#        'idBeneficiario_x', 'fecha_x', 'anyo_x', 'mes_x', 'dia_x',
#        'usuarios.nomCentroDigital_y', 'usuarios.codISO_y',
#        'usuarios.localidad_y', 'usuarios.nombreDepartamento_y',
#        'usuarios.sistemaEnergia_y', 'usuarios.nombreMunicipio_y',
#        'usuarios.idBeneficiario_y', 'usuarios.location_y',
#        'usuarios.fechaControl', 'usuarios.usuariosNuevos',
#        'usuarios.totales.usuariosNuevos', 'usuarios.fecha_y',
#        'usuarios.anyo_y', 'usuarios.mes_y', 'usuarios.dia_y', 'usuarios.hora',
#        'usuarios.minuto', 'nombreDepartamento_y', 'nombreMunicipio_y',
#        'idBeneficiario_y', 'fecha_y', 'anyo_y', 'mes_y', 'dia_y'],
#       dtype='object')

# %%
#salida = helpers.bulk(es, doc_generator(result))

# %%
result
# Out:
# Empty DataFrame
# Columns: [usuarios.fecha_x, usuarios.siteID, usuarios.usuariosRegistrados, usuarios.anyo_x, usuarios.mes_x, usuarios.dia_x, usuarios.nomCentroDigital_x, usuarios.codISO_x, usuarios.localidad_x, usuarios.nombreDepartamento_x, usuarios.sistemaEnergia_x, usuarios.nombreMunicipio_x, usuarios.idBeneficiario_x, usuarios.location_x, nombreDepartamento_x, nombreMunicipio_x, idBeneficiario_x, fecha_x, anyo_x, mes_x, dia_x, @timestamp_x, usuarios.macRed_x, usuarios.fechaControl_x, usuarios.tiempoPromedioSesionSitio, usuarios.nomCentroDigital_y, usuarios.codISO_y, usuarios.localidad_y, usuarios.nombreDepartamento_y, usuarios.sistemaEnergia_y, usuarios.nombreMunicipio_y, usuarios.idBeneficiario_y, usuarios.location_y, usuarios.apGroup_x, ip, status, usuarios.fecha_y, usuarios.anyo_y, usuarios.mes_y, usuarios.dia_y, usuarios.hora_x, usuarios.minuto_x, nombreDepartamento_y, nombreMunicipio_y, idBeneficiario_y, fecha_y, anyo_y, mes_y, dia_y, @timestamp_y, usuarios.nomCentroDigital_x, usuarios.codISO_x, usuarios.localidad_x, usuarios.nombreDepartamento_x, usuarios.sistemaEnergia_x, usuarios.nombreMunicipio_x, usuarios.idBeneficiario_x, usuarios.location_x, usuarios.fechaControl_y, usuarios.macRed_y, usuarios.usuariosConectados, usuarios.sesiones_Usuarios, usuarios.apGroup_y, usuarios.fecha_x, usuarios.anyo_x, usuarios.mes_x, usuarios.dia_x, usuarios.hora_y, usuarios.minuto_y, nombreDepartamento_x, nombreMunicipio_x, idBeneficiario_x, fecha_x, anyo_x, mes_x, dia_x, usuarios.nomCentroDigital_y, usuarios.codISO_y, usuarios.localidad_y, usuarios.nombreDepartamento_y, usuarios.sistemaEnergia_y, usuarios.nombreMunicipio_y, usuarios.idBeneficiario_y, usuarios.location_y, usuarios.fechaControl, usuarios.usuariosNuevos, usuarios.totales.usuariosNuevos, usuarios.fecha_y, usuarios.anyo_y, usuarios.mes_y, usuarios.dia_y, usuarios.hora, usuarios.minuto, nombreDepartamento_y, nombreMunicipio_y, idBeneficiario_y, fecha_y, anyo_y, mes_y, dia_y]
# Index: []
#
# [0 rows x 100 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 100 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   usuarios.fecha_x                    0 non-null      object
#  1   usuarios.siteID                     0 non-null      object
#  2   usuarios.usuariosRegistrados        0 non-null      int64
#  3   usuarios.anyo_x                     0 non-null      object
#  4   usuarios.mes_x                      0 non-null      object
#  5   usuarios.dia_x                      0 non-null      object
#  6   usuarios.nomCentroDigital_x         0 non-null      object
#  7   usuarios.codISO_x                   0 non-null      object
#  8   usuarios.localidad_x                0 non-null      object
#  9   usuarios.nombreDepartamento_x       0 non-null      object
#  10  usuarios.sistemaEnergia_x           0 non-null      object
#  11  usuarios.nombreMunicipio_x          0 non-null      object
#  12  usuarios.idBeneficiario_x           0 non-null      int64
#  13  usuarios.location_x                 0 non-null      object
#  14  nombreDepartamento_x                0 non-null      object
#  15  nombreMunicipio_x                   0 non-null      object
#  16  idBeneficiario_x                    0 non-null      int64
#  17  fecha_x                             0 non-null      object
#  18  anyo_x                              0 non-null      object
#  19  mes_x                               0 non-null      object
#  20  dia_x                               0 non-null      object
#  21  @timestamp_x                        0 non-null      object
#  22  usuarios.macRed_x                   0 non-null      object
#  23  usuarios.fechaControl_x             0 non-null      object
#  24  usuarios.tiempoPromedioSesionSitio  0 non-null      float64
#  25  usuarios.nomCentroDigital_y         0 non-null      object
#  26  usuarios.codISO_y                   0 non-null      object
#  27  usuarios.localidad_y                0 non-null      object
#  28  usuarios.nombreDepartamento_y       0 non-null      object
#  29  usuarios.sistemaEnergia_y           0 non-null      object
#  30  usuarios.nombreMunicipio_y          0 non-null      object
#  31  usuarios.idBeneficiario_y           0 non-null      int64
#  32  usuarios.location_y                 0 non-null      object
#  33  usuarios.apGroup_x                  0 non-null      object
#  34  ip                                  0 non-null      object
#  35  status                              0 non-null      object
#  36  usuarios.fecha_y                    0 non-null      object
#  37  usuarios.anyo_y                     0 non-null      object
#  38  usuarios.mes_y                      0 non-null      object
#  39  usuarios.dia_y                      0 non-null      object
#  40  usuarios.hora_x                     0 non-null      object
#  41  usuarios.minuto_x                   0 non-null      object
#  42  nombreDepartamento_y                0 non-null      object
#  43  nombreMunicipio_y                   0 non-null      object
#  44  idBeneficiario_y                    0 non-null      int64
#  45  fecha_y                             0 non-null      object
#  46  anyo_y                              0 non-null      object
#  47  mes_y                               0 non-null      object
#  48  dia_y                               0 non-null      object
#  49  @timestamp_y                        0 non-null      object
#  50  usuarios.nomCentroDigital_x         0 non-null      object
#  51  usuarios.codISO_x                   0 non-null      object
#  52  usuarios.localidad_x                0 non-null      object
#  53  usuarios.nombreDepartamento_x       0 non-null      object
#  54  usuarios.sistemaEnergia_x           0 non-null      object
#  55  usuarios.nombreMunicipio_x          0 non-null      object
#  56  usuarios.idBeneficiario_x           0 non-null      int64
#  57  usuarios.location_x                 0 non-null      object
#  58  usuarios.fechaControl_y             0 non-null      object
#  59  usuarios.macRed_y                   0 non-null      object
#  60  usuarios.usuariosConectados         0 non-null      int64
#  61  usuarios.sesiones_Usuarios          0 non-null      int64
#  62  usuarios.apGroup_y                  0 non-null      object
#  63  usuarios.fecha_x                    0 non-null      object
#  64  usuarios.anyo_x                     0 non-null      object
#  65  usuarios.mes_x                      0 non-null      object
#  66  usuarios.dia_x                      0 non-null      object
#  67  usuarios.hora_y                     0 non-null      object
#  68  usuarios.minuto_y                   0 non-null      object
#  69  nombreDepartamento_x                0 non-null      object
#  70  nombreMunicipio_x                   0 non-null      object
#  71  idBeneficiario_x                    0 non-null      int64
#  72  fecha_x                             0 non-null      object
#  73  anyo_x                              0 non-null      object
#  74  mes_x                               0 non-null      object
#  75  dia_x                               0 non-null      object
#  76  usuarios.nomCentroDigital_y         0 non-null      object
#  77  usuarios.codISO_y                   0 non-null      object
#  78  usuarios.localidad_y                0 non-null      object
#  79  usuarios.nombreDepartamento_y       0 non-null      object
#  80  usuarios.sistemaEnergia_y           0 non-null      object
#  81  usuarios.nombreMunicipio_y          0 non-null      object
#  82  usuarios.idBeneficiario_y           0 non-null      int64
#  83  usuarios.location_y                 0 non-null      object
#  84  usuarios.fechaControl               0 non-null      object
#  85  usuarios.usuariosNuevos             0 non-null      object
#  86  usuarios.totales.usuariosNuevos     0 non-null      int64
#  87  usuarios.fecha_y                    0 non-null      object
#  88  usuarios.anyo_y                     0 non-null      object
#  89  usuarios.mes_y                      0 non-null      object
#  90  usuarios.dia_y                      0 non-null      object
#  91  usuarios.hora                       0 non-null      object
#  92  usuarios.minuto                     0 non-null      object
#  93  nombreDepartamento_y                0 non-null      object
#  94  nombreMunicipio_y                   0 non-null      object
#  95  idBeneficiario_y                    0 non-null      int64
#  96  fecha_y                             0 non-null      object
#  97  anyo_y                              0 non-null      object
#  98  mes_y                               0 non-null      object
#  99  dia_y                               0 non-null      object
# dtypes: float64(1), int64(12), object(87)
# memory usage: 0.0+ bytes

# %% [markdown]
# ## Actualiza fecha control

# %% [markdown]
# * Se actualiza la fecha de control. Si el calculo supera la fecha actual, se asocia esta ultima.

# %%
fecha_ejecucion= (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=10)).strftime("%Y-%m-%d %H:%M:%S")[0:15] + '0:00'    

if fecha_ejecucion > str(now.strftime('%Y-%m-%d %H:%M:%S'))[0:15] + '0:00':
    fecha_ejecucion = str(now.strftime('%Y-%m-%d %H:%M:%S'))[0:15] + '0:00'
response = es.index(
        index = indice_control,
        id = 'jerarquia-tablero12',
        body = { 'jerarquia-tablero12': 'jerarquia-tablero12','usuarios.fechaControl' : fecha_ejecucion}
)
print("actualizada fecha control de ejecucion:",fecha_ejecucion)
