# %% [markdown]
# ### ¿Qué hace este script?
#
# Calcula para cada dispositivo de red(AP) y rango de fecha, el tiempo promedio de sesión (usuarios.tiempoPromedioSesionSitio)

# %%
from elasticsearch import Elasticsearch, helpers
from ssl import create_default_context
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import parametros
import random
import re

# %% [markdown]
# ## Conectando a ElasticSearch

# %% [markdown]
# La ultima línea se utiliza para garantizar la ejecución de la consulta
# * timeout es el tiempo para cada ejecución
# * max_retries el número de intentos si la conexión falla
# * retry_on_timeout para activar los reitentos

# %%
context = create_default_context(cafile=parametros.cafile)
es = Elasticsearch(
    parametros.servidor,
    http_auth=(parametros.usuario_EC, parametros.password_EC),
    scheme="https",
    port=parametros.puerto,
    ssl_context=context,
    timeout=60, max_retries=3, retry_on_timeout=True
)

# %% [markdown]
# ### Calculando fechas para la ejecución

# %% [markdown]
# * Se calculan las fechas para asociar al nombre del indice
# * fecha_hoy es usada para concatenar al nombre del indice principal previa inserción

# %%
now = datetime.now()
fecha_hoy = str(now.strftime("%Y.%m.%d"))

# %% [markdown]
# ### nombre de indice donde se insertará e indice para control de ejecución

# %%
indice = parametros.usuarios_tablero07_index
indice_control = parametros.tableros_mintic_control

# %% [markdown]
# ### Funcion para JSON compatible con ElasticSearch

# %%
def filterKeys(document):
    return {key: document[key] for key in use_these_keys }

# %% [markdown]
# ### Trae la ultima fecha para control de ejecución

# %% [markdown]
# Cuando en el rango de tiempo de la ejecución, no se insertan nuevos valores, las fecha maxima en indice mintic no aumenta, por tanto se usa esta fecha de control para garantizar que incremente el bucle de ejecución

# %%
total_docs = 1
try:
    response = es.search(
        index= indice_control,
        body={
               "_source": ["usuarios.Tablero07.fechaControl"],
              "query": {
                "bool": {
                  "filter": [
                  {
                    "exists": {
                      "field":"jerarquia_usuarios_sesiones_sitio"
                    }
                  }
                  ]
                }
              }
        },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["hits"]["hits"]
    fields = {}
    for num, doc in enumerate(elastic_docs):
        fecha_ejecucion = doc["_source"]['usuarios.Tablero07.fechaControl']
except:
    pass
if response["hits"]["hits"] == []:
    fecha_ejecucion = '2021-05-01 00:00:00'
print("ultima fecha para control de ejecucion:",fecha_ejecucion)
# Out:
# ultima fecha para control de ejecucion: 2021-07-01 00:50:00

# %% [markdown]
# ### leyendo indice semilla-inventario

# %% [markdown]
# En el script que ingesta semilla, trae la información de los centros de conexión administrados. Para el indice principal se requiere:
# * site_id como llave del centro de conexión.
# * Datos geográficos (Departamento, municipio, centro poblado, sede, energía, latitud, longitud, COD_ISO, id_Beneficiario).

# %%
total_docs = 10000
try:
    response = es.search(
        index= parametros.semilla_inventario_index,
        body={
               "_source": ['site_id','nombre_municipio', 'nombre_departamento', 'nombre_centro_pob', 'nombreSede' 
                           , 'energiadesc', 'latitud', 'longitud', 'COD_ISO','id_Beneficiario']
        },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["hits"]["hits"]
    fields = {}
    for num, doc in enumerate(elastic_docs):
        source_data = doc["_source"]
        for key, val in source_data.items():
            try:
                fields[key] = np.append(fields[key], val)
            except KeyError:
                fields[key] = np.array([val])

    datos_semilla = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ])) #pd.DataFrame(fields)
except:
    exit()

# %% [markdown]
# ### Cambiando nombre de campos y generando location

# %% [markdown]
# * Se valida latitud y longitud. Luego se calcula campo location
# * Se renombran los campos de semilla

# %%
def get_location(x):
    patron = re.compile('^(\-?\d+(\.\d+)?),\s*(\-?\d+(\.\d+)?)$') #patrón que debe cumplir
    if (not patron.match(x) is None):
        return x.replace(',','.')
    else:
        #Código a ejecutar si las coordenadas no son válidas
        return 'a'
datos_semilla['latitud'] = datos_semilla['latitud'].apply(get_location)
datos_semilla['longitud'] = datos_semilla['longitud'].apply(get_location)
datos_semilla = datos_semilla.drop(datos_semilla[(datos_semilla["longitud"]=='a') | (datos_semilla["latitud"]=='a')].index)
datos_semilla['usuarios.location'] = datos_semilla['latitud'] + ',' + datos_semilla['longitud']
datos_semilla['usuarios.location']=datos_semilla['usuarios.location'].str.replace('a,a','')
datos_semilla.drop(columns=['latitud','longitud'],inplace=True)

# %%
datos_semilla = datos_semilla.rename(columns={'lugar_cod' : 'usuarios.centroDigitalUsuarios'
                                            , 'nombre_municipio': 'usuarios.nombreMunicipio'
                                            , 'nombre_departamento' : 'usuarios.nombreDepartamento'
                                            , 'nombre_centro_pob': 'usuarios.localidad'
                                            , 'nombreSede' : 'usuarios.nomCentroDigital'
                                            , 'energiadesc' : 'usuarios.sistemaEnergia'
                                            , 'COD_ISO' : 'usuarios.codISO'
                                            , 'id_Beneficiario' : 'usuarios.idBeneficiario'})

# %% [markdown]
# Se descartan los registros que tengan la latitud y longitud vacía o no valida

# %%
datos_semilla = datos_semilla.drop(datos_semilla[(datos_semilla["usuarios.location"]=='')].index)

# %%
datos_semilla
# Out:
#                    usuarios.nomCentroDigital usuarios.codISO  \
# 0                           C.E.R LA PAULINA          CO-ANT
# 1            CENTRO EDUCATIVO RURAL EL CERRO          CO-ANT
# 2                   C. E. R.  MERCEDES YEPES          CO-ANT
# 3                     C. E. R. MEDIAS FALDAS          CO-ANT
# 4                   C. E. R.  ROSAURA ORTEGA          CO-ANT
# ...                                      ...             ...
# 6941                ESCUELA RURAL SAN MIGUEL          CO-VAU
# 6942                    ESCUELA SANTA ISABEL          CO-VAU
# 6943  ESCUELA RURAL DE SAN LUIS DE PIEDRA ÑI          CO-VAU
# 6945                  ESCUELA RURAL DE TOAKA          CO-VAU
# 6946      ESCUELA SAMUEL DE PUERTO ESPERANZA          CO-VAU
#
#           usuarios.localidad        site_id usuarios.nombreDepartamento  \
# 0                 LA PAULINA  22154-ZGYO176                   ANTIOQUIA
# 1                   EL CERRO  20022-ZGYO177                   ANTIOQUIA
# 2             VDA. LA MESETA                                  ANTIOQUIA
# 3               VDA EL LIMÓN                                  ANTIOQUIA
# 4                 BELLAVISTA                                  ANTIOQUIA
# ...                      ...            ...                         ...
# 6941    COMUNIDAD SAN MIGUEL                                     VAUPÉS
# 6942  COMUNIDAD SANTA ISABEL                                     VAUPÉS
# 6943   COMUNIDAD DE SAN LUIS                                     VAUPÉS
# 6945      COMUNIDAD DE TOAKA                                     VAUPÉS
# 6946        PUERTO ESPERANZA                                     VAUPÉS
#
#      usuarios.sistemaEnergia usuarios.nombreMunicipio  \
# 0         RED INTERCONECTADA                 VALDIVIA
# 1         RED INTERCONECTADA                 FRONTINO
# 2         RED INTERCONECTADA                    ANORÍ
# 3              TIENE ENERGÍA                    ANORÍ
# 4         RED INTERCONECTADA                    ANORÍ
# ...                      ...                      ...
# 6941        SOLUCIÓN SOLAR                      PACOA
# 6942        SOLUCIÓN SOLAR                      PACOA
# 6943         SIN INFORMACIÓN                    PACOA
# 6945         SIN INFORMACIÓN                    PACOA
# 6946        NO TIENE ENERGÍA                   CARURÚ
#
#       usuarios.idBeneficiario         usuarios.location
# 0                       22154    6.7048548,-76.14525469
# 1                       20022  4.225166667,-73.10716667
# 2                       18787  6.93848274,-75.151177190
# 3                       18802   7.04797951,-75.19442611
# 4                       18804   7.06272584,-75.22730972
# ...                       ...                       ...
# 6941                    67732     0.11678,-70.072640000
# 6942                    67733  6.39026335,-73.138349330
# 6943                    70622   0.08164385,-70.07416384
# 6945                    70624  1.007644476,-71.25103723
# 6946                    70625   2.56013117,-72.64258639
#
# [6676 rows x 9 columns]

# %% [markdown]
# ### leyendo indice cambium-devicedevices

# %% [markdown]
# De esta formas se asocia las MAC de dispositivos de red INDOOR y OUTDOOR
# * site_id para cruzar con las misma llave de semilla.
# * datos del dispositivo: mac, status, ip.
# * ap_group para identificar si la conexión es indoor/outdoor

# %%
total_docs = 30000
try:
    response = es.search(
        index= parametros.cambium_d_d_index,
        body={
                    "_source": ["site_id","mac","status","ip","ap_group"]
                  , "query": {
                    "match_all": {}
                  }
        },
        size=total_docs
    )
    #print(es.info())
    elastic_docs = response["hits"]["hits"]
    fields = {}
    for num, doc in enumerate(elastic_docs):
        source_data = doc["_source"]
        for key, val in source_data.items():
            try:
                fields[key] = np.append(fields[key], val)
            except KeyError:
                fields[key] = np.array([val])

    datos_dev = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ])) #pd.DataFrame(fields)
except:
    exit()

# %% [markdown]
# Se descartan registros con site_id vacios ya que no cruzarán en el merge y se limpian los NaN del dataframe.

# %%
datos_dev.dropna(subset=['site_id'], inplace=True)
datos_dev.fillna('', inplace=True)
datos_dev = datos_dev.drop(datos_dev[(datos_dev['site_id']=='')].index)

# %% [markdown]
# Se corrigen datos de ap group con formato no valido

# %%
datos_dev['ap_group'] = datos_dev['ap_group'].str.split("-", n = 1, expand = True)[0]
datos_dev['ap_group'] = datos_dev['ap_group'].str.split("_", n = 1, expand = True)[0]
datos_dev = datos_dev.drop(datos_dev[(datos_dev['ap_group']=='')].index)

# %% [markdown]
# Se toman solo los datos con site_id y mac unicos.

# %%
#datos_dev.drop_duplicates(subset=['site_id','mac'],inplace=True)
datos_dev = datos_dev.drop_duplicates('mac')

# %%
datos_dev
# Out:
#      ap_group              ip        site_id                mac   status
# 0      INDOOR  172.28.118.179  44745-ZGYO227  BC:E6:7C:5E:66:88   online
# 1     OUTDOOR  172.28.118.180  44745-ZGYO227  58:C1:7A:E9:C9:6F   online
# 2     OUTDOOR  172.28.118.181  44745-ZGYO227  58:C1:7A:E9:C8:5C   online
# 3      INDOOR  172.28.118.171  44747-ZGYO413  BC:E6:7C:ED:F2:4F   online
# 4     OUTDOOR  172.28.118.172  44747-ZGYO413  BC:E6:7C:4F:07:88   online
# ...       ...             ...            ...                ...      ...
# 4498   INDOOR   172.25.30.163  49318-ZZZY605  BC:E6:7C:EC:AA:C7  offline
# 4499  OUTDOOR    172.25.84.76  37717-ZZZY751  BC:A9:93:0C:7B:9D  offline
# 4500  OUTDOOR    172.25.84.77  37717-ZZZY751  BC:A9:93:0C:E3:1D  offline
# 4501   INDOOR   172.25.38.243  47123-ZGYO420  BC:E6:7C:ED:8A:EA   online
# 4504  OUTDOOR   172.25.60.212  47847-VZVF114  BC:A9:93:00:97:B7  offline
#
# [4466 rows x 5 columns]

# %% [markdown]
# Se cambia el nombre a la mac del dispositivo de red para no confundir con la de dispositivos de usuario

# %%
datos_dev= datos_dev.rename(columns={'mac' : 'usuarios.macRed','ap_group' : 'usuarios.apGroup'})

# %% [markdown]
# ### Se lee información de Ohmyfi consumos

# %% [markdown]
# Apartir de esta lectura se toma el valor del tiempo promedio de sesión en minutos. Se toma de referencia los campos:
# * fecha_inicio a partir de la cual se calcula fecha control
# * tiempo_sesion_minutos
# * mac_usuario
# * lugar_cod

# %%
def traeSesiones(fecha_max,fecha_tope):
    total_docs = 500000
    response = es.search(
        index= parametros.ohmyfi_consumos_index,
        body={
                  "_source": ["lugar_cod", "tiempo_sesion_minutos","mac_ap","fecha_inicio"]
                , "query": {
                      "range": {
                            "fecha_inicio": {
                            "gte": fecha_max,
                            "lt": fecha_tope
                            }
                        }
                  }
        },
        size=total_docs
    )
    elastic_docs = response["hits"]["hits"]
    fields = {}
    for num, doc in enumerate(elastic_docs):
        source_data = doc["_source"]
        for key, val in source_data.items():
            try:
                fields[key] = np.append(fields[key], val)
            except KeyError:
                fields[key] = np.array([val])

    return pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in fields.items() ]))

# %%
def trae_conexiones(fecha_ini,fecha_fin):
    total_docs = 5000000
    response = es.search(
        index= parametros.ohmyfi_d_c_index,
        body={
                "_source": ["fechahora","fecha_control","lugar","lugar_cod","mac_usuario", "dispositivo"
                            ,"sistema_operativo",'tipodoc','documento']
                , "query": {
                  "range": {
                    "fechahora": {
                      "gte": fecha_ini,
                      "lt": fecha_fin
                    }
                  }
              }
        },
        size=total_docs
    )
    elastic_docs = response["hits"]["hits"]

    return pd.DataFrame([x["_source"] for x in elastic_docs])

# %% [markdown]
# ### Se ejecuta consulta de datos

# %% [markdown]
# * Se calcula rango en base a la fecha de control. Para este caso es de 10 minutos.
# * Se ejecuta la función de consulta con el rango de fechas.
# * Si no retorna datos se incrementa el rango y se ejecuta nuevamente. Este proceso se repite hasta conseguir datos o hasta que el rango de ejecución alcance la fecha y hora actual.

# %%
fecha_max_mintic = fecha_ejecucion

fecha_tope_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=50)-timedelta(seconds=1)).strftime("%Y-%m-%d %H:%M:%S")
datos_consumos = traeSesiones(fecha_max_mintic,fecha_tope_mintic)

if datos_consumos is None or datos_consumos.empty:
    while (datos_consumos is None or datos_consumos.empty) and ((datetime.strptime(fecha_max_mintic[0:50], '%Y-%m-%d').strftime("%Y-%m-%d %H:%M:%S")) < str(now.strftime("%Y-%m-%d %H:%M:%S"))):
        fecha_max_mintic = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=50)).strftime("%Y-%m-%d %H:%M:%S")
        fecha_tope_mintic = (datetime.strptime(fecha_tope_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=50)).strftime("%Y-%m-%d %H:%M:%S")
        datos_consumos = traeSesiones(fecha_max_mintic,fecha_tope_mintic)
else:
    pass

# %%
type(fecha_max_mintic)
# Out:
# str

# %%
type(fecha_ejecucion)
# Out:
# str

# %%
datos_det_conex = trae_conexiones(fecha_max_mintic,fecha_tope_mintic)

# %%
datos_det_conex['fecha'] = datos_det_conex['fecha_control'].str.split(" ", n = 1, expand = True)[0]
datos_det_conex.drop_duplicates(subset=["fecha_control","lugar","lugar_cod","mac_usuario", "dispositivo","sistema_operativo",'tipodoc','documento'],inplace=True)

# %%
datos_det_conex = datos_det_conex.rename(columns={'lugar_cod' : 'site_id'
                                                             ,'fechahora':'usuarios.fechaConexionUsuarios'
                                                             ,'dispositivo': 'usuarios.tipoDispositivoUsuarios'
                                                             , 'sistema_operativo': 'usuarios.sistemaOperativoUsuarios'})

# %%
fecha_max_mintic
# Out:
# '2021-07-01 00:50:00'

# %%
datos_det_conex
# Out:
#    usuarios.fechaConexionUsuarios        mac_usuario  \
# 0             2021-07-01 01:00:14  88:10:8F:FB:93:81
# 1             2021-07-01 01:00:35  68:A0:3E:98:AA:CF
# 3             2021-07-01 01:00:41  88:AD:D2:5E:95:18
# 4             2021-07-01 01:00:44  EC:AA:25:29:C4:89
# 9             2021-07-01 01:01:55  B8:94:36:8C:37:98
# 10            2021-07-01 01:30:06  D0:FC:CC:17:05:9A
# 11            2021-07-01 01:30:34  7C:38:AD:69:6B:5B
# 13            2021-07-01 01:31:41  9C:28:F7:A0:B9:D0
#
#    usuarios.tipoDispositivoUsuarios                                 lugar  \
# 0                        Smartphone  CGTO DE VALENCIA DE JESUS_VALLEDUPAR
# 1                        Smartphone                  GUAIMARITO_HATONUEVO
# 3                        Smartphone                         TOLIMA_TUCHIN
# 4                        Smartphone                   SACANA ABAJO, MOMIL
# 9                        Smartphone                     DE BREMEN, MORROA
# 10                       Smartphone             CALLE 115 # 06 - 60_TURBO
# 11                       Smartphone          VILLANUEVA_PUERTO LIBERTADOR
# 13                       Smartphone                     SANTA ANA_ITUANGO
#
#      documento tipodoc        site_id        fecha_control  \
# 0     10674528      TI  67697-ZGYO849  2021-07-01 01:00:00
# 1   1006734120      CC  37617-ZZZY740  2021-07-01 01:00:00
# 3   1193557935      CC  32313-ZGYO438  2021-07-01 01:00:00
# 4   1003213476      CC  31730-ZGYO298  2021-07-01 01:00:00
# 9     64740741      CC  47362-ZZZY006  2021-07-01 01:00:00
# 10    39310107      CC  10835-ZGYO372  2021-07-01 01:30:00
# 11  1145678904      CC  32066-ZZZY759  2021-07-01 01:30:00
# 13  1037262939      TI  20270-ZGYO186  2021-07-01 01:30:00
#
#    usuarios.sistemaOperativoUsuarios       fecha
# 0                            Android  2021-07-01
# 1                            Android  2021-07-01
# 3                            Android  2021-07-01
# 4                            Android  2021-07-01
# 9                            Android  2021-07-01
# 10                           Android  2021-07-01
# 11                           Android  2021-07-01
# 13                           Android  2021-07-01

# %%
datos_det_conex.columns
# Out:
# Index(['usuarios.fechaConexionUsuarios', 'mac_usuario',
#        'usuarios.tipoDispositivoUsuarios', 'lugar', 'documento', 'tipodoc',
#        'site_id', 'fecha_control', 'usuarios.sistemaOperativoUsuarios',
#        'fecha'],
#       dtype='object')

# %% [markdown]
# # Escribiendo en indice la información de tiempo promedio sesión en sitio

# %%
use_these_keys = ['usuarios.tiempoPromedioSesionSitio'
                  , 'usuarios.nomCentroDigital'
                  , 'usuarios.codISO'
                  , 'usuarios.idBeneficiario'
                  , 'usuarios.localidad'
                  , 'usuarios.siteID'
                  , 'usuarios.nombreDepartamento'
                  , 'usuarios.sistemaEnergia'
                  , 'usuarios.nombreMunicipio'
                  , 'usuarios.location'
                  , 'usuarios.macRed'
                  , 'usuarios.apGroup'
                  , 'usuarios.usuariosConectados'
                  , 'usuarios.sesiones_Usuarios'
                  , 'usuarios.fechaControl'
                  , 'usuarios.fecha'
                  , 'usuarios.anyo'
                  , 'usuarios.mes'
                  , 'usuarios.dia'
                  , 'usuarios.hora'
                  , 'usuarios.minuto'
                    , 'nombreDepartamento'
                    , 'nombreMunicipio'
                    , 'idBeneficiario'
                    , 'fecha'
                    , 'anyo'
                    , 'mes'
                    , 'dia'
                  , '@timestamp']
def doc_generator(df):
        df_iter = df.iterrows()
        for index, document in df_iter:
            document = document.rename(index={'usuarios.tiempoPromedioSesionSitio_x': 'usuarios.tiempoPromedioSesionSitio','usuarios.macRed_x':'usuarios.macRed','usuarios.apGroup_x':'usuarios.apGroup','usuarios.fechaControl_x':'usuarios.fechaControl'})
            yield {
                    "_index": indice, 
                    "_id": f"{str(document['usuarios.siteID']) + '-' + str(document['usuarios.fechaControl']) + '-' + str(document['usuarios.macRed'])+'-'+str(random.randrange(10000000))}",
                    "_source": filterKeys(document),
                }

# %%
use_these_keys
# Out:
# ['usuarios.tiempoPromedioSesionSitio',
#  'usuarios.nomCentroDigital',
#  'usuarios.codISO',
#  'usuarios.idBeneficiario',
#  'usuarios.localidad',
#  'usuarios.siteID',
#  'usuarios.nombreDepartamento',
#  'usuarios.sistemaEnergia',
#  'usuarios.nombreMunicipio',
#  'usuarios.location',
#  'usuarios.macRed',
#  'usuarios.apGroup',
#  'usuarios.usuariosConectados',
#  'usuarios.sesiones_Usuarios',
#  'usuarios.fechaControl',
#  'usuarios.fecha',
#  'usuarios.anyo',
#  'usuarios.mes',
#  'usuarios.dia',
#  'usuarios.hora',
#  'usuarios.minuto',
#  'nombreDepartamento',
#  'nombreMunicipio',
#  'idBeneficiario',
#  'fecha',
#  'anyo',
#  'mes',
#  'dia',
#  '@timestamp']

# %% [markdown]
# Se agrupa por lugar_cod, fecha_control, mac_usuario y se promedia el tiempo_sesion_minutos. Este genera el campo del indice final:
# * usuarios.tiempoPromedioSesionSitio

# %%
datos_consumos.columns
# Out:
# Index(['fecha_inicio', 'tiempo_sesion_minutos', 'mac_ap', 'lugar_cod'], dtype='object')

# %%
datos_consumos
# Out:
#             fecha_inicio  tiempo_sesion_minutos             mac_ap  \
# 0    2021-07-01 00:52:47                   5.00  58:C1:7A:E8:76:8B
# 1    2021-07-01 00:57:48                   0.78  58:C1:7A:E8:77:EA
# 2    2021-07-01 00:58:34                   9.97  58:C1:7A:E8:76:8B
# 3    2021-07-01 00:57:24                  15.63  BC:E6:7C:EF:FC:D1
# 4    2021-07-01 00:52:16                   0.35  BC:E6:7C:E7:FD:51
# ..                   ...                    ...                ...
# 492  2021-07-01 01:20:13                 102.22  BC:E6:7C:EF:FE:4F
# 493  2021-07-01 01:20:29                  21.28  BC:E6:7C:EF:FE:4F
# 494  2021-07-01 01:01:29                   4.40  BC:E6:7C:E7:FC:FB
# 495  2021-07-01 01:06:06                   3.55  BC:E6:7C:E7:FC:FB
# 496  2021-07-01 01:27:40                  13.33  BC:E6:7C:E7:FC:FB
#
#          lugar_cod
# 0    22483-ZGYO057
# 1    22483-ZGYO057
# 2    22483-ZGYO057
# 3    30731-ZGYO144
# 4    70813-ZZZY057
# ..             ...
# 492  30435-ZGYO116
# 493  30435-ZGYO116
# 494  47054-VZVF187
# 495  47054-VZVF187
# 496  47054-VZVF187
#
# [497 rows x 4 columns]

# %% [markdown]
#  Se corrigen valores errados de site_id en detalle conexiones

# %%
try:
    datos_consumos = datos_consumos.rename(columns={'lugar_cod' :'site_id'})
    datos_consumos['mac_ap'] = datos_consumos['mac_ap'].str.replace('-',':')
    datos_consumos['fecha_control'] = datos_consumos["fecha_inicio"].str[0:-4] + '0:00'
    tiempoPromedioSesionSitio=datos_consumos[['site_id','mac_ap','fecha_control','tiempo_sesion_minutos']].groupby(['site_id','mac_ap','fecha_control']).agg(['mean']).reset_index()
    tiempoPromedioSesionSitio.columns = tiempoPromedioSesionSitio.columns.droplevel(1)
    tiempoPromedioSesionSitio = tiempoPromedioSesionSitio.rename(columns={'tiempo_sesion_minutos' : 'usuarios.tiempoPromedioSesionSitio'})
    tiempoPromedioSesionSitio['usuarios.tiempoPromedioSesionSitio'] = round(tiempoPromedioSesionSitio['usuarios.tiempoPromedioSesionSitio'],6)
    tiempoPromedioSesionSitio = tiempoPromedioSesionSitio.rename(columns={'mac_ap' : 'usuarios.macRed'
                                                                          ,'fecha_control' : 'usuarios.fechaControl'})
    tiempoPromedioSesionSitio = pd.merge(tiempoPromedioSesionSitio,datos_semilla, on ='site_id', how='inner')
    tiempoPromedioSesionSitio = pd.merge(tiempoPromedioSesionSitio, datos_dev, on=['site_id','usuarios.macRed'], how='left')
    tiempoPromedioSesionSitio.fillna({'usuarios.apGroup':'No identificado'},inplace=True)

    datos_logins = datos_det_conex[['fecha_control', 'site_id', 'documento']].groupby(["fecha_control","site_id"])['documento'].nunique().reset_index()
    datos_logins= datos_logins.rename(columns={'documento' : 'usuarios.sesiones_Usuarios'})

    usuariosConectados = datos_det_conex[["fecha_control","site_id","mac_usuario"]].groupby(["fecha_control","site_id"]).agg(['count']).reset_index()
    usuariosConectados.columns = usuariosConectados.columns.droplevel(1)
    usuariosConectados= usuariosConectados.rename(columns={'mac_usuario' : 'usuarios.usuariosConectados' })
    usuariosConectados = pd.merge(usuariosConectados,datos_logins, on=["fecha_control","site_id"], how='inner')
    usuariosConectados = pd.merge(datos_semilla,  usuariosConectados, on=['site_id'], how='inner')
    usuariosConectados = pd.merge(usuariosConectados, tiempoPromedioSesionSitio, on=['site_id'], how='inner')
    usuariosConectados.fillna({'usuarios.consumoUsuarios' : 0
                              ,'usuarios.consumoUsuariosDescarga':0
                              ,'usuarios.consumoUsuariosCarga':0},inplace=True)

    usuariosConectados.fillna({'usuarios.apGroup':'No identificado'},inplace=True)
    usuariosConectados['usuarios.usuariosConectados'] = usuariosConectados['usuarios.usuariosConectados'].astype(int)
    usuariosConectados = usuariosConectados.rename(columns={'fecha_control':'usuarios.fechaControl'
                                                           ,'site_id' : 'usuarios.siteID'})

    tiempoPromedioSesionSitio = tiempoPromedioSesionSitio.rename(columns={'site_id' : 'usuarios.siteID'})
    tiempoPromedioSesionSitio["usuarios.fecha"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str[0:10]
    tiempoPromedioSesionSitio["usuarios.anyo"] = tiempoPromedioSesionSitio["usuarios.fecha"].str[0:4]
    tiempoPromedioSesionSitio["usuarios.mes"] = tiempoPromedioSesionSitio["usuarios.fecha"].str[5:7]
    tiempoPromedioSesionSitio["usuarios.dia"] = tiempoPromedioSesionSitio["usuarios.fecha"].str[8:10]
    tiempoPromedioSesionSitio["usuarios.hora"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[0]["usuarios.hora"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[0]
    tiempoPromedioSesionSitio["usuarios.minuto"] = tiempoPromedioSesionSitio["usuarios.fechaControl"].str.split(" ", n = 1, expand = True)[1].str.split(":", n = 2, expand = True)[1]

    tiempoPromedioSesionSitio['nombreDepartamento'] = tiempoPromedioSesionSitio['usuarios.nombreDepartamento']
    tiempoPromedioSesionSitio['nombreMunicipio'] = tiempoPromedioSesionSitio['usuarios.nombreMunicipio']
    tiempoPromedioSesionSitio['idBeneficiario'] = tiempoPromedioSesionSitio['usuarios.idBeneficiario']
    tiempoPromedioSesionSitio['fecha'] = tiempoPromedioSesionSitio['usuarios.fecha']
    tiempoPromedioSesionSitio['anyo'] = tiempoPromedioSesionSitio['usuarios.anyo']
    tiempoPromedioSesionSitio['mes'] = tiempoPromedioSesionSitio['usuarios.mes']
    tiempoPromedioSesionSitio['dia'] = tiempoPromedioSesionSitio['usuarios.dia']
    tiempoPromedioSesionSitio['@timestamp'] = now.isoformat()

    usuariosConectados2 = pd.merge(tiempoPromedioSesionSitio, usuariosConectados, on=['usuarios.siteID'], how='inner')  
    usuariosConectados2

    salida = helpers.bulk(es, doc_generator(usuariosConectados2))
    
    print("Fecha: ", now,"- Tiempo promedio sesion en sitio insertado en indice principal:",salida[0])
    
except:
    print("Fecha: ", now,"- Nada para insertar en indice principal")
# Out:
# Fecha:  2021-08-02 22:05:02.309076 - Tiempo promedio sesion en sitio insertado en indice principal: 33

# %%
usuariosConectados2
# Out:
#    usuarios.siteID  usuarios.macRed_x usuarios.fechaControl_x  \
# 0    10835-ZGYO372  BC:E6:7C:4E:3E:8F     2021-07-01 01:30:00
# 1    20270-ZGYO186  BC:E6:7C:4E:3C:DE     2021-07-01 01:30:00
# 2    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:00:00
# 3    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:00:00
# 4    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:00:00
# 5    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:00:00
# 6    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:10:00
# 7    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:10:00
# 8    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:10:00
# 9    31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:10:00
# 10   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:20:00
# 11   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:20:00
# 12   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:20:00
# 13   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:20:00
# 14   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:30:00
# 15   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:30:00
# 16   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:30:00
# 17   31730-ZGYO298  BC:E6:7C:E7:FC:D8     2021-07-01 01:30:00
# 18   32313-ZGYO438  BC:E6:7C:4E:3E:37     2021-07-01 01:00:00
# 19   37617-ZZZY740  BC:E6:7C:E8:3E:7E     2021-07-01 01:00:00
# 20   47362-ZZZY006  BC:E6:7C:E8:CE:4D     2021-07-01 01:00:00
# 21   47362-ZZZY006  BC:E6:7C:E8:CE:4D     2021-07-01 01:00:00
# 22   47362-ZZZY006  BC:E6:7C:E8:CE:71     2021-07-01 00:50:00
# 23   47362-ZZZY006  BC:E6:7C:E8:CE:71     2021-07-01 00:50:00
# 24   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 00:50:00
# 25   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 00:50:00
# 26   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 00:50:00
# 27   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 01:00:00
# 28   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 01:00:00
# 29   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 01:00:00
# 30   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 01:20:00
# 31   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 01:20:00
# 32   67697-ZGYO849  BC:E6:7C:5B:AF:C8     2021-07-01 01:20:00
#
#     usuarios.tiempoPromedioSesionSitio_x  \
# 0                               7.850000
# 1                             120.000000
# 2                               0.966667
# 3                               0.966667
# 4                               0.966667
# 5                               0.966667
# 6                               0.675000
# 7                               0.675000
# 8                               0.675000
# 9                               0.675000
# 10                              1.140000
# 11                              1.140000
# 12                              1.140000
# 13                              1.140000
# 14                              1.135000
# 15                              1.135000
# 16                              1.135000
# 17                              1.135000
# 18                             58.670000
# 19                            120.000000
# 20                            120.000000
# 21                            120.000000
# 22                            120.000000
# 23                            120.000000
# 24                              0.380000
# 25                              0.380000
# 26                              0.380000
# 27                             10.890000
# 28                             10.890000
# 29                             10.890000
# 30                             20.260000
# 31                             20.260000
# 32                             20.260000
#
#                    usuarios.nomCentroDigital usuarios.codISO  \
# 0                       E.U. SIETE DE AGOSTO          CO-ANT
# 1      INSTITUCIÓN EDUCATIVA RURAL SANTA ANA          CO-ANT
# 2                     ESC NUEVA SACANA ABAJO          CO-COR
# 3                     ESC NUEVA SACANA ABAJO          CO-COR
# 4                     ESC NUEVA SACANA ABAJO          CO-COR
# 5                     ESC NUEVA SACANA ABAJO          CO-COR
# 6                     ESC NUEVA SACANA ABAJO          CO-COR
# 7                     ESC NUEVA SACANA ABAJO          CO-COR
# 8                     ESC NUEVA SACANA ABAJO          CO-COR
# 9                     ESC NUEVA SACANA ABAJO          CO-COR
# 10                    ESC NUEVA SACANA ABAJO          CO-COR
# 11                    ESC NUEVA SACANA ABAJO          CO-COR
# 12                    ESC NUEVA SACANA ABAJO          CO-COR
# 13                    ESC NUEVA SACANA ABAJO          CO-COR
# 14                    ESC NUEVA SACANA ABAJO          CO-COR
# 15                    ESC NUEVA SACANA ABAJO          CO-COR
# 16                    ESC NUEVA SACANA ABAJO          CO-COR
# 17                    ESC NUEVA SACANA ABAJO          CO-COR
# 18                ESCUELA RURAL MIXTA TOLIMA          CO-COR
# 19               CENTRO EDUCATIVO GUAIMARITO          CO-LAG
# 20                   CENTRO EDUCATIVO BREMEN          CO-SUC
# 21                   CENTRO EDUCATIVO BREMEN          CO-SUC
# 22                   CENTRO EDUCATIVO BREMEN          CO-SUC
# 23                   CENTRO EDUCATIVO BREMEN          CO-SUC
# 24  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 25  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 26  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 27  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 28  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 29  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 30  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 31  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
# 32  ESCUELA RURAL MIXTA DE VALENCIA DE JESÚS          CO-CES
#
#            usuarios.localidad usuarios.nombreDepartamento  \
# 0         CALLE 115 # 06 - 60                   ANTIOQUIA
# 1                   SANTA ANA                   ANTIOQUIA
# 2                SACANA ABAJO                     CÓRDOBA
# 3                SACANA ABAJO                     CÓRDOBA
# 4                SACANA ABAJO                     CÓRDOBA
# 5                SACANA ABAJO                     CÓRDOBA
# 6                SACANA ABAJO                     CÓRDOBA
# 7                SACANA ABAJO                     CÓRDOBA
# 8                SACANA ABAJO                     CÓRDOBA
# 9                SACANA ABAJO                     CÓRDOBA
# 10               SACANA ABAJO                     CÓRDOBA
# 11               SACANA ABAJO                     CÓRDOBA
# 12               SACANA ABAJO                     CÓRDOBA
# 13               SACANA ABAJO                     CÓRDOBA
# 14               SACANA ABAJO                     CÓRDOBA
# 15               SACANA ABAJO                     CÓRDOBA
# 16               SACANA ABAJO                     CÓRDOBA
# 17               SACANA ABAJO                     CÓRDOBA
# 18                     TOLIMA                     CÓRDOBA
# 19                 GUAIMARITO                  LA GUAJIRA
# 20                  DE BREMEN                       SUCRE
# 21                  DE BREMEN                       SUCRE
# 22                  DE BREMEN                       SUCRE
# 23                  DE BREMEN                       SUCRE
# 24  CGTO DE VALENCIA DE JESUS                       CESAR
# 25  CGTO DE VALENCIA DE JESUS                       CESAR
# 26  CGTO DE VALENCIA DE JESUS                       CESAR
# 27  CGTO DE VALENCIA DE JESUS                       CESAR
# 28  CGTO DE VALENCIA DE JESUS                       CESAR
# 29  CGTO DE VALENCIA DE JESUS                       CESAR
# 30  CGTO DE VALENCIA DE JESUS                       CESAR
# 31  CGTO DE VALENCIA DE JESUS                       CESAR
# 32  CGTO DE VALENCIA DE JESUS                       CESAR
#
#    usuarios.sistemaEnergia usuarios.nombreMunicipio  ...  usuarios.codISO_y  \
# 0       RED INTERCONECTADA                    TURBO  ...             CO-ANT
# 1       RED INTERCONECTADA                  ITUANGO  ...             CO-ANT
# 2       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 3       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 4       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 5       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 6       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 7       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 8       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 9       RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 10      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 11      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 12      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 13      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 14      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 15      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 16      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 17      RED INTERCONECTADA                    MOMIL  ...             CO-COR
# 18      RED INTERCONECTADA                   TUCHÍN  ...             CO-COR
# 19      RED INTERCONECTADA                HATONUEVO  ...             CO-LAG
# 20      RED INTERCONECTADA                   MORROA  ...             CO-SUC
# 21      RED INTERCONECTADA                   MORROA  ...             CO-SUC
# 22      RED INTERCONECTADA                   MORROA  ...             CO-SUC
# 23      RED INTERCONECTADA                   MORROA  ...             CO-SUC
# 24      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 25      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 26      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 27      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 28      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 29      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 30      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 31      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
# 32      RED INTERCONECTADA               VALLEDUPAR  ...             CO-CES
#
#          usuarios.localidad_y usuarios.nombreDepartamento_y  \
# 0         CALLE 115 # 06 - 60                     ANTIOQUIA
# 1                   SANTA ANA                     ANTIOQUIA
# 2                SACANA ABAJO                       CÓRDOBA
# 3                SACANA ABAJO                       CÓRDOBA
# 4                SACANA ABAJO                       CÓRDOBA
# 5                SACANA ABAJO                       CÓRDOBA
# 6                SACANA ABAJO                       CÓRDOBA
# 7                SACANA ABAJO                       CÓRDOBA
# 8                SACANA ABAJO                       CÓRDOBA
# 9                SACANA ABAJO                       CÓRDOBA
# 10               SACANA ABAJO                       CÓRDOBA
# 11               SACANA ABAJO                       CÓRDOBA
# 12               SACANA ABAJO                       CÓRDOBA
# 13               SACANA ABAJO                       CÓRDOBA
# 14               SACANA ABAJO                       CÓRDOBA
# 15               SACANA ABAJO                       CÓRDOBA
# 16               SACANA ABAJO                       CÓRDOBA
# 17               SACANA ABAJO                       CÓRDOBA
# 18                     TOLIMA                       CÓRDOBA
# 19                 GUAIMARITO                    LA GUAJIRA
# 20                  DE BREMEN                         SUCRE
# 21                  DE BREMEN                         SUCRE
# 22                  DE BREMEN                         SUCRE
# 23                  DE BREMEN                         SUCRE
# 24  CGTO DE VALENCIA DE JESUS                         CESAR
# 25  CGTO DE VALENCIA DE JESUS                         CESAR
# 26  CGTO DE VALENCIA DE JESUS                         CESAR
# 27  CGTO DE VALENCIA DE JESUS                         CESAR
# 28  CGTO DE VALENCIA DE JESUS                         CESAR
# 29  CGTO DE VALENCIA DE JESUS                         CESAR
# 30  CGTO DE VALENCIA DE JESUS                         CESAR
# 31  CGTO DE VALENCIA DE JESUS                         CESAR
# 32  CGTO DE VALENCIA DE JESUS                         CESAR
#
#    usuarios.sistemaEnergia_y usuarios.nombreMunicipio_y  \
# 0         RED INTERCONECTADA                      TURBO
# 1         RED INTERCONECTADA                    ITUANGO
# 2         RED INTERCONECTADA                      MOMIL
# 3         RED INTERCONECTADA                      MOMIL
# 4         RED INTERCONECTADA                      MOMIL
# 5         RED INTERCONECTADA                      MOMIL
# 6         RED INTERCONECTADA                      MOMIL
# 7         RED INTERCONECTADA                      MOMIL
# 8         RED INTERCONECTADA                      MOMIL
# 9         RED INTERCONECTADA                      MOMIL
# 10        RED INTERCONECTADA                      MOMIL
# 11        RED INTERCONECTADA                      MOMIL
# 12        RED INTERCONECTADA                      MOMIL
# 13        RED INTERCONECTADA                      MOMIL
# 14        RED INTERCONECTADA                      MOMIL
# 15        RED INTERCONECTADA                      MOMIL
# 16        RED INTERCONECTADA                      MOMIL
# 17        RED INTERCONECTADA                      MOMIL
# 18        RED INTERCONECTADA                     TUCHÍN
# 19        RED INTERCONECTADA                  HATONUEVO
# 20        RED INTERCONECTADA                     MORROA
# 21        RED INTERCONECTADA                     MORROA
# 22        RED INTERCONECTADA                     MORROA
# 23        RED INTERCONECTADA                     MORROA
# 24        RED INTERCONECTADA                 VALLEDUPAR
# 25        RED INTERCONECTADA                 VALLEDUPAR
# 26        RED INTERCONECTADA                 VALLEDUPAR
# 27        RED INTERCONECTADA                 VALLEDUPAR
# 28        RED INTERCONECTADA                 VALLEDUPAR
# 29        RED INTERCONECTADA                 VALLEDUPAR
# 30        RED INTERCONECTADA                 VALLEDUPAR
# 31        RED INTERCONECTADA                 VALLEDUPAR
# 32        RED INTERCONECTADA                 VALLEDUPAR
#
#    usuarios.idBeneficiario_y        usuarios.location_y usuarios.apGroup_y  \
# 0                      10835  10.88307108,-75.077732850            OUTDOOR
# 1                      20270  8.051666667,-75.669000000            OUTDOOR
# 2                      31730   9.32313135,-75.622755310            OUTDOOR
# 3                      31730   9.32313135,-75.622755310            OUTDOOR
# 4                      31730   9.32313135,-75.622755310            OUTDOOR
# 5                      31730   9.32313135,-75.622755310            OUTDOOR
# 6                      31730   9.32313135,-75.622755310            OUTDOOR
# 7                      31730   9.32313135,-75.622755310            OUTDOOR
# 8                      31730   9.32313135,-75.622755310            OUTDOOR
# 9                      31730   9.32313135,-75.622755310            OUTDOOR
# 10                     31730   9.32313135,-75.622755310            OUTDOOR
# 11                     31730   9.32313135,-75.622755310            OUTDOOR
# 12                     31730   9.32313135,-75.622755310            OUTDOOR
# 13                     31730   9.32313135,-75.622755310            OUTDOOR
# 14                     31730   9.32313135,-75.622755310            OUTDOOR
# 15                     31730   9.32313135,-75.622755310            OUTDOOR
# 16                     31730   9.32313135,-75.622755310            OUTDOOR
# 17                     31730   9.32313135,-75.622755310            OUTDOOR
# 18                     32313    4.93549001,-75.59530623            OUTDOOR
# 19                     37617    9.39831634,-75.46428801            OUTDOOR
# 20                     47362        8.613822,-75.317972            OUTDOOR
# 21                     47362        8.613822,-75.317972            OUTDOOR
# 22                     47362        8.613822,-75.317972            OUTDOOR
# 23                     47362        8.613822,-75.317972            OUTDOOR
# 24                     67697   9.257807923,-75.48863058            OUTDOOR
# 25                     67697   9.257807923,-75.48863058            OUTDOOR
# 26                     67697   9.257807923,-75.48863058            OUTDOOR
# 27                     67697   9.257807923,-75.48863058            OUTDOOR
# 28                     67697   9.257807923,-75.48863058            OUTDOOR
# 29                     67697   9.257807923,-75.48863058            OUTDOOR
# 30                     67697   9.257807923,-75.48863058            OUTDOOR
# 31                     67697   9.257807923,-75.48863058            OUTDOOR
# 32                     67697   9.257807923,-75.48863058            OUTDOOR
#
#               ip_y status_y
# 0   172.28.118.244   online
# 1   172.28.107.197   online
# 2    172.25.39.220   online
# 3    172.25.39.220   online
# 4    172.25.39.220   online
# 5    172.25.39.220   online
# 6    172.25.39.220   online
# 7    172.25.39.220   online
# 8    172.25.39.220   online
# 9    172.25.39.220   online
# 10   172.25.39.220   online
# 11   172.25.39.220   online
# 12   172.25.39.220   online
# 13   172.25.39.220   online
# 14   172.25.39.220   online
# 15   172.25.39.220   online
# 16   172.25.39.220   online
# 17   172.25.39.220   online
# 18   172.25.49.116   online
# 19    172.25.84.28   online
# 20   172.25.121.52   online
# 21   172.25.121.53   online
# 22   172.25.121.52   online
# 23   172.25.121.53   online
# 24  172.25.117.133   online
# 25  172.25.117.133   online
# 26  172.25.117.133   online
# 27  172.25.117.133   online
# 28  172.25.117.133   online
# 29  172.25.117.133   online
# 30  172.25.117.133   online
# 31  172.25.117.133   online
# 32  172.25.117.133   online
#
# [33 rows x 54 columns]

# %%
usuariosConectados2.columns
# Out:
# Index(['usuarios.siteID', 'usuarios.macRed_x', 'usuarios.fechaControl_x',
#        'usuarios.tiempoPromedioSesionSitio_x', 'usuarios.nomCentroDigital',
#        'usuarios.codISO', 'usuarios.localidad', 'usuarios.nombreDepartamento',
#        'usuarios.sistemaEnergia', 'usuarios.nombreMunicipio',
#        'usuarios.idBeneficiario', 'usuarios.location', 'usuarios.apGroup_x',
#        'ip_x', 'status_x', 'usuarios.fecha', 'usuarios.anyo', 'usuarios.mes',
#        'usuarios.dia', 'usuarios.hora', 'usuarios.minuto',
#        'nombreDepartamento', 'nombreMunicipio', 'idBeneficiario', 'fecha',
#        'anyo', 'mes', 'dia', '@timestamp', 'usuarios.nomCentroDigital_x',
#        'usuarios.codISO_x', 'usuarios.localidad_x',
#        'usuarios.nombreDepartamento_x', 'usuarios.sistemaEnergia_x',
#        'usuarios.nombreMunicipio_x', 'usuarios.idBeneficiario_x',
#        'usuarios.location_x', 'usuarios.fechaControl_y',
#        'usuarios.usuariosConectados', 'usuarios.sesiones_Usuarios',
#        'usuarios.macRed_y', 'usuarios.fechaControl_y',
#        'usuarios.tiempoPromedioSesionSitio_y', 'usuarios.nomCentroDigital_y',
#        'usuarios.codISO_y', 'usuarios.localidad_y',
#        'usuarios.nombreDepartamento_y', 'usuarios.sistemaEnergia_y',
#        'usuarios.nombreMunicipio_y', 'usuarios.idBeneficiario_y',
#        'usuarios.location_y', 'usuarios.apGroup_y', 'ip_y', 'status_y'],
#       dtype='object')

# %% [markdown]
# ### Guardando fecha para control de ejecución

# %% [markdown]
# * Se actualiza la fecha de control. Si el calculo supera la fecha hora actual, se asocia esta ultima.

# %%
fecha_ejecucion = (datetime.strptime(fecha_max_mintic, '%Y-%m-%d %H:%M:%S')+timedelta(minutes=50)).strftime("%Y-%m-%d %H:%M:%S")[0:15] + '0:00'    

if fecha_ejecucion > str(now.strftime('%Y-%m-%d %H:%M:%S'))[0:15] + '0:00':
    fecha_ejecucion = str(now.strftime('%Y-%m-%d %H:%M:%S'))[0:15] + '0:00'
response = es.index(
        index = indice_control,
        id = 'jerarquia_usuarios_sesiones_sitio',
        body = { 'jerarquia_usuarios_sesiones_sitio': 'usuarios_sesiones_sitio','usuarios.Tablero07.fechaControl' : fecha_ejecucion}
)
print("actualizada fecha control de ejecucion:",fecha_ejecucion)
# Out:
# actualizada fecha control de ejecucion: 2021-07-01 01:40:00
